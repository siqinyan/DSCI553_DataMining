# %%
import json
from datetime import datetime
from pyspark import SparkConf, SparkContext
from operator import add

# %% [markdown]
# ### Task1: Data Exploration (4.5pts)

# %% [markdown]
# Task description: You will explore the review dataset and write a program to answer the following questions.

# %%
# params = sys.argv
# input_file, output_file, stopwords = params[1], params[2], params[3], 
# y, m, n = int(params[4]), int(params[5]), int(params[6])

# %%
results = {}

# %%
input_file = './review.json'
# output_file = sys.argv[2]
stopwords = './stopwords'
y = 2018
m = 4
n = 5

# %%
conf = SparkConf()
sc = SparkContext(conf=conf)

# %%
review = sc.textFile(input_file).map(lambda r: json.loads(r))

# %% [markdown]
# A. The total number of reviews (0.5pts)

# %%
results['A'] = review.map(lambda r: r['review_id']).count()
results
# Out:
# {'A': 1151625}

# %% [markdown]
# B. The number of reviews in a given year, y (1pts)

# %%
results['B'] = review.map(lambda r: r['date']) \
                    .filter(lambda r: datetime.strptime(r, '%Y-%m-%d %H:%M:%S').year==y).count()
results
# Out:
# {'A': 1151625, 'B': 202784}

# %% [markdown]
# C. The number of distinct users who have written the reviews (1pts)

# %%
results['C'] = review.map(lambda r: r['user_id']).distinct().count()
results
# Out:
# {'A': 1151625, 'B': 202784, 'C': 566269}

# %% [markdown]
# D. Top m users who have the largest number of reviews and its count (1pts)

# %%
results['D'] = review.map(lambda r: (r['business_id'], r['user_id'])).map(lambda r: (r[1], 1)) \
                     .reduceByKey(add).top(m, key=lambda r: r[1])
results
# Out:
# {'A': 1151625,
#  'B': 202784,
#  'C': 566269,
#  'D': [('CxDOIDnH8gp9KXzpBHJYXw', 715),
#   ('bLbSNkLggFnqwNNzzq-Ijw', 424),
#   ('PKEzKWv_FktMm2mGPjwd0Q', 322),
#   ('DK57YibC5ShBmqQl97CKog', 291)]}

# %% [markdown]
# E. Top n frequent words in the review text. The words should be in lower cases. The following punctuations “(”, “[”, “,”, “.”, “!”, “?”, “:”, “;”, “]”, “)” and the given stopwords are excluded (1pts)

# %%
punctuations = set(['(', '[', ',', '.', '!', '?', ':', ';', ']', ')'])
stopwords = set(w.strip() for w in open(stopwords))

# %%
def exclude_words(word):
    if word not in stopwords:
        re = ''
        for w in word:
            if w not in punctuations:
                re += w
        return re

# %%
tmp = review.map(lambda r: r['text']).flatMap(lambda t: t.lower().split(' ')) \
            .map(lambda w: (exclude_words(w), 1)).filter(lambda w: w[0]!=None).reduceByKey(add) \
#             .top(n, key=lambda c: c[1])
            .sortBy(lambda c: (-c[1], c[0])).take(n)
tmp
# Out:
# [('the', 6160209),
#  ('and', 4431354),
#  ('i', 3235332),
#  ('a', 3213701),
#  ('was', 2254455)]

# %%
results['E'] = [w for w,_ in tmp]
results['E']
# Out:
# ['the', 'and', 'i', 'a', 'was']

# %%
with open(output_file, 'w+') as o:
    json.dump(results, o)

# %% [markdown]
# ### Task2: Exploration on Multiple Datasets (4pts)

# %% [markdown]
# Task description: In task2, you will explore the two datasets together (i.e., review and business) and write a program to compute the average stars for each business category and output top n categories with the highest average stars. The business categories should be extracted from the “categories” tag in the business file. The categories should be split by comma and removed leading and trailing spaces. No other operations needed to process contents in the “categories” tag in the business file. Stars are extracted from the review dataset. Two datasets are joined by “business_id” tag. You need to implement a version without Spark (2pts) and a version with Spark (2pts). You could then compare their performance yourself (not graded).

# %%
# params = sys.argv
# input_file, business_file, output_file = params[1], params[2], params[3], 
# if_spark, n = params[4], int(params[5])

# %%
review_file = './review.json'
business_file = './business.json'
# output_file = ''
if_spark = 'spark'
n = 10

# %%
results = {}

# %% [markdown]
# ##### W/ Spark

# %%
if if_spark=='spark':
#     conf = SparkConf()
#     sc = SparkContext(conf=conf)
    sc = SparkContext.getOrCreate()
    
    review = sc.textFile(review_file).map(lambda r: json.loads(r))
    business = sc.textFile(business_file).map(lambda r: json.loads(r))

# %%
review_rdd = review.map(lambda r: (r['business_id'], r['stars']))
business_rdd = business.map(lambda b: (b['business_id'], b['categories']))

# %%
stars = review_rdd.groupByKey().mapValues(list).map(lambda bid: (bid[0], (sum(bid[1]), len(bid[1]))))

# %%
stars.take(2)
# Out:
# [('abaIvBrlg3QI4FUG1v3bdA', (4.0, 1)), ('M8a5DRdXl8KMu4bMFLPgQg', (85.0, 20))]

# %%
categories = business_rdd.filter(lambda ctg: ctg[1]!=None) \
                        .mapValues(lambda ctgs: [ctg.strip() for ctg in ctgs.split(',')])

# %%
categories.take(2)
# Out:
# [('1SWheh84yJXfytovILXOAQ', ['Golf', 'Active Life']),
#  ('QXAEGFB4oINsVuTFxEYKFQ',
#   ['Specialty Food',
#    'Restaurants',
#    'Dim Sum',
#    'Imported Food',
#    'Food',
#    'Chinese',
#    'Ethnic Food',
#    'Seafood'])]

# %%
aggregated = categories.leftOuterJoin(stars)

# %%
aggregated.take(2)
# Out:
# [('jZ23B--fu21is2zrWiy4Kg',
#   (['Pet Groomers', 'Pets', 'Pet Sitting', 'Pet Services'], (10.0, 2))),
#  ('2ffee6OI50skuFyEVmOBZQ',
#   (['Eyelash Service', 'Beauty & Spas', 'Skin Care'], (5.0, 1)))]

# %%
# tmp = aggregated.map(lambda id_c_s: id_c_s[1]).filter(lambda c_s: c_s[1]!=None) \
#                 .flatMap(lambda c_s: [(c, c_s[1]) for c in c_s[0]]) \
#                 .reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1])).mapValues(lambda s: s[0]/s[1]) \
#                 .top(n, key=lambda s:s[1])
# tmp

# %%
tmp = aggregated.map(lambda id_c_s: id_c_s[1]).filter(lambda c_s: c_s[1]!=None) \
                .flatMap(lambda c_s: [(c, c_s[1]) for c in c_s[0]]) \
                .reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1])).mapValues(lambda s: s[0]/s[1]) \
                .sortBy(lambda r: (-r[1], r[0])).take(n)
tmp
# Out:
# [('Astrologers', 5.0),
#  ('Audio/Visual Equipment Rental', 5.0),
#  ('Bocce Ball', 5.0),
#  ('Calabrian', 5.0),
#  ('Chinese Martial Arts', 5.0),
#  ('Christmas Markets', 5.0),
#  ('Crane Services', 5.0),
#  ('DIY Auto Shop', 5.0),
#  ('Duplication Services', 5.0),
#  ('Fireworks', 5.0)]

# %%
results['result'] = [[c_s[0], c_s[1]] for c_s in tmp]
results
# Out:
# {'result': [['Astrologers', 5.0],
#   ['Audio/Visual Equipment Rental', 5.0],
#   ['Bocce Ball', 5.0],
#   ['Calabrian', 5.0],
#   ['Chinese Martial Arts', 5.0],
#   ['Christmas Markets', 5.0],
#   ['Crane Services', 5.0],
#   ['DIY Auto Shop', 5.0],
#   ['Duplication Services', 5.0],
#   ['Fireworks', 5.0]]}

# %% [markdown]
# ##### W/O Spark

# %%
d = open(business_file, encoding="utf8").readlines()[1]
d
# Out:
# '{"business_id":"QXAEGFB4oINsVuTFxEYKFQ","name":"Emerald Chinese Restaurant","address":"30 Eglinton Avenue W","city":"Mississauga","state":"ON","postal_code":"L5R 3E7","latitude":43.6054989743,"longitude":-79.652288909,"stars":2.5,"review_count":128,"is_open":1,"attributes":{"RestaurantsReservations":"True","GoodForMeal":"{\'dessert\': False, \'latenight\': False, \'lunch\': True, \'dinner\': True, \'brunch\': False, \'breakfast\': False}","BusinessParking":"{\'garage\': False, \'street\': False, \'validated\': False, \'lot\': True, \'valet\': False}","Caters":"True","NoiseLevel":"u\'loud\'","RestaurantsTableService":"True","RestaurantsTakeOut":"True","RestaurantsPriceRange2":"2","OutdoorSeating":"False","BikeParking":"False","Ambience":"{\'romantic\': False, \'intimate\': False, \'classy\': False, \'hipster\': False, \'divey\': False, \'touristy\': False, \'trendy\': False, \'upscale\': False, \'casual\': True}","HasTV":"False","WiFi":"u\'no\'","GoodForKids":"True","Alcohol":"u\'full_bar\'","RestaurantsAttire":"u\'casual\'","RestaurantsGoodForGroups":"True","RestaurantsDelivery":"False"},"categories":"Specialty Food, Restaurants, Dim Sum, Imported Food, Food, Chinese, Ethnic Food, Seafood","hours":{"Monday":"9:0-0:0","Tuesday":"9:0-0:0","Wednesday":"9:0-0:0","Thursday":"9:0-0:0","Friday":"9:0-1:0","Saturday":"9:0-1:0","Sunday":"9:0-0:0"}}\n'

# %%
json.loads(d)['stars']
# Out:
# 2.5

# %%
def json_to_dict(file, keys):
    result = []
    data = open(file, encoding="utf8").readlines()
    for d in data:
        dictionary = {}
        for k in keys:
            dictionary[k] = json.loads(d)[k]
        result.append(dictionary)
                        
    return result

stars = json_to_dict(review_file, keys=['business_id', 'stars'])
categories = json_to_dict(business_file, keys=['business_id', 'categories'])
# categories

# %%
stars_agg = {}
for data in stars:
    bs_id, s = data['business_id'], data['stars']
    if bs_id not in stars_agg:
        stars_agg[bs_id] = [s, 1]
    else:
        stars_agg[bs_id][0] += s
        stars_agg[bs_id][1] += 1
stars_agg
# Out:
# {'mRUVMJkUGxrByzMQ2MuOpA': [39.0, 10],
#  'LUN6swQYa4xJKaM_UEUOEw': [130.0, 29],
#  'NyLYY8q1-H3hfsTwuwLPCg': [410.0, 91],
#  '6lj2BJ4tJeu7db5asGHQ4w': [50.0, 18],
#  'Mem13A3C202RzT53npn4NA': [50.0, 12],
#  'I4Nr-MVc26qWr08-S3Q1ow': [238.0, 58],
#  'Pq2kDojfCW8B6s1ABna6ug': [8.0, 2],
#  'JdZ1ltpUcjODBqkJzJ9ZLg': [30.0, 8],
#  'q_xY-2SYi-RJ38zJy36GUA': [46.0, 14],
#  'f_eiOrEcMnkHB7GvQVOHkQ': [551.0, 141],
#  'r48H_sNUGmcRGX1LsEc2mg': [26.0, 11],
#  'VGZ_MJ7P3vSQMYyQf-mNjw': [25.0, 9],
#  'FqOjyZyVpIloRpoipoM1qw': [4.0, 3],
#  'jItm9rWFREGUkHMJZRbbPg': [366.0, 104],
#  'cDugOhPR40gBk-DYNPYREA': [98.0, 23],
#  'oXFRaSgcT9GwCWfC9lf8dg': [67.0, 18],
#  'OfErL1qfNmgTF4375veOPA': [174.0, 37],
#  'AAfOST7l6YF44gIsQ21BDw': [7.0, 4],
#  ...}

# %%
categories[1]
# Out:
# {'business_id': 'QXAEGFB4oINsVuTFxEYKFQ',
#  'categories': 'Specialty Food, Restaurants, Dim Sum, Imported Food, Food, Chinese, Ethnic Food, Seafood'}

# %%
ctgr_agg = {}
for data in categories:
    bs_id, ctgrs = data['business_id'], data['categories']
    if ctgrs!=None:
        ctgr_agg[bs_id] = [ctgr.strip() for ctgr in ctgrs.split(',')]
ctgr_agg
# Out:
# {'1SWheh84yJXfytovILXOAQ': ['Golf', 'Active Life'],
#  'QXAEGFB4oINsVuTFxEYKFQ': ['Specialty Food',
#   'Restaurants',
#   'Dim Sum',
#   'Imported Food',
#   'Food',
#   'Chinese',
#   'Ethnic Food',
#   'Seafood'],
#  'gnKjwL_1w79qoiV3IC_xQQ': ['Sushi Bars', 'Restaurants', 'Japanese'],
#  'xvX2CttrVhyG2z1dFg_0xw': ['Insurance', 'Financial Services'],
#  'HhyxOkGAM07SRYtlQ4wMFQ': ['Plumbing',
#   'Shopping',
#   'Local Services',
#   'Home Services',
#   'Kitchen & Bath',
#   'Home & Garden',
#   'Water Heater Installation/Repair'],
#  '68dUKd8_8liJ7in4aWOSEA': ['Shipping Centers',
#   'Couriers & Delivery Services',
#   'Local Services',
#   'Printing Services'],
#  '5JucpCfHZltJh5r1JabjDg': ['Beauty & Spas', 'Hair Salons'],
#  'gbQN7vr_caG_A1ugSmGhWg': ['Hair Salons',
#   'Hair Stylists',
#   'Barbers',
#   "Men's Hair Salons",
#   'Cosmetics & Beauty Supply',
#   'Shopping',
#   'Beauty & Spas'],
#  'Y6iyemLX_oylRpnr38vgMA': ['Nail Salons', 'Beauty & Spas', 'Day Spas'],
#  '4GBVPIYRvzGh4K4TkRQ_rw': ['Beauty & Spas',
#   'Nail Salons',
#   'Day Spas',
#   'Massage'],
#  'fcXOEZdXYeZqnQ3lGlOXmg': ['Local Services',
#   'Professional Services',
#   'Computers',
#   'Shopping',
#   'Home Services',
#   'IT Services & Computer Repair',
#   'Internet Service Providers',
#   'Web Design'],
#  '1Dfx3zM-rW4n-31KeC8sJg': ['Restaurants',
#   'Breakfast & Brunch',
#   'Mexican',
#   'Tacos',
#   'Tex-Mex',
#   'Fast Food'],
#  '5t3KVdMnFgAYmSl1wYLhmA': ['Bars',
#   'Nightlife',
#   'Pubs',
#   'Barbers',
#   'Beauty & Spas',
#   'Irish Pub'],
#  'fweCYi8FmbJXHCqLnwuk8w': ['Italian',
#   'Restaurants',
#   'Pizza',
#   'Chicken Wings'],
#  '-K4gAv8_vjx8-2BxkVeRkA': ['Bakeries', 'Food'],
#  'A98xW4qb7vOTguggHFs7Ng': ['Fitness & Instruction', 'Active Life', 'Yoga'],
#  'giC3pVVFxCRR89rApqklyw': ['Hair Stylists',
#   'Beauty & Spas',
#   'Hair Salons',
#   "Men's Hair Salons"],
#  'PZ-LZzSlhSe9utkQYU8pFg': ['Restaurants', 'Italian'],
#  'nh_kQ16QAoXWwqZ05MPfBQ': ['Event Planning & Services',
#   'Photographers',
#   'Professional Services'],
#  'zSpQmEBvRe3IhTUlMSA6HQ': ['Trainers',
#   'Health & Medical',
#   'Active Life',
#   'Physical Therapy',
#   'Gyms',
#   'Fitness & Instruction'],
#  'dFMxzHygTy6F873843dHAA': ['Arcades', 'Arts & Entertainment'],
#  'lxnuq9wJiwLOPJ4uZU2ljg': ['Automotive', 'Car Dealers'],
#  'KWywu2tTEPWmR9JnBc0WyQ': ['Nightlife',
#   'Arts & Entertainment',
#   'Bars',
#   'Strip Clubs',
#   'Adult Entertainment',
#   'Dance Clubs'],
#  '1RHY4K3BD22FK7Cfftn8Mg': ['Sandwiches',
#   'Salad',
#   'Restaurants',
#   'Burgers',
#   'Comfort Food'],
#  'BsMdebN4nZySpGTfXr-7yg': ["Women's Clothing",
#   'Shopping',
#   'Accessories',
#   'Fashion',
#   'Shoe Stores'],
#  'tstimHoMcYbkSC4eBA1wEg': ['Mexican',
#   'Restaurants',
#   'Patisserie/Cake Shop',
#   'Food',
#   'Bars',
#   'Nightlife'],
#  'C9oCPomVP0mtKa8z99E3gg': ['Bakeries', 'Food'],
#  'C9keC4mWuXdl2mYFHZXudQ': ['Fashion',
#   'Sporting Goods',
#   "Men's Clothing",
#   'Shopping',
#   'Sports Wear'],
#  'iojTeSaoPuxm4WeCzDUA6w': ['Car Rental',
#   'Windshield Installation & Repair',
#   'Auto Detailing',
#   'Hotels & Travel',
#   'Automotive',
#   'Towing',
#   'Body Shops'],
#  'NDuUMJfrWk52RA-H-OtrpA': ['Juice Bars & Smoothies',
#   'Food',
#   'Restaurants',
#   'Fast Food',
#   'Vegan'],
#  'LB6ZyCfUzeX9OLdunHhnOQ': ['Shopping',
#   'Home & Garden',
#   'Department Stores',
#   "Men's Clothing",
#   'Fashion',
#   "Women's Clothing",
#   'Discount Store',
#   'Home Decor'],
#  'mNBp4KI2goFJKDB9VLGP9w': ['Automotive', 'Auto Repair'],
#  'SP_YXIEwkFPPl_9anCYmpQ': ['Restaurants',
#   'Nightlife',
#   'Breakfast & Brunch',
#   'Vegan',
#   'Food',
#   'Tapas Bars',
#   'Bars',
#   'Southern',
#   'Coffee & Tea'],
#  'irft4YkdNsww4DNf_Aftew': ['Juice Bars & Smoothies',
#   'Food',
#   'Ice Cream & Frozen Yogurt'],
#  'HVPcIcqiJkrpD36xZFGN6g': ['Home Services',
#   'Real Estate',
#   'Financial Services',
#   'Banks & Credit Unions',
#   'Mortgage Brokers'],
#  'BvYU3jvGd0TJ7IyZdfiN2Q': ['Sandwiches',
#   'Italian',
#   'American (Traditional)',
#   'American (New)',
#   'Seafood',
#   'Steakhouses',
#   'Restaurants'],
#  '0_ohldeFwysbglrTLSGM4Q': ['Beauty & Spas', 'Barbers'],
#  'M9DM1ktbW-TB7nXu3Z4RDw': ['Home Services',
#   'Real Estate',
#   'Apartments',
#   'Hotels & Travel',
#   'Vacation Rentals'],
#  'n2kOsDur7tCLygSa87glJQ': ['Medical Centers',
#   'Doctors',
#   'Obstetricians & Gynecologists',
#   'Health & Medical'],
#  'hgPhZoB3zdiRdlT9FETskw': ['Auto Glass Services',
#   'Auto Detailing',
#   'Automotive',
#   'Auto Parts & Supplies',
#   'Auto Customization',
#   'Vehicle Wraps'],
#  '-MsRvdPnuw6QuLn5Vxjruw': ['Shopping',
#   'Home Services',
#   'Interior Design',
#   'Rugs',
#   'Furniture Stores',
#   'Home & Garden',
#   'Home Decor',
#   'Mattresses'],
#  'FDI2PkyJBWEVFZ0ndHFg2g': ['Real Estate',
#   'Home Services',
#   'Mortgage Brokers',
#   'Real Estate Services'],
#  'Qwt9lOpplBAZ7JBrgAqI7g': ['Home Services', 'Real Estate', 'Apartments'],
#  'NBn4hgfGtNz91k3VsDZlmw': ['Local Services',
#   'Food Banks',
#   'Community Service/Non-Profit'],
#  'teknANRU8ZKnwdIHWYyd8Q': ['Massage Therapy',
#   'Massage',
#   'Health & Medical',
#   'Beauty & Spas'],
#  'e_EMySqP0uwlVZfd8mRaaQ': ['Chinese', 'Dim Sum', 'Restaurants'],
#  '-l45pZ9izx2mo5RzX2PwMw': ["Children's Clothing",
#   'Accessories',
#   'Used',
#   'Vintage & Consignment',
#   'Fashion',
#   "Women's Clothing",
#   'Shopping'],
#  'GWO87Y-IqL54_Ijx6hTYAQ': ['Food',
#   'Desserts',
#   'Juice Bars & Smoothies',
#   'Ice Cream & Frozen Yogurt'],
#  'Jff5hTK1ZMLKS06sOSNWdA': ['Hotels & Travel',
#   'Hotels',
#   'Event Planning & Services'],
#  '5ws3QWQXUhqTeLd7IZsDww': ['Health & Medical', 'Endodontists', 'Dentists'],
#  'mlHC2XcU9Bows6cnYEmRgg': ['Restaurants',
#   'Breakfast & Brunch',
#   'Bars',
#   'Modern European',
#   'Nightlife',
#   'Wine Bars'],
#  'Qnz3ywR7BosTr8qDk6G-Pw': ['Home & Garden',
#   'Mattresses',
#   'Home Decor',
#   'Furniture Stores',
#   'Shopping'],
#  'viivlh_KJkiDVxhIdZnV8Q': ['Arts & Entertainment',
#   'Dance Clubs',
#   'Nightlife',
#   'Music Venues'],
#  'q2KtxnPa6rPSpAlMbg9l8g': ['Desserts', 'Food', 'Cupcakes', 'Bakeries'],
#  'c-BELKj0SvNhBesQMf-bKw': ['Convenience Stores',
#   'Automotive',
#   'Food',
#   'Gas Stations',
#   'Grocery'],
#  'qWWBVE5T_zMEF7UJ4iTfNw': ['Home Services',
#   'Heating & Air Conditioning/HVAC'],
#  'YNvZdMLXa4q8e9tiE4ge4A': ['Health & Medical', 'Medical Centers'],
#  'cQ8FKduGfVskvi11NZXsAg': ['Parks', 'Active Life'],
#  '_J_x_RaYTqAqAuCwgRhnRQ': ['Coffee & Tea',
#   'Hookah Bars',
#   'Nightlife',
#   'Persian/Iranian',
#   'Country Dance Halls',
#   'Middle Eastern',
#   'Beer',
#   'Wine & Spirits',
#   'Bars',
#   'Restaurants',
#   'Food',
#   'Lounges',
#   'Delis'],
#  '0KlYc--jcw4EOYdPS8CDQg': ['Beauty & Spas',
#   'Hair Salons',
#   'Kids Hair Salons'],
#  'KSoAqqpLSUHMzpMDf46DMg': ['Shopping', 'Jewelry'],
#  '6l00a9Gkxkcp_y-GPjYBiw': ['Fish & Chips', 'Restaurants'],
#  'xu29IdQ4J9o5bffgoONwSA': ['Active Life', 'Golf'],
#  'jtzU8hk78718cNWM_dMcDg': ["Men's Clothing",
#   'Sporting Goods',
#   'Shopping',
#   'Fashion',
#   "Women's Clothing",
#   'Sports Wear'],
#  'a_TfmuLIHsRDyg7aVJQCBQ': ['Financial Services', 'Banks & Credit Unions'],
#  'qac28VmbQ7OrTMk-RCl7Yg': ['Beauty & Spas',
#   'Skin Care',
#   'Tanning Beds',
#   'Hair Salons',
#   'Tanning'],
#  'dQj5DLZjeDK3KFysh1SYOQ': ['Nightlife',
#   'Bars',
#   'Polish',
#   'Modern European',
#   'Restaurants',
#   'Vegan'],
#  'R3rss9fkfJxiOK6DueON3w': ['Shopping', "Women's Clothing", 'Fashion'],
#  'Y0dRlYjRNWckjvTGd55hzg': ['Caterers', 'Event Planning & Services'],
#  'kJbteCeQTiEB8Xdn9dA7rw': ['Tree Services',
#   'Landscape Architects',
#   'Home Services',
#   'Landscaping',
#   'Lawn Services'],
#  '5sFVttifV5ID8Gs0-iiAsA': ['Hair Loss Centers',
#   'Beauty & Spas',
#   'Hair Stylists',
#   'Hair Salons'],
#  '9UTpmQ4OhX5jNFUIu7dPPQ': ['Restaurants', 'Korean'],
#  'HYunM2pknhIh8lbiMa7THw': ['Interior Design',
#   'Contractors',
#   'Hardware Stores',
#   'Building Supplies',
#   'Home & Garden',
#   'Paint Stores',
#   'Home Services',
#   'Shopping',
#   'Painters'],
#  'v-scZMU6jhnmV955RSzGJw': ['Japanese', 'Sushi Bars', 'Restaurants'],
#  'gS-IoDQSggdxPn2Sf1yfGQ': ['General Dentistry',
#   'Health & Medical',
#   'Dentists'],
#  'kANF0dbeoW34s2vwh6Umfw': ['Fast Food',
#   'Food',
#   'Restaurants',
#   'Ice Cream & Frozen Yogurt'],
#  'D6ffAaTr_m5lsKxHNp9fwg': ['Eyebrow Services',
#   'Hair Salons',
#   'Day Spas',
#   'Nail Salons',
#   'Beauty & Spas'],
#  'KFbUQ-RR2UOV62Ep7WnXHw': ['American (Traditional)', 'Restaurants'],
#  '44YFU284Z3KDEy25QyVoUw': ['Chinese', 'Restaurants'],
#  'iXkqd9uNods7YnxrnBq_RA': ['Home Decor',
#   'Cosmetics & Beauty Supply',
#   'Health & Medical',
#   'Home & Garden',
#   'Herbal Shops',
#   'Beauty & Spas',
#   'Food',
#   'Nurseries & Gardening',
#   'Spiritual Shop',
#   'Shopping'],
#  'PkDghu4aan2_wxrhXjTEgg': ['Nightlife',
#   'Italian',
#   'Restaurants',
#   'Japanese',
#   'Lounges',
#   'Bars'],
#  'eXgDqKD7-sojyzh6q7PJ4g': ['Sandwiches',
#   'Desserts',
#   'Custom Cakes',
#   'Bakeries',
#   'Patisserie/Cake Shop',
#   'Cafes',
#   'Restaurants',
#   'Food',
#   'Breakfast & Brunch',
#   'Coffee & Tea'],
#  'i_oghUPqLzzJtxC6Zm-D2A': ['Canadian (New)', 'Portuguese', 'Restaurants'],
#  'RFbMVekR8lU9tPJ8sWrwHg': ['Italian', 'Restaurants'],
#  '735UkyT4px_oeW3iyotGmA': ['Parks', 'Active Life'],
#  'HHH_mrl-x694asUCs3SHeQ': ['General Dentistry',
#   'Dentists',
#   'Oral Surgeons',
#   'Cosmetic Dentists',
#   'Health & Medical',
#   'Orthodontists'],
#  '1gkJBdrkfdO7rEMml9e2KQ': ['Automotive', 'Auto Repair', 'Tires'],
#  'nkoie_y3fbaQGjZqFGqsrg': ['Home Services',
#   'Auto Glass Services',
#   'Windows Installation',
#   'Windshield Installation & Repair',
#   'Auto Parts & Supplies',
#   'Automotive'],
#  'HBQG_DT8pfbkv8jiv3P6Gw': ['Shopping', 'Discount Store'],
#  'DLaE25PS7bO9ar5rz-zRow': ['Beauty & Spas', 'Nail Salons'],
#  'iA6IwYzo6qDmY7dZfXdzyg': ['Health & Medical',
#   'Dentists',
#   'General Dentistry'],
#  'CJ4hyISN5qHyqMGHcydZFg': ['Medical Centers',
#   'Beauty & Spas',
#   'Naturopathic/Holistic',
#   'Weight Loss Centers',
#   'Doctors',
#   'Medical Spas',
#   'Health & Medical',
#   'Nutritionists'],
#  'SWX0K1dpy4fcRq-ktZxmCg': ['Landmarks & Historical Buildings',
#   'Mediterranean',
#   'Public Services & Government',
#   'Restaurants'],
#  'gas3YSrKkEcBliUHhnOLTg': ['Accessories',
#   'Shopping',
#   'Fashion',
#   'Jewelry',
#   'Leather Goods'],
#  '3d6ys6yvpF3svKa4HtUnoA': ['Professional Services', 'Life Coach'],
#  'BUdtUH9SkcitAf4JOOsa6A': ['Hospitals',
#   'Doctors',
#   'Rehabilitation Center',
#   'Medical Centers',
#   'Health & Medical'],
#  'NPHZkn1e-tSJAbo8Zm9rYw': ['Tex-Mex', 'Mexican', 'Restaurants'],
#  'smkZUv_IeYYj_BA6-Po7oQ': ['Bakeries',
#   'Food',
#   'Event Planning & Services',
#   'Desserts'],
#  'Cat1JuOOdv89E8Zck23smQ': ['Hair Stylists',
#   'Makeup Artists',
#   'Hair Salons',
#   'Permanent Makeup',
#   'Hair Extensions',
#   'Beauty & Spas'],
#  '1lp-Y6oaoI4BOPU3hyvIVQ': ['Property Management',
#   'Home Services',
#   'Real Estate'],
#  'f2ZWZPENViL92BrFsIgR6w': ['Beauty & Spas', 'Hair Salons'],
#  'YK5eFV8uS1bCmp8GeiQ-Qg': ['Food', 'Donuts'],
#  'cr5pOUYVlwIDflN_SZuGog': ['Doctors', 'Family Practice', 'Health & Medical'],
#  'sV6kKpzneWwQ8cY8gQ8bgA': ['Libraries',
#   'Educational Services',
#   'Education',
#   'Books',
#   'Mags',
#   'Music & Video',
#   'Shopping',
#   'Bookstores',
#   'Public Services & Government'],
#  'QHr_fc_TLnGfUEuDEa2jDg': ['Beer', 'Wine & Spirits', 'Food'],
#  'PL9xKgFL9FB8wDQ9AKrm4g': ['Cosmetics & Beauty Supply',
#   'Hair Stylists',
#   'Beauty & Spas',
#   'Shopping',
#   'Hair Salons'],
#  'OOnIQMkjg1VpAcPRFLnM0g': ['Shopping',
#   'Fashion',
#   'Home & Garden',
#   'Department Stores',
#   "Women's Clothing",
#   'Home Decor',
#   "Men's Clothing"],
#  'jtlAfuINMCYVFpjwMgy2jw': ['Grocery',
#   'Restaurants',
#   'Steakhouses',
#   'Butcher',
#   'Food'],
#  'pLMfv9jqRElSyJ9pcuFgdA': ['Banks & Credit Unions', 'Financial Services'],
#  '0-pC3IoaEK5gNVi2Sz6v7w': ['Nail Salons', 'Beauty & Spas'],
#  'KjicU7uxRt2KDEnO5cgxDQ': ['Shopping',
#   'Floral Designers',
#   'Event Planning & Services',
#   'Florists',
#   'Flowers & Gifts'],
#  'X8mtoSxY8whtmbDlj0D3Aw': ['Restaurants', 'Chinese'],
#  'JAiZVIzhwKgPjncWUedCNQ': ['Funeral Services & Cemeteries', 'Local Services'],
#  '7aLkFEBnL1LJmQdcuaovuQ': ['Restaurants',
#   'Pubs',
#   'Bars',
#   'Nightlife',
#   'American (Traditional)',
#   'Beer Gardens'],
#  '80hHlCEz_1-vgAhmLvs3lQ': ['Hair Stylists',
#   'Nail Technicians',
#   'Beauty & Spas',
#   'Makeup Artists',
#   'Nail Salons',
#   'Hair Salons'],
#  'qJeSjOMgWB3er3UXG33ZVw': ['American (Traditional)',
#   'Breakfast & Brunch',
#   'Restaurants',
#   'Burgers',
#   'Fast Food'],
#  'gyFYZV4b_9TxG1ulQNi0Ig': ['Middle Eastern',
#   'Restaurants',
#   'Salad',
#   'Breakfast & Brunch'],
#  'WyNlF7TMW7lNIta0jpWabw': ['Local Services', 'Bike Repair/Maintenance'],
#  'Yd7H9VvU4Euyguxwyrlfkw': ['Education',
#   'Paint & Sip',
#   'Arts & Crafts',
#   'Arts & Entertainment',
#   'Art Classes',
#   'Hobby Shops',
#   'Event Planning & Services',
#   'Party & Event Planning',
#   'Shopping',
#   'Venues & Event Spaces'],
#  'OezwOIJ0_62Mj8MLdkGRAw': ['Sandwiches',
#   'Cafes',
#   'Food',
#   'Restaurants',
#   'Coffee & Tea'],
#  '0lFAD4CuWcQVl9u3-lRaCQ': ['Pubs',
#   'Restaurants',
#   'Bars',
#   'Event Planning & Services',
#   'American (Traditional)',
#   'Nightlife',
#   'Lounges',
#   'Venues & Event Spaces',
#   'Sports Bars'],
#  'aql8K6zVoJDGRJ3P-IgtpQ': ['Sushi Bars', 'Restaurants'],
#  '0PVrf9UoZBR5lEjee893Wg': ['Nightlife', 'Comedy Clubs'],
#  'VaNjd3jir0MKntCFya70uA': ['Graphic Design',
#   'Printing Services',
#   'Web Design',
#   'Local Services',
#   'Professional Services'],
#  'wUsjANxpknTpsaTjYoo9iA': ['Beauty & Spas', 'Nail Salons'],
#  'Kxbn0XLcCgQqmkdIkhuOeQ': ['Desserts',
#   'Ice Cream & Frozen Yogurt',
#   'Food',
#   'Restaurants',
#   'Vegan'],
#  'MvKj4_etnStgYRnXOwFSPw': ['Community Service/Non-Profit', 'Local Services'],
#  'iedsG4rv8SYY22kGUVDjaw': ['Chiropractors', 'Health & Medical'],
#  'sKhDrZFCJqfRNylkHrIDsQ': ['Food', 'Coffee & Tea'],
#  'N2G7ySm6R-jYrHvDAV2Ndw': ['Hotels',
#   'Event Planning & Services',
#   'Hotels & Travel',
#   'Venues & Event Spaces'],
#  'DwsESfIDIsgQ4DTx9VNOsw': ['Home Services',
#   'Handyman',
#   'Painters',
#   'Contractors'],
#  'faixHjogPjNUo07T0RBRFw': ['Security Systems', 'Home Services'],
#  '3aUBEB206LBNLUY6rCW2sw': ['Traditional Chinese Medicine',
#   'Health & Medical',
#   'Acupuncture'],
#  'ysfeDcLAYk_MVzfBmyiSTg': ['Restaurants', 'Food', 'Cafes'],
#  'fn6ySvSF79V3s-f6xnPVRw': ['Accessories',
#   'Fashion',
#   "Women's Clothing",
#   'Plus Size Fashion',
#   'Shopping'],
#  'bJP4l_BGq2CudEu0m-wNjg': ['Restaurants',
#   'Pizza',
#   'Italian',
#   'American (New)'],
#  'MbGUIsOkVeKrwH3_RcGqng': ['Heating & Air Conditioning/HVAC',
#   'Contractors',
#   'Home Services'],
#  'Q1GhjqlLENaT383k9Ex5wg': ['Donuts',
#   'Coffee & Tea',
#   'Juice Bars & Smoothies',
#   'Food'],
#  'xYGb7EAEIbrLamlpaUPmJA': ['Jewelry Repair',
#   'Jewelry',
#   'Watches',
#   'Shopping',
#   'Local Services'],
#  '1HRSElW1HgBiTtSNrhjMeA': ['Restaurants', 'Vietnamese'],
#  'r8764MtYyt8JhxMvrfM_xQ': ['American (New)',
#   'Bars',
#   'Wine Bars',
#   'Nightlife',
#   'Restaurants'],
#  'L0aSDVHNXCl6sY4cfZQ-5Q': ['Restaurants', 'Thai'],
#  'qhkfFrB7IA9AlT-cSl2NSQ': ['Doctors',
#   'Diagnostic Services',
#   'Health & Medical',
#   'Diagnostic Imaging',
#   'Radiologists'],
#  'mruax-1iDdb8GlAKwLy8JQ': ['Airports',
#   'Hotels',
#   'Event Planning & Services',
#   'Hotels & Travel',
#   'Venues & Event Spaces'],
#  'la2-RM1eWKmb0kFYwZVr_Q': ['Auto Detailing',
#   'Car Wash',
#   'Body Shops',
#   'Automotive',
#   'Auto Repair',
#   'Auto Glass Services'],
#  'LcIHB4sWUKTnpBtvVx_W5A': ['Taxis',
#   'Limos',
#   'Transportation',
#   'Airport Shuttles',
#   'Hotels & Travel'],
#  'voZnDQs6Hs3YpNcS-9TALg': ['Restaurants', 'Mexican'],
#  't-6tdxRaz7s9a0sf94Tguw': ['Restaurants', 'Caribbean'],
#  'QaXU3XeFaWwJ1_E1A3_3uw': ['Art Galleries',
#   'Used',
#   'Vintage & Consignment',
#   'Shopping',
#   'Furniture Stores',
#   'Home & Garden',
#   'Home Decor',
#   'Arts & Entertainment',
#   'Fashion'],
#  'WlArCYe6xCzOe5u2Lt1how': ['Pizza',
#   'Caterers',
#   'Restaurants',
#   'Event Planning & Services'],
#  'S-ib-0USQYqj8WsOjiuVtw': ['Local Services',
#   'Education',
#   'Child Care & Day Care',
#   'Preschools'],
#  'TOJuL1S42GOdkv5Y2am1mw': ['Lawyers',
#   'Divorce & Family Law',
#   'Personal Injury Law',
#   'Professional Services'],
#  'RcQCseZjTj9_FFRrixkLdw': ['Painters',
#   'Home Services',
#   'Roofing',
#   'Handyman'],
#  'rHKC8TjQP_u6k3uwEkdCsQ': ['Dentists',
#   'General Dentistry',
#   'Endodontists',
#   'Cosmetic Dentists',
#   'Health & Medical'],
#  '7_nq0GqNvc5CT0A3tVCpcg': ['Shopping',
#   'Eyewear & Opticians',
#   'Health & Medical',
#   'Optometrists'],
#  'xXdRivb3LjGCl8HiuUa22g': ['Insurance', 'Financial Services'],
#  'jScBTQtdAt-8RshaiBEHgw': ['Ethnic Food',
#   'American (New)',
#   'Burgers',
#   'Food',
#   'Restaurants',
#   'Asian Fusion',
#   'Specialty Food',
#   'Mexican',
#   'Sandwiches',
#   'Breakfast & Brunch',
#   'Korean'],
#  'U3kygJOTlTQFlfaZS7sQjA': ['Caterers',
#   'Hot Dogs',
#   'Restaurants',
#   'Vegetarian',
#   'American (Traditional)',
#   'Event Planning & Services'],
#  'Ik-vXB7HCwnC44KDf_nwdw': ['Automotive', 'Auto Repair'],
#  'c35qzLN6ItDpVIoj2uQW4Q': ['Soup', 'Restaurants', 'Sandwiches'],
#  'wOS6masGoY5JszRAF3goLQ': ['Antiques',
#   'Shopping',
#   'Local Services',
#   'Thrift Stores',
#   'Community Service/Non-Profit'],
#  'yZUBzm3J8lxJwKNMtWU0Mw': ['Health & Medical',
#   'Internal Medicine',
#   'Doctors'],
#  'nsNONDHbV7Vudqh21uicqw': ['Seafood', 'Restaurants'],
#  'jwHtNvHBPafiAwM92jM8yA': ['Restaurants', 'Pizza'],
#  'DTyxXf17YCcfjoa08LyS4g': ['Kitchen & Bath',
#   'Shopping',
#   'Home & Garden',
#   'Painters',
#   'Contractors',
#   'Flooring',
#   'Cabinetry',
#   'Home Services',
#   'Home Decor',
#   'Interior Design'],
#  'kGal388xLnmCwI4mw2TG8Q': ['Food', 'Grocery', 'Convenience Stores'],
#  'SvUvVEr9cTjS-PJQ9MuckQ': ['Restaurants',
#   'Breakfast & Brunch',
#   'Sandwiches',
#   'Food',
#   'Coffee & Tea'],
#  'YAbKZJxEtdHCWrJYj2uR3w': ['Arts & Entertainment',
#   'Employment Agencies',
#   'Talent Agencies',
#   'Performing Arts',
#   'Professional Services'],
#  'BKtkkcAf_sa6Kk99VIDnog': ['Sewing & Alterations',
#   'Local Services',
#   'Fashion',
#   'Bridal',
#   'Clothing Rental',
#   'Formal Wear',
#   'Shopping'],
#  'RZ48zp2J2SWUy-lZ4PHZrw': ['Meat Shops', 'Food', 'Specialty Food'],
#  'cz5kBEZMHKyJ_nZXn-IRIA': ['General Dentistry',
#   'Oral Surgeons',
#   'Dentists',
#   'Health & Medical'],
#  'M_jPgrNm1BrIXWokvvxpOQ': ['Veterinarians', 'Pets'],
#  'IgQ8lSds3AgLFQsYsshUHQ': ['Restaurants',
#   'Mexican',
#   'Ethnic Food',
#   'Specialty Food',
#   'Food'],
#  'v7ZFEEqJBg_r8NCwHRP_2A': ['Food',
#   'Pizza',
#   'Wine Bars',
#   'Bars',
#   'Restaurants',
#   'Nightlife'],
#  '6fPQJq4f_yiq1NHn0fd11Q': ['French', 'Restaurants', 'Creperies'],
#  'sAX1q1kLvOnXKURq_MP_Wg': ['Bookstores',
#   'Books',
#   'Mags',
#   'Music & Video',
#   'Shopping',
#   'Newspapers & Magazines'],
#  'k-dDZvTeLysoJvjHI-qr9g': ['Buffets', 'Restaurants'],
#  '5WMIvoMx3l1vn1uJ3HZB6Q': ['Fast Food', 'Sandwiches', 'Restaurants'],
#  'T_tnCsUQmqTMEI3XxJAyOA': ['Restaurants',
#   'Beer Gardens',
#   'Nightlife',
#   'Burgers'],
#  '2JcGcLMzP_TXTRvhCotYZA': ['IT Services & Computer Repair',
#   'Local Services',
#   'Shopping',
#   'Professional Services',
#   'Computers',
#   'Video/Film Production'],
#  'spi9UEWyNrq2O4y5DD84LA': ['Vietnamese', 'Restaurants', 'Soup'],
#  'Rs8Wi4OEjeOX7LVlzsXDOA': ['Restaurants', 'Mexican', 'Sushi Bars'],
#  'zgjeunqPvj_423xkGtiFjw': ['Medical Centers',
#   'Health & Medical',
#   'Walk-in Clinics',
#   'Urgent Care'],
#  'vzo659ogST1F_Vj9aTXLUg': ['Business Consulting',
#   'Financial Services',
#   'Professional Services'],
#  '_FrJLtITs2p8SeOJdSpsQQ': ['Eyewear & Opticians', 'Shopping'],
#  'SJBzyJDCR_f6dx5tpYAABA': ['Sushi Bars', 'Japanese', 'Restaurants'],
#  'b9R3msDsU2cC6WKBm68tzQ': ['Eyelash Service',
#   'Hair Removal',
#   'Eyebrow Services',
#   'Beauty & Spas'],
#  'MhnihE0alud0ereVInSt8Q': ['Chinese', 'Restaurants'],
#  'i6hWP3si97eKQl_JyK8L3w': ['Hotels',
#   'Event Planning & Services',
#   'Hotels & Travel'],
#  'wht5FaGi7r86WKW7-VX2lQ': ['Food', 'Specialty Food', 'Health Markets'],
#  '111d13yLgIdqvpZekgVnbQ': ['Restaurants',
#   'Caterers',
#   'Italian',
#   'Event Planning & Services'],
#  'EXr-oKAbgON2bYNinu6cyQ': ['Auto Customization',
#   'Auto Parts & Supplies',
#   'Auto Glass Services',
#   'Auto Repair',
#   'Automotive',
#   'Body Shops'],
#  'zTIna6imZC9Ij5JWgHL9jw': ['Hair Salons', 'Hair Stylists', 'Beauty & Spas'],
#  'kvM34AeKBJoQn3FJfGXWhw': ['Education',
#   'Specialty Schools',
#   'Cooking Schools'],
#  'cBQDYO0dIpG6--I3DMiWoQ': ['Hair Removal',
#   'Beauty & Spas',
#   'Shopping',
#   'Laser Hair Removal',
#   'Cosmetics & Beauty Supply'],
#  '1Oa6PpE1MYDT8OLRm8SBig': ['Body Shops', 'Automotive', 'Auto Repair'],
#  '6aOnrzf15RMqFNOQ-_ElIA': ['Chocolatiers & Shops',
#   'Specialty Food',
#   'Ice Cream & Frozen Yogurt',
#   'Desserts',
#   'Food'],
#  'FDEm-c3NAXnTVtl-hgzAhA': ['Burgers', 'Restaurants'],
#  '4n81G-pmC3rfhmaPsbwYKg': ['Bars',
#   'Sports Bars',
#   'Nightlife',
#   'Beer',
#   'Wine & Spirits',
#   'Restaurants',
#   'Food',
#   'American (Traditional)'],
#  'o5TylXKBuAK6cOIWQm3S2g': ['Automotive',
#   'Windshield Installation & Repair',
#   'Car Window Tinting',
#   'Auto Glass Services'],
#  'y-1sMhUMubrHWdIW4FaE8w': ['Fast Food',
#   'Sandwiches',
#   'Restaurants',
#   'Burgers'],
#  'Fw9BOyUhk5Ldslh0taa7kg': ['Automotive',
#   'Auto Repair',
#   'Tires',
#   'Auto Parts & Supplies'],
#  'RGvf3iTT3NUD1GvjzgNfLw': ['Venues & Event Spaces',
#   'Event Planning & Services'],
#  'pSdi9Z4QkKBN6aWwFnLC0A': ['Pet Sitting',
#   'Pet Groomers',
#   'Veterinarians',
#   'Pet Services',
#   'Pets'],
#  'v8zKjH1o_qAI4SBd3na7gg': ['Restaurants', 'Canadian (New)'],
#  'Q_jcNwx1MiN8SceiSMweNQ': ['Automotive', 'Car Wash'],
#  'PWjgwphd2prhtqTPWwLbXw': ['Sandwiches',
#   'Restaurants',
#   'Delis',
#   'Desserts',
#   'Food'],
#  'aGdyRoDCn6Z9_j2vIvnKNw': ['Breakfast & Brunch',
#   'Diners',
#   'Restaurants',
#   'Coffee & Tea',
#   'Food'],
#  'rVBPQdeayMYht4Uv_FOLHg': ['Burgers', 'Food', 'Restaurants'],
#  'qUraZNprg0Vk4PmjaPQREQ': ['Auto Repair',
#   'Car Dealers',
#   'Body Shops',
#   'Automotive'],
#  'W7QOR9r7mm6ak3DURkSwxg': ['Hotels',
#   'Hotels & Travel',
#   'Event Planning & Services'],
#  'jdJwziOX5FB2C2D-vESY0Q': ['Professional Services',
#   'Cosmetics & Beauty Supply',
#   'Hair Salons',
#   'Nail Salons',
#   'Hair Stylists',
#   'Beauty & Spas',
#   'Shopping',
#   'Hair Extensions',
#   'Blow Dry/Out Services',
#   'Barbers'],
#  '99KKeZYRPnz7qDi5USsHmw': ['Hotels & Travel', 'Tours'],
#  '7yY0XAmi0TEDFvvDdG4y-A': ['Garage Door Services', 'Home Services'],
#  'eY98EH_PHGnJVaJ7t2UpoQ': ['Middle Eastern',
#   'Restaurants',
#   'Vegetarian',
#   'Juice Bars & Smoothies',
#   'Ethnic Food',
#   'Salad',
#   'Food',
#   'Sandwiches',
#   'Specialty Food'],
#  'n812L7Mz4104bQ5Goo7yQg': ['Golf', 'Active Life'],
#  'iwGhazq9eP51PSerTrMrwg': ['Dive Bars',
#   'Food',
#   'Bars',
#   'Pubs',
#   'Restaurants',
#   'Nightlife',
#   'American (Traditional)',
#   'Beer',
#   'Wine & Spirits'],
#  'CPgz4srKkE5u9aoBAOaQsA': ['Chicken Wings', 'Pizza', 'Salad', 'Restaurants'],
#  'XqzOzjezod88Fgf16AWplA': ['Health & Medical',
#   'Eyewear & Opticians',
#   'Optometrists',
#   'Shopping'],
#  'qNChnVaoWDS-RFd9NDBPEA': ['Tires',
#   'Wheel & Rim Repair',
#   'Automotive',
#   'Auto Glass Services',
#   'Car Wash'],
#  'uZuh51lXu7tsrC8RAwkg1A': ['Shoe Stores', 'Fashion', 'Shopping'],
#  'cUesIMddiBM--8q5KxXu5w': ["Children's Clothing",
#   'Shoe Stores',
#   'Accessories',
#   'Fashion',
#   'Shopping'],
#  'w7N_q76R_DydNqK1zvHmBw': ['Home Services', 'Apartments', 'Real Estate'],
#  'cmcUx0yiIiuVRUhjb0kGXw': ['Arts & Crafts',
#   'Costumes',
#   'Fashion',
#   'Formal Wear',
#   'Used',
#   'Vintage & Consignment',
#   'Antiques',
#   'Shopping'],
#  'd9ftOq9cPFsicPSasP-IRw': ['Restaurants', 'Burgers'],
#  'CsLQLiRoafpJPJSkNX2h5Q': ['Food',
#   'Grocery',
#   'Restaurants',
#   'Middle Eastern'],
#  'OwXMxqxIy4YoprAjnoUoiA': ['Barbeque', 'Restaurants'],
#  'jqOwxL3g8ZIagujompYALw': ['Barbers',
#   'Beauty & Spas',
#   'Hair Salons',
#   'Tattoo'],
#  'Sd75ucXKoZUM2BEfBHFUOg': ['Chinese', 'Restaurants'],
#  'VA232TY-ThR8L5wjuuLZVg': ['Mediterranean',
#   'Restaurants',
#   'Middle Eastern',
#   'Turkish'],
#  'Sr9y814fYmbjp9Jn0bVz9A': ['Car Dealers', 'Automotive', 'Used Car Dealers'],
#  'rJRMmiyR8AynlUwSzOF0Kg': ['Accountants',
#   'Professional Services',
#   'Financial Services',
#   'Tax Services'],
#  'X9s0hWVFKB7zCxc5jMgYag': ['Chiropractors',
#   'Doctors',
#   'Pain Management',
#   'Health & Medical'],
#  '_T0c2ASP6N8zUIEKV-k6mg': ['Beauty & Spas', 'Nail Salons'],
#  'BpmstSasmYdEGFfnCZE-CQ': ['Automotive',
#   'Oil Change Stations',
#   'Tires',
#   'Auto Repair'],
#  'Ia6G7YSAXi8twqvUJDcoHg': ['Shopping',
#   'Fashion',
#   "Women's Clothing",
#   'Accessories'],
#  'NqpX1HsFVGwmnxnw_bcEuA': ['Restaurants', 'American (Traditional)'],
#  'sHuBPTQuQ3tOxEcUT5JYVw': ['Golf', 'Active Life'],
#  'NX88XnZQOVbaSVj1exilLA': ['Specialty Food', 'Food', 'Herbs & Spices'],
#  'Br5-7y1Niq6quMvfSmlFow': ['Automotive', 'Auto Repair', 'Tires', 'Towing'],
#  '0G83H_zoum-Q4bWU2olTqQ': ['Restaurants',
#   'Food',
#   'Delis',
#   'Desserts',
#   'Bakeries',
#   'Coffee & Tea'],
#  '-ucQnELMVRIUOi3-Kv5r0Q': ['Motorcycle Repair',
#   'Motorcycle Rental',
#   'Motorcycle Dealers',
#   'Automotive',
#   'Hotels & Travel'],
#  'ldJfWnId1V2cSt4_-uPUXA': ['Fashion', 'Shopping', 'Department Stores'],
#  'U3-kxz7NWq4ix4bPmKKQ0w': ['Ethnic Food',
#   'Specialty Food',
#   'Food',
#   'Restaurants',
#   'Vegetarian',
#   'Mediterranean',
#   'Middle Eastern'],
#  '18gN_BCI-vS8JHAtDN9Ztg': ['Shopping',
#   'Local Services',
#   'Jewelry',
#   'Jewelry Repair'],
#  '55hh7ytRsWTEPC-66KJqGw': ['Shopping',
#   'Home & Garden',
#   'Furniture Stores',
#   'Mattresses'],
#  '0YkNypUMDoIklcgoGYioMg': ['Florists',
#   'Flowers & Gifts',
#   'Baby Gear & Furniture',
#   'Home & Garden',
#   'Shopping'],
#  'z3csSfd-UBMP1Gk6zHY_AA': ['Bars',
#   'Pubs',
#   'Gastropubs',
#   'Nightlife',
#   'Restaurants',
#   'Canadian (New)'],
#  '3E0JDI0XMUoFztoEmX2D7w': ['Nightlife', 'Bars'],
#  'IjGU7ZopsgeomsDQf20UXQ': ['Grocery', 'Food', 'Specialty Food'],
#  'B7a5Gknl7QAYKLCV33w6IQ': ['Financial Services',
#   'Real Estate',
#   'Investing',
#   'Home Services',
#   'Mortgage Brokers',
#   'Banks & Credit Unions'],
#  'a7zF4dDTeswXZGmohBDbJw': ['Arts & Entertainment',
#   'Music Venues',
#   'Nightlife',
#   'Bars'],
#  'tMwX4n8o4xh5hN0FWKIJ4g': ['Landscape Architects',
#   'Nurseries & Gardening',
#   'Home & Garden',
#   'Shopping',
#   'Home Services'],
#  'YOhtdvjmveAtsblep0CQrg': ['Fitness & Instruction',
#   'Yoga',
#   'Education',
#   'Active Life',
#   'Specialty Schools'],
#  'TTVwcuc1Nz4ZSZH4wnbxKQ': ['Sandwiches', 'Restaurants', 'Pizza', 'Salad'],
#  'IeSExZRuxGhBYbZvLk0Srw': ['Beauty & Spas', 'Nail Salons'],
#  'sRLczTc6OHuttVSanRfHaw': ['Restaurants', 'Burgers', 'Fast Food'],
#  'CU047MuCn7u-9UGA2-xhmA': ['Art Galleries',
#   'Shopping',
#   'Arts & Entertainment',
#   'Museums',
#   'Art Museums'],
#  '4Rp1y8L_zecjHt6AvKtekg': ['Cajun/Creole', 'Restaurants'],
#  '9FPEg18SyYsKgbWZ0XDysQ': ['Food', 'Ice Cream & Frozen Yogurt'],
#  'tWjfgVtTD5n01Cq9dFWGsA': ['Italian',
#   'Canadian (New)',
#   'Food',
#   'American (New)',
#   'Restaurants'],
#  'ET2dIIR1qMThKyBEOL5BkA': ['Hiking', 'Active Life'],
#  'lrYB3RSnr8OVrrqHhGMwPA': ['Specialty Food',
#   'Imported Food',
#   'Ethnic Food',
#   'Food'],
#  'CxRBRrtd7NHz890gWPG9AA': ['Italian',
#   'Restaurants',
#   'Event Planning & Services',
#   'Caterers'],
#  'jZ23B--fu21is2zrWiy4Kg': ['Pet Groomers',
#   'Pets',
#   'Pet Sitting',
#   'Pet Services'],
#  '2ffee6OI50skuFyEVmOBZQ': ['Eyelash Service', 'Beauty & Spas', 'Skin Care'],
#  'g9mFgdWF5ZnvY0TqaTYKmA': ['Auto Repair',
#   'Auto Detailing',
#   'Body Shops',
#   'Automotive',
#   'Windshield Installation & Repair',
#   'Auto Glass Services'],
#  'AxQpXcQvCnmCV0dai8I3ew': ['Beauty & Spas',
#   'Hair Extensions',
#   'Tanning',
#   'Hair Salons',
#   'Eyelash Service'],
#  'W3VBN9rTCG0iyAZSafKZ3w': ['Desserts',
#   'Food',
#   'Chocolatiers & Shops',
#   'Specialty Food'],
#  '0dZgKUc-8Hc8LQSJ80C8Cg': ['Dentists',
#   'Cosmetic Dentists',
#   'Oral Surgeons',
#   'General Dentistry',
#   'Health & Medical'],
#  '3kwigsDDg6DjYtKiqMr7mw': ['Plumbing', 'Home Services'],
#  'KiE81YHZCEdPPlmrXghgzA': ['Beauty & Spas', 'Nail Salons'],
#  'dUffgo9Lh_Vk9TLuFR5ywg': ['Restaurants', 'Pizza', 'Sandwiches', 'Italian'],
#  'XNjxFMYAN1HgcmZREefrGw': ['Event Planning & Services',
#   'Party & Event Planning',
#   'Arts & Entertainment',
#   'Party Equipment Rentals',
#   'Casinos'],
#  'P5ISHdbAHe_IZ_FvxDItWw': ['Bike Rentals',
#   'Active Life',
#   'Bikes',
#   'Sports Wear',
#   'Fashion',
#   'Shopping',
#   'Outdoor Gear',
#   'Ski & Snowboard Shops',
#   'Sporting Goods'],
#  'c7JoAt6a3Ufkpn3TrGU23A': ['Mexican', 'Restaurants'],
#  'NAb3h3qC-12q5sjOzvIDHg': ['Coffee & Tea', 'Food'],
#  'ZpjAltpV8mq-HGqsipocsA': ['Restaurants',
#   'American (Traditional)',
#   'Moroccan'],
#  'k5U4UF1ySD9NpYLwetXzVA': ['Heating & Air Conditioning/HVAC',
#   'Home Services'],
#  '_w7P2DhkrgmAWGHXRXTe8g': ['Apartments', 'Real Estate', 'Home Services'],
#  'N1a_o-SGOWf2kdY2uRSs8g': ['Pubs', 'Bars', 'Nightlife'],
#  'JQbAksVl1luNa83C6-5xmw': ['Medical Spas',
#   'Day Spas',
#   'Sugaring',
#   'Health & Medical',
#   'Hair Removal',
#   'Skin Care',
#   'Beauty & Spas'],
#  'b9SMb3ka6MQ5UsCvcLXT6w': ["Women's Clothing",
#   'Plus Size Fashion',
#   'Accessories',
#   'Fashion',
#   'Shopping',
#   "Men's Clothing"],
#  'fFKbj19pBWMQosCn9qsTdw': ['Beauty & Spas', 'Hair Salons'],
#  'AXq8uPxqBP-c5PCrnba-4A': ['Mexican', 'Restaurants'],
#  'q4P3WHwC0lFafwvTlkKMIw': ['Restaurants', 'Pizza'],
#  '1-ArjtGW6PytvR1NEWpXqg': ['Beauty & Spas',
#   'Wedding Planning',
#   'Event Planning & Services',
#   'Makeup Artists',
#   'Professional Services',
#   'Video/Film Production'],
#  '_pBXtjN43eqMV0XZTz7nmw': ['Music Venues',
#   'Dance Clubs',
#   'Arts & Entertainment',
#   'Nightlife'],
#  'tsXCDIijxbgsh980VgRc9g': ['Movers',
#   'Local Services',
#   'Self Storage',
#   'Home Services'],
#  'K8O1xlF9pWkHLVXhC1CQFg': ['Health & Medical',
#   'Massage Therapy',
#   'Physical Therapy',
#   'Chiropractors'],
#  'v-sFF0zhcCB7Afhem1tMWw': ['Fences & Gates', 'Contractors', 'Home Services'],
#  'oNbkFvGTErw_ue_3_Mwcng': ['Home Services',
#   'Heating & Air Conditioning/HVAC'],
#  'iyPtSR0s6EkvaQFbdJ_jVA': ['Dim Sum',
#   'Chinese',
#   'Tapas/Small Plates',
#   'Restaurants'],
#  'hZj2HCiLae5-AxIp0im6lQ': ['Bars',
#   'Nightlife',
#   'Restaurants',
#   'American (Traditional)'],
#  'vwntGW400t5WG0ubjuaz5g': ['Barbeque', 'Restaurants'],
#  'KqouzJ7_jh9tRQnSmEde5g': ['Doctors', 'Family Practice', 'Health & Medical'],
#  'Hj8gh-0IH739-ZhqUQn_Lg': ['Breakfast & Brunch',
#   'Restaurants',
#   'Canadian (New)',
#   'Diners'],
#  'vg4ynLZ0yJ89pT4s_CEMzQ': ['Fast Food', 'Restaurants', 'Burgers', 'Food'],
#  'bsagBzOdt-JmeuSengyUWA': ['Handyman',
#   'Professional Services',
#   'Electricians',
#   'Contractors',
#   'Home Services'],
#  'XWa7nXOddOYKxojywngk8w': ['American (Traditional)',
#   'Gluten-Free',
#   'Restaurants',
#   'Food Delivery Services',
#   'American (New)',
#   'Weight Loss Centers',
#   'Health & Medical',
#   'Nutritionists',
#   'Food'],
#  'ViZL5Ycz-ua5uH5ojMY4jw': ['Professional Services',
#   'Graphic Design',
#   'Web Design'],
#  'e-9f6vasnWh3z0uOq287Aw': ['Restaurants',
#   'Italian',
#   'Pizza',
#   'Fast Food',
#   'Chicken Wings'],
#  'AwHI7IzBQz8gWV5Yht_boQ': ['Professional Services',
#   'Home Services',
#   'Financial Services',
#   'Real Estate Services',
#   'Insurance',
#   'Real Estate'],
#  'X2wGtV-oDtzVSva7hCBDDw': ['Battery Stores',
#   'Auto Parts & Supplies',
#   'Automotive',
#   'Auto Repair',
#   'Shopping'],
#  'pUihHVilZtpZz4FApnOvtA': ['Restaurants', 'Middle Eastern'],
#  'ripszTzwIaQxa0ySLOhV_g': ['Local Services', 'Appliances & Repair'],
#  'Qb4sJ4ssSX1clY2wEAOmsA': ['Food',
#   'Specialty Food',
#   'Beer',
#   'Wine & Spirits',
#   'Shopping',
#   'Flowers & Gifts',
#   'Florists',
#   'Grocery'],
#  '_72dMXdWbVAgwB-Bxwz-mw': ['Chinese', 'Restaurants'],
#  'LF66oShCh30k5NOV6pPJTQ': ['Coffee & Tea',
#   'Cafes',
#   'Restaurants',
#   'Bakeries',
#   'Juice Bars & Smoothies',
#   'Local Flavor',
#   'Food'],
#  'XQ9mowss1Bn87EQxgpceOg': ['Nail Salons', 'Beauty & Spas'],
#  '9uhXxFrTR58KVD5fq1ua3Q': ['Restaurants',
#   'Burgers',
#   'Poutineries',
#   'Canadian (New)'],
#  'MIVd5fL1iiDoSTJZQBNmzg': ['Laboratory Testing',
#   'Doctors',
#   'Diagnostic Services',
#   'Urgent Care',
#   'Medical Centers',
#   'Health & Medical'],
#  'H4oxmmF-QCFYwWZGE6rbhg': ['Chimney Sweeps',
#   'Fireplace Services',
#   'Home Services',
#   'Masonry/Concrete'],
#  'pNnHgna1cCjUEZyXRUc6oA': ['Home Services', 'Cabinetry'],
#  'ebDtlHODMCNmV1PrdNXKnA': ['Nightlife',
#   'Bars',
#   'American (New)',
#   'Restaurants',
#   'American (Traditional)'],
#  'oUi5Dhv7_6OgHKAsZMyojQ': ['Home Services', 'Home Cleaning'],
#  '1sVIau1rvgec3ul6g7EJag': ['Mobile Phones', 'Shopping'],
#  'bLwLZLo9aw0qRNeEPXGpEA': ['Nail Salons',
#   'Hair Extensions',
#   'Beauty & Spas',
#   'Eyelash Service',
#   "Men's Hair Salons",
#   'Hair Salons'],
#  'sohYJdSBaNhTPPqOOFc9QA': ['Food',
#   'Internet Cafes',
#   'Arts & Entertainment',
#   'Computers',
#   'Shopping',
#   'LAN Centers',
#   'Arcades'],
#  '0Xrlx6TzEKqxzz-82AABuQ': ['Laboratory Testing',
#   'Diagnostic Services',
#   'Health & Medical'],
#  'TWa07Bllw_jfI2Y2Lry9DQ': ['Sandwiches', 'Restaurants', 'Barbeque', 'Salad'],
#  'OX0GbUgiv1733Eeu7HqW9A': ['Bird Shops',
#   'Pets',
#   'Home Decor',
#   'Toy Stores',
#   'Shopping',
#   'Holiday Decorations',
#   'Arts & Crafts',
#   'Home & Garden',
#   'Pet Stores'],
#  'w2cMki_NUkJAAgePqM_GHg': ['Beauty & Spas', 'Hair Stylists', 'Hair Salons'],
#  'TNtzvDcY20ueBMz9mG_JeA': ['Psychic Mediums',
#   'Jewelry',
#   'Shopping',
#   'Psychics',
#   'Supernatural Readings',
#   'Arts & Entertainment'],
#  'F3c8UkGPBEkhvTItCxp7jw': ['Musical Instrument Services',
#   'Movers',
#   'Local Services',
#   'Self Storage',
#   'Piano Services',
#   'Home Services'],
#  'vdKUDXI1j89VO65Krg6VGg': ['Flight Instruction',
#   'Education',
#   'Hotels & Travel',
#   'Transportation',
#   'Specialty Schools',
#   'Airlines'],
#  'ci3xUs8ZffvGhWfoioAL0Q': ['Hotels & Travel',
#   'Nightlife',
#   'Food',
#   'Beer',
#   'Wine & Spirits'],
#  'Kot0deqA1WAbZ7YXY5fQ5w': ['Home Services',
#   'Department Stores',
#   'Fashion',
#   'Nurseries & Gardening',
#   'Hardware Stores',
#   'Home & Garden',
#   'Shopping',
#   'Building Supplies',
#   'Appliances'],
#  'j227Ila_C6ZjAEoAxKU_CQ': ['Home Services',
#   'Heating & Air Conditioning/HVAC'],
#  'fsklFcY47qJIr0mjgobuUg': ['Car Dealers',
#   'Auto Repair',
#   'Auto Parts & Supplies',
#   'Automotive'],
#  'gkxOddGO7MLPkhP_BDwzpg': ['Financial Services', 'Banks & Credit Unions'],
#  'qvKvxTEp7Lg1fDB6yDoJBg': ['Apartments', 'Real Estate', 'Home Services'],
#  'OGTcFgRhPhj2GqUEyAi_eA': ['Event Planning & Services',
#   'Venues & Event Spaces'],
#  '5GXKxdlJQOrmoPe0GXzJNA': ['Local Flavor',
#   'Chinese',
#   'Nightlife',
#   'Restaurants',
#   'Bars',
#   'Buffets',
#   'Asian Fusion'],
#  'GB3L81lYwu-GuyXrbnUpUQ': ['Restaurants'],
#  'Tuu_B0QGo7SQUuXW_Nd4hg': ['Middle Eastern',
#   'Pizza',
#   'Sandwiches',
#   'Chicken Wings',
#   'Restaurants'],
#  'ItmLljzhwhuyyvekNs4Ymg': ['Fast Food',
#   'Restaurants',
#   'Delis',
#   'Sandwiches',
#   'Wraps'],
#  'Q2R7pFWY8ZrZ_xS6IvPADg': ['Air Duct Cleaning',
#   'Local Services',
#   'Heating & Air Conditioning/HVAC',
#   'Home Services'],
#  'aXa1nUP_rShmuFbqQ44ijA': ['Pest Control', 'Local Services'],
#  '8TBt9XAVZIZR2Y0EqBHskg': ['Food',
#   'Gas Stations',
#   'Car Wash',
#   'Convenience Stores',
#   'Automotive',
#   'Auto Detailing',
#   'Oil Change Stations'],
#  'LWxSTjV6zybxIZKkSK3SNQ': ['Local Services',
#   'Shopping',
#   'Donation Center',
#   'Thrift Stores'],
#  'gj8mPhHVqJwFLH-PFRQDRw': ['Local Services',
#   'Home Services',
#   'Pest Control',
#   'Window Washing'],
#  'jX9DocoiY4Bo9EUkaTSqvg': ['Restaurants',
#   'Hawaiian',
#   'Chinese',
#   'Japanese',
#   'Poke',
#   'Asian Fusion',
#   'Mexican',
#   'Food'],
#  'oqvh7TAJgyayxYwNM4PlZw': ['Bars', 'Sports Bars', 'Nightlife'],
#  '1LmdjQv3-5v8vpiF08UhLw': ['Nail Salons', 'Beauty & Spas'],
#  'ecJri9ozyke4dOCWulZiRQ': ['Asian Fusion',
#   'Japanese',
#   'Restaurants',
#   'Ramen',
#   'Tapas Bars'],
#  'VL0JMErbrfZcTPdQlxx-Xg': ['Cosmetics & Beauty Supply',
#   'Shopping',
#   'Beauty & Spas',
#   'Skin Care',
#   'Makeup Artists',
#   'Hair Removal'],
#  've9zM6VNkDSNXd_OKayuwQ': ['Beauty & Spas', 'Nail Salons'],
#  'bIzxwD9L56Gza6swL4eoJQ': ['Automotive', 'Gas Stations'],
#  'LV7HOYO2UEajOK81hOuZMQ': ['Employment Agencies', 'Professional Services'],
#  'Z_-KUIoogqjFJyLNP0TW3A': ['IT Services & Computer Repair',
#   'Mobile Phone Repair',
#   'Electronics Repair',
#   'Local Services'],
#  '3e0IGa_-zqTemKLc1dbdmg': ['Restaurants', 'Taiwanese'],
#  'xXtWrRKn8A708BfaNs1nZw': ['Sandwiches',
#   'Juice Bars & Smoothies',
#   'Coffee & Tea',
#   'Food',
#   'Donuts',
#   'Ice Cream & Frozen Yogurt',
#   'Restaurants'],
#  'yxAw_NtCqtvFPXGq4C1f5A': ['Restaurants'],
#  'iA9xu-6oOFynZQxO5qrauQ': ['Nightlife', 'Restaurants', 'Bars'],
#  'mofOjB6flg-eAWOFbOkHfQ': ['Sushi Bars', 'Buffets', 'Restaurants', 'Chinese'],
#  'pSSJHn14sdH6oGPwtRn1Xg': ['Sewing & Alterations', 'Local Services'],
#  'QAqm1ubKgPYYqjZKxfi87A': ['Pet Groomers',
#   'Pet Stores',
#   'Pet Services',
#   'Pets'],
#  '4cS8ql252b9OMlKeNq_YCQ': ['Real Estate',
#   'Home Services',
#   'Property Management'],
#  'EQq1K0q9VVJm4zYw0NGwfA': ['Automotive', 'Smog Check Stations'],
#  'P4HqDYI1icascvcwca7iLg': ["Men's Clothing",
#   'Shopping',
#   'Department Stores',
#   'Fashion',
#   'Shoe Stores',
#   "Women's Clothing"],
#  '6gorEMxDpiCTUmLXI5DCoQ': ['Restaurants',
#   'Vegetarian',
#   'Pakistani',
#   'Middle Eastern',
#   'Indian'],
#  'U1iF2RC18uBgBe01z5BMXw': ['Restaurants', 'Fast Food', 'Chicken Wings'],
#  'El6Bum4I-0VWJRgzbtscJQ': ['Fast Food',
#   'Sandwiches',
#   'Restaurants',
#   'Food',
#   'Food Delivery Services',
#   'Delis'],
#  'eJMbAEvDNyet8_MmaVPsmA': ['Beauty & Spas',
#   'Nail Salons',
#   'Waxing',
#   'Eyelash Service',
#   'Hair Removal'],
#  'adpp_kxCabWfLPJ4N106nw': ['Pawn Shops', 'Shopping', 'Jewelry'],
#  'trMrmg0EKcxEYAkqLBbRMA': ['Food',
#   'Beer',
#   'Wine & Spirits',
#   'Restaurants',
#   'Barbeque',
#   'Local Flavor',
#   'American (Traditional)'],
#  'eezVjNlzIZrXs9GM5O8b2w': ['Shopping', 'Vape Shops'],
#  '4jubHRWnZICNNMyQwnyjQw': ['Home Services',
#   'Commercial Real Estate',
#   'Mortgage Brokers',
#   'Real Estate Agents',
#   'Financial Services',
#   'Mortgage Lenders',
#   'Real Estate'],
#  'DZWLw5AaCcu9SgO_1lBZ-Q': ['Cosmetics & Beauty Supply',
#   'Shoe Stores',
#   'Shopping',
#   'Fashion',
#   'Hair Removal',
#   'Nail Salons',
#   'Lingerie',
#   'Hair Salons',
#   'Arts & Crafts',
#   'Tanning',
#   'Beauty & Spas',
#   'Costumes',
#   "Women's Clothing",
#   'Accessories'],
#  '9eY5ZfKPc_oz6Co5WCPynQ': ['Financial Advising', 'Financial Services'],
#  'pbt-wWuOE2Kp4rvz57Bdvg': ['Jewelry', 'Shopping'],
#  'w6l6uq95_-36unVjTaFIXw': ['Beauty & Spas',
#   'Hair Extensions',
#   'Hair Stylists',
#   'Hair Salons'],
#  'QZ4GFIArBMGolsVi0XHgcA': ['Chinese', 'Restaurants', 'Fast Food'],
#  'MBxoJEZ1laNbxCg4exLNug': ['Home Services',
#   'Hot Tub & Pool',
#   'Shopping',
#   'Home & Garden',
#   'Pool Cleaners',
#   'Contractors'],
#  'WHcaRhDuMY9j6N6cxDmGWg': ['Health & Medical', 'Allergists', 'Doctors'],
#  'F6c3D1o9Z4Tl6cDorb3WgA': ['Burgers',
#   'Restaurants',
#   'Cafes',
#   'Salad',
#   'Sandwiches'],
#  'yEma5FsJzqYaTHaMMxwwMA': ['Local Services',
#   'Home Services',
#   'Home Cleaning',
#   'Carpet Cleaning',
#   'Tiling',
#   'Grout Services'],
#  'aERMWmIT6yJVGYIn4qQizQ': ['Automotive',
#   'Motorcycle Dealers',
#   'Motorcycle Repair'],
#  'tREKISC21iPORmC24fEpdw': ['Shopping', 'Electronics'],
#  'rtKB12BkQVb3x1e4diTIeA': ['Food',
#   'Sandwiches',
#   'Restaurants',
#   'Soup',
#   'Bakeries',
#   'Salad'],
#  '9MDMNb8JhJcJzIAvD8kl3g': ['Education',
#   'Venues & Event Spaces',
#   'Event Planning & Services',
#   'Art Schools',
#   'Shopping',
#   'Jewelry',
#   'Art Classes',
#   'Specialty Schools'],
#  '-ACp6Qv866UuTD6UhTNWTA': ['Home & Garden',
#   'Fashion',
#   "Women's Clothing",
#   'Furniture Stores',
#   'Shopping'],
#  'CodoVn98WzIP2_NC18NuCw': ['Restaurants',
#   'Canadian (New)',
#   'French',
#   'Brasseries'],
#  'x0R0DPvH4RWNrPltI4DFTw': ['Nail Salons', 'Beauty & Spas'],
#  '4MxNo7pH-PRdwik4Hx5Jyw': ['Yoga', 'Active Life', 'Fitness & Instruction'],
#  'JO5_Frcbp9J732VNn-I3Ew': ['American (New)',
#   'Burgers',
#   'Diners',
#   'Restaurants',
#   'Fast Food',
#   'Breakfast & Brunch',
#   'American (Traditional)'],
#  'Ye6Bdtw2lq5Y6FeX-p377Q': ['Vegan',
#   'Soul Food',
#   'Restaurants',
#   'Food',
#   'Juice Bars & Smoothies'],
#  '9zH9cMABl2ZiBWlvvHJ_kQ': ['Furniture Assembly',
#   'Local Services',
#   'Couriers & Delivery Services',
#   'Handyman',
#   'Home Services'],
#  'iMb2NjGdBO6_JOe1OwoL7A': ['Hair Salons',
#   "Men's Hair Salons",
#   'Hair Stylists',
#   'Barbers',
#   'Beauty & Spas'],
#  's6-E2ojR__3CSCsIvVq-xA': ['Fashion', 'Shopping', "Men's Clothing"],
#  'Ykn6eHLY8vPHuUH7UQrvxw': ['Food', 'Bakeries', 'Coffee & Tea'],
#  '9MFcLXNi4pbqHsdrH9giZw': ['Restaurants', 'Filipino', 'Soup', 'Fast Food'],
#  'CDOjlyFd8ro5X0-XZl6Eeg': ['Hotels & Travel',
#   'Private Jet Charter',
#   'Airports',
#   'Transportation',
#   'Travel Services'],
#  'Ao8DPAkiK7-wNlTsvHwnhw': ['Car Rental', 'Hotels & Travel'],
#  '_WyTVGIhZIqesE4DLrcTvA': ['Burgers',
#   'Restaurants',
#   'American (Traditional)'],
#  'KvVE3Zt0UO4EVLng8M5x9A': ['Movers',
#   'Self Storage',
#   'Packing Services',
#   'Home Services',
#   'Local Services'],
#  'PkI1x_NCyEt2sR8MYv4l7w': ['Flowers & Gifts',
#   'Shopping',
#   'Gift Shops',
#   'Electronics'],
#  'MKxUR2hiolsE1ubji_mMGw': ['Real Estate',
#   'Auction Houses',
#   'Real Estate Services',
#   'Antiques',
#   'Shopping',
#   'Home Services',
#   'Estate Liquidation',
#   'Contractors'],
#  'bt00hbBi-DN6ksKiQngV4g': ['Grocery',
#   'Health Markets',
#   'Specialty Food',
#   'Health & Medical',
#   'Herbs & Spices',
#   'Organic Stores',
#   'Food'],
#  '4tjKsIaBXCDUP9PL82Vu_A': ['Day Spas',
#   'Beauty & Spas',
#   'Hair Salons',
#   'Massage',
#   'Skin Care'],
#  'gMMSxoxlu-CcocrwRJfgPg': ['Used',
#   'Vintage & Consignment',
#   'Shopping Centers',
#   'Bridal',
#   'Fashion',
#   'Event Planning & Services',
#   "Children's Clothing",
#   'Wedding Planning',
#   'Shopping'],
#  'j8Sdor4_SkPBD7fhC8IS8w': ['Automotive', 'Auto Parts & Supplies'],
#  'efI62THmRB2PvCyDF08BAQ': ['Pain Management',
#   'Professional Services',
#   'Doctors',
#   'Anesthesiologists',
#   'Rehabilitation Center',
#   'Personal Injury Law',
#   'Lawyers',
#   'Massage',
#   'Physical Therapy',
#   'Chiropractors',
#   'Health & Medical',
#   'Nutritionists',
#   'Medical Centers',
#   'Beauty & Spas'],
#  'R_nQsi2egjUyjgKqOZRJIw': ['Performing Arts', 'Arts & Entertainment'],
#  'j9YFHVQqxM_qKHIc4nck-A': ['Hakka',
#   'Indian',
#   'Asian Fusion',
#   'Restaurants',
#   'Chinese'],
#  'KAhavksKQwKbMzZHiNOyOQ': ['Italian', 'Restaurants', 'Pizza'],
#  '11TptVg6LRkVssYLRSrpgA': ['Health & Medical', 'Hospitals'],
#  'UdL8Z06DaNj6qhen0fEH9A': ['Mexican', 'Restaurants', 'Seafood'],
#  'UZCfJ29B4MRIS3igABE_Ew': ['Grocery',
#   'Specialty Food',
#   'Ethnic Food',
#   'Food',
#   'Imported Food'],
#  'nwxF9EKLOCpkScMF2utHDw': ['Ice Cream & Frozen Yogurt',
#   'Food',
#   'Event Planning & Services',
#   'Desserts',
#   'Caterers'],
#  'zHY31XJfijzjKDM03vJCJA': ['Shopping', 'Drugstores'],
#  'KZ9v7M1A5t6OMDghR64_5g': ['American (New)',
#   'Restaurants',
#   'Breakfast & Brunch'],
#  'i_0rSAui4zaz4ydVaOZ6bQ': ['Food',
#   'Grocery',
#   'Delis',
#   'Buffets',
#   'Event Planning & Services',
#   'Breakfast & Brunch',
#   'Restaurants',
#   'Caterers'],
#  '6XImdD5qH_LFZhHeLjLaGQ': ['Sandwiches', 'Fast Food', 'Restaurants'],
#  'vM_NrQmVd4wjEcB1czP2bg': ['Department Stores', 'Fashion', 'Shopping'],
#  'L6R2Op88NkoG1EGxlVvdRQ': ['Food',
#   'Coffee & Tea',
#   'Bakeries',
#   'Restaurants',
#   'Cafes'],
#  'xHZmM-kGXqOfmQNTm0T05g': ['Burgers',
#   'Italian',
#   'Beauty & Spas',
#   'Wine Bars',
#   'Barbers',
#   'Peruvian',
#   'American (Traditional)',
#   'Bars',
#   'Gastropubs',
#   'Diners',
#   'Salad',
#   'Specialty Food',
#   'Restaurants',
#   'American (New)',
#   'Nightlife',
#   'Cafes',
#   'Food'],
#  'xJuHAICm6aNl39lDRw75_Q': ['Shopping',
#   'Used',
#   'Vintage & Consignment',
#   'Fashion'],
#  'sn19SpNpjZ8BsZiXOqsAAA': ['Arts & Crafts', 'Art Supplies', 'Shopping'],
#  'QfOJ9-nFnV4hlVlndUCMCQ': ['Home Services', 'Home Cleaning'],
#  'BV5aMfFFDOvaWsSS-D5j9g': ['Restaurants', 'Mediterranean'],
#  'UwanDENbM3PYTpkKqJD4WQ': ['Beauty & Spas',
#   'Cosmetics & Beauty Supply',
#   'Shopping'],
#  'mQkVFNSDpD4frPUMycVoWw': ['Canadian (New)',
#   'Wine Bars',
#   'Italian',
#   'Restaurants',
#   'Caterers',
#   'Bars',
#   'Nightlife',
#   'Event Planning & Services'],
#  'Mq6qiz-Bxgd8VE6tBwCuUg': ['Restaurants',
#   'Breakfast & Brunch',
#   'Food',
#   'Coffee & Tea'],
#  'Hdzo5ggPswyv-8ZlW0PVLw': ['Coffee & Tea',
#   'Wedding Planning',
#   'Food',
#   'Event Planning & Services',
#   'Ice Cream & Frozen Yogurt',
#   'Party & Event Planning',
#   'Gelato'],
#  '_RTnzQumsGrs3n4XuJaDQg': ['Nightlife', 'Bars', 'Sports Bars'],
#  'nm5yx8yvJNJYVjaRPwjnsw': ['Buffets', 'Restaurants'],
#  'Xf4qG-Ob_dC3B8ZPtW38Fg': ['Home Services',
#   'Heating & Air Conditioning/HVAC'],
#  'ZCzK3cGob727bW3EvtAlYg': ['Massage Therapy',
#   'Nutritionists',
#   'Life Coach',
#   'Health & Medical',
#   'Professional Services',
#   'Fitness & Instruction',
#   'Trainers',
#   'Active Life'],
#  'm4DwPVxmFDQE_FnGIOa3cQ': ['Buffets', 'Chinese', 'Restaurants'],
#  '9VSPMQXgPdJ4rNgBPLJZ1A': ['Restaurants',
#   'Coffee & Tea',
#   'Bakeries',
#   'Food',
#   'Breakfast & Brunch',
#   'Coffee Roasteries'],
#  'cujI9gM6YlQr29cDhTBSAQ': ['Restaurants', 'Filipino'],
#  'wdsGP5rJinx0J5GcGzPQUw': ['Steakhouses', 'Restaurants'],
#  'UPh90LM8UMnVFQP6NGktrA': ['Restaurants', 'Bakeries', 'Food'],
#  'tQwSTmYTpMTGY3r5rCKMsg': ['Shopping', 'Mobile Phones'],
#  'SZ5KO1KNiwtrktKo5mpuLA': ['Seafood',
#   'Chinese',
#   'Steakhouses',
#   'Restaurants',
#   'Italian'],
#  'hhyxW1YCt8wgj4GcecD9rQ': ['Roofing', 'Contractors', 'Home Services'],
#  'hXzoNgpkC86K_Jfg_zMHvA': ['Vietnamese', 'Restaurants'],
#  'me_UR1W9xfVaAAxGse07og': ['Home Cleaning', 'Home Services'],
#  'EVC1vn1KQ2uETnTbDWXc5w': ['Caribbean', 'Tapas/Small Plates', 'Restaurants'],
#  'Euq0ltqgsmD2VMlBopDbdg': ['Local Services', 'Funeral Services & Cemeteries'],
#  'iFLXgtv8vrIQQu07vrGWgA': ['Medical Centers', 'Health & Medical'],
#  '4B8VnRAstRRshxiUzm9yPw': ['Restaurants', 'Sushi Bars', 'Japanese'],
#  '8ELlbjnXfZAw4KbQRP3-EQ': ['Italian', 'Restaurants'],
#  'dtpFxDbBTBl90NyttDqoMg': ['Food', 'Restaurants', 'Bakeries', 'Cafes'],
#  '5DdD6Z634cMSvnynSq8p1w': ['Advertising',
#   'Business Consulting',
#   'Professional Services',
#   'Web Design',
#   'Graphic Design',
#   'Event Planning & Services',
#   'Videographers',
#   'Marketing',
#   'Public Relations'],
#  'iiHXERJsuPSxLCqQFvPYKA': ['Fences & Gates', 'Home Services'],
#  'EefLnsulpa0t3Uw5kKR7eA': ['Event Photography',
#   'Event Planning & Services',
#   'Photographers',
#   'Session Photography'],
#  '8oxMIWw5NzchZJIOnX8sTw': ['Web Design',
#   'Print Media',
#   'Local Services',
#   'Mass Media',
#   'Printing Services',
#   'Signmaking',
#   'Professional Services',
#   'Graphic Design'],
#  'RRTkmwGTBSWnmYdtg-SmdA': ['Summer Camps',
#   'Preschools',
#   'Active Life',
#   'Child Care & Day Care',
#   'Local Services',
#   'Education'],
#  'NX1281ugzs2navHAX5X9cQ': ['Bubble Tea',
#   'Food',
#   'Restaurants',
#   'Taiwanese',
#   'Coffee & Tea'],
#  '43PeF0ERpSIiEbXM6f9N2g': ['Restaurants',
#   'Greek',
#   'Mediterranean',
#   'Caterers',
#   'Event Planning & Services'],
#  'GiTv0gFXtYFQAzCXnPvepQ': ['Restaurants',
#   'American (Traditional)',
#   'American (New)',
#   'Tex-Mex',
#   'Bars',
#   'Nightlife'],
#  'NCac2iPhlIeWRgG5L4hCzg': ['Home Services',
#   'Carpet Cleaning',
#   'Local Services',
#   'Tiling',
#   'Refinishing Services'],
#  '9ffhtZhp7RclEJM0OHnGPA': ['Health & Medical',
#   'Financial Services',
#   'Health Insurance Offices',
#   'Insurance'],
#  'tylsscXmLq03-DzGI36bIA': ['Restaurants', 'Sandwiches', 'Salad', 'Pizza'],
#  'Q8AutZN3WoZb69D9bsCGUw': ['Nightlife', 'Dive Bars', 'Bars'],
#  'aVdW5rDFDCCTwBiS2-AI1w': ['Body Shops', 'Automotive'],
#  'O-fYUqXjkwNvRfFnlUH6Iw': ['Bakeries',
#   'Event Planning & Services',
#   'Caterers',
#   'Desserts',
#   'Ice Cream & Frozen Yogurt',
#   'Food'],
#  'x5mv33siyWGXVpOmLACfPQ': ['Automotive', 'Car Wash'],
#  'O4QbewwNOZ20gDaWK1hxtw': ['Heating & Air Conditioning/HVAC',
#   'Home Cleaning',
#   'Professional Services',
#   'Office Cleaning',
#   'Air Duct Cleaning',
#   'Home Services',
#   'Chimney Sweeps',
#   'Local Services'],
#  'G_05ZI4Vpl4bxjjZR11jEQ': ['Arts & Entertainment',
#   'Botanical Gardens',
#   'Parks',
#   'Active Life'],
#  'LEOvXK3lMEfjnex3CPvrng': ['Food', 'Bakeries', 'Restaurants'],
#  'G7sVtpD6aqpuUB4F3LEG_w': ['Breakfast & Brunch',
#   'Food',
#   'Restaurants',
#   'Coffee & Tea'],
#  'fin8bCrfZ7aCB1pGesvDmw': ['Shopping',
#   'Fashion',
#   "Men's Clothing",
#   'Jewelry',
#   'Accessories',
#   'Bridal'],
#  'jP5l-EWJcMYUiv1UoQssAg': ['Fashion',
#   'Shopping',
#   'Used',
#   'Vintage & Consignment'],
#  'zfOum9_rEhaLAqoAV3nYaQ': ['Specialty Food',
#   'Food',
#   'Bars',
#   'Italian',
#   'Nightlife',
#   'Ethnic Food',
#   'Restaurants',
#   'Cocktail Bars',
#   'Mediterranean'],
#  'cXBB07Kb2TcAuzJTVo9tZw': ['Breakfast & Brunch',
#   'Restaurants',
#   'Canadian (New)',
#   'Diners'],
#  'hZzwkAJG92KkszWO8PoOQA': ['Fast Food', 'Sandwiches', 'Restaurants'],
#  'rFYmB7_Ba1rq04NzZBbRkg': ['Photo Booth Rentals',
#   'Party Supplies',
#   'Party Equipment Rentals',
#   'Event Planning & Services'],
#  'fKgupz5SZzgW0Hrmq4mG7A': ['Blow Dry/Out Services',
#   'Hair Stylists',
#   'Beauty & Spas',
#   'Hair Salons'],
#  'YYQ6-vDjbJkhknyzeeQ8OQ': ['Chiropractors',
#   'Medical Spas',
#   'Beauty & Spas',
#   'Health & Medical',
#   'Massage',
#   'Day Spas'],
#  '2tE_n3ws4Vn1byejSZZIsQ': ['Pet Sitting',
#   'Dog Walkers',
# ...
#  'oWEFIvvt_kJCuk2V268XeQ': ['Restaurants', 'Chinese', 'Dim Sum'],
#  'yxxd0BUAJPgKgnYHn4sUiQ': ['Taekwondo',
#   'Gyms',
#   'Martial Arts',
#   'Education',
#   'Active Life',
#   'Fitness & Instruction',
#   'Educational Services'],
#  'DgRQufnyhXHfaxFggv124g': ['Doctors', 'Health & Medical', 'Pediatricians'],
#  'BrGJGL4Y4xilpZ3IdfZCVA': ['Physical Therapy',
#   'Doctors',
#   'Chiropractors',
#   'Health & Medical',
#   'Naturopathic/Holistic',
#   'Acupuncture'],
#  'j1-t7dIoGgzgcmotB7pkOg': ['Bubble Tea', 'Food', 'Coffee & Tea', 'Desserts'],
#  'vIsMdsBQNJd66kSVYns_YQ': ['Transportation', 'Airlines', 'Hotels & Travel'],
#  'SXlTTzi9lfbzl6uKrESslA': ['Soccer', 'Active Life', 'Parks', 'Playgrounds'],
#  '_9u7I2RN0NEJnWaP2zhWsQ': ['Food', 'Ice Cream & Frozen Yogurt'],
#  'YShJyhSL6pBLIDC7xy-cYA': ['Flooring',
#   'Home Services',
#   'Carpet Cleaning',
#   'Tiling',
#   'Office Cleaning',
#   'Local Services',
#   'Refinishing Services',
#   'Grout Services',
#   'Home Cleaning',
#   'Professional Services',
#   'Contractors'],
#  'RbZK0G5GJtcXNIXYRB9pzQ': ['Grocery',
#   'Shopping',
#   'Food',
#   'Florists',
#   'Flowers & Gifts',
#   'Convenience Stores'],
#  'GZr47kxnbhB2L8bp0NpaCw': ['Appliances', 'Shopping', 'Home & Garden'],
#  '06vop9TL2yZrloLMtb_9sQ': ['Local Services',
#   'Electronics Repair',
#   'IT Services & Computer Repair',
#   'Mobile Phone Repair'],
#  'tfJF9ZjHH3oyqWwrGXYCvA': ['Active Life',
#   'Parks',
#   'Landmarks & Historical Buildings',
#   'Local Flavor',
#   'Public Services & Government'],
#  'MPy49gUd9JkVcHCEin03bw': ['Car Dealers',
#   'Auto Parts & Supplies',
#   'Auto Repair',
#   'Automotive'],
#  '1RKSuFsvxZ0KiFfMpX3YZA': ['Food', 'Bakeries'],
#  '2_ngZCEtgrzZzUF-pwTVcA': ['Health & Medical',
#   'Hospitals',
#   'Doctors',
#   'Emergency Rooms',
#   'Family Practice'],
#  'DuUksv9EDj3agIMysRgYlw': ['Shopping',
#   "Men's Clothing",
#   'Accessories',
#   'Fashion',
#   'Plus Size Fashion',
#   "Women's Clothing"],
#  'VE8BouWadOixfUIljcdSZg': ['Restaurants'],
#  'e8H_6IynA1X13PbJbQP-3A': ['Home Cleaning', 'Home Services'],
#  'cMK38jKxH8x5PvFfAfjZmA': ['Mexican', 'Restaurants'],
#  'SGPjYRy6x7R5ZlGa_nrskg': ['Restaurants',
#   'Southern',
#   'American (New)',
#   'American (Traditional)'],
#  'mQTem4Fcj3jlJ7xUaNj1wQ': ['Physical Therapy', 'Health & Medical'],
#  'RDf4A5uo_0aLeSufH3NMhA': ['Furniture Stores',
#   'Home & Garden',
#   'Shopping',
#   'Mattresses'],
#  'lNOPJU1mGMePKmRy268ziQ': ['Day Spas',
#   'Beauty & Spas',
#   'Skin Care',
#   'Makeup Artists'],
#  'WOQNQx7SrMalJMXFENitpg': ['Sandwiches', 'Soup', 'Restaurants'],
#  '_sqtz2Lk7LKVQ-RwHqoujQ': ['Pilates',
#   'Active Life',
#   'Yoga',
#   'Fitness & Instruction',
#   'Sports Clubs',
#   'Gyms'],
#  'fQXo3sLLR5M7J8hTReQ8Vg': ['Beauty & Spas',
#   'Hair Removal',
#   'Laser Hair Removal'],
#  'mk7xgXuTVMfv4sH7GD2SoA': ['Coffee & Tea', 'Food', 'Tea Rooms', 'Desserts'],
#  'OrGGV05yjScIPekmZkEwXg': ['Pet Services',
#   'Veterinarians',
#   'Pets',
#   'Emergency Pet Hospital'],
#  'vXg8jQrYPGH7fTe2QoUMnA': ['Car Dealers', 'Automotive', 'Auto Repair'],
#  '143ym0TQNgSVxW7BW23Azw': ['Automotive',
#   'Towing',
#   'Oil Change Stations',
#   'Auto Repair'],
#  'VVLGIq6ksrgGSfi7VBTmpg': ['Restaurants', 'American (Traditional)'],
#  'ZRdHKIjiIa0k5-ufCLyIaQ': ['American (Traditional)',
#   'Breakfast & Brunch',
#   'Diners',
#   'American (New)',
#   'Restaurants'],
#  'FKQUxOfW_W5R4OTut4G1Vw': ['Restaurants', 'Sandwiches'],
#  'MCCpclxhfgk2FATwyKyZ1A': ['Education',
#   'Middle Schools & High Schools',
#   'Elementary Schools'],
#  'aRNjAsmXv1pJTUWTtI7xlw': ['Food', 'Convenience Stores'],
#  'c_FTil8s5PS2l_YJDQAXhA': ['Restaurants',
#   'Bars',
#   'Seafood',
#   'Nightlife',
#   'Pubs'],
#  'dfq3DgjQRpkDfH6beZI7Ag': ['Health & Medical',
#   'Community Service/Non-Profit',
#   'Local Services'],
#  'WMbaBGpWX2rROed0q-R5EA': ['Hot Tub & Pool',
#   'Home & Garden',
#   'Pool Cleaners',
#   'Home Services',
#   'Shopping'],
#  '7RoaNSRDpjaDVWfpDnbPng': ['Sports Clubs',
#   'Local Services',
#   'Community Service/Non-Profit',
#   'Child Care & Day Care',
#   'Active Life',
#   'Gyms',
#   'Fitness & Instruction'],
#  '1wJckBZ43wD3Y8SEm92c-Q': ['Shopping',
#   'Mobile Phone Repair',
#   'Local Services',
#   'Mobile Phones',
#   'IT Services & Computer Repair'],
#  'oOHgRtOX2NIC3-YwoiGJwA': ['Beauty & Spas', 'Nail Salons'],
#  'n3a4ytrLWiSkLMrhp8P0Uw': ['Active Life',
#   'Gyms',
#   'Trainers',
#   'Fitness & Instruction'],
#  'IlLKpNu4BrIhjruik8poiQ': ['Emergency Rooms',
#   'Health & Medical',
#   'Hospitals',
#   'Medical Centers'],
#  'MdtsA9oE2aFEYLHqmKfp9w': ['Fashion', 'Shopping', 'Lingerie'],
#  'pDA8NJUwGl1IoLDeaVfo0Q': ['Cinema', 'Arts & Entertainment'],
#  'g62TXcQXbSnR0uzOuSVxjQ': ['Plus Size Fashion',
#   'Shopping',
#   'Fashion',
#   'Accessories',
#   "Women's Clothing"],
#  'XK1Xk_hhBlJuoUrwtBTbnA': ['Arts & Entertainment',
#   'Home Decor',
#   'Shopping',
#   'Home & Garden',
#   'Art Galleries'],
#  'NbjeMaUoYT_XUB8PWnwLkw': ['Restaurants', 'Pizza'],
#  '9B2kV3k4t72mr-o4Ry_soQ': ['Bakeries', 'Food', 'Coffee & Tea'],
#  'bpO1ZGxUrD-oWLKEgmc9vA': ['Hobby Shops',
#   'Shopping',
#   'Photography Stores & Services'],
#  '9hV1Up0dOHpHFLEhFH0wtw': ['Automotive',
#   'Auto Repair',
#   'Auto Parts & Supplies',
#   'Oil Change Stations'],
#  'AozgNfsjP4SizYq5Zcs_LA': ['Shopping', 'Lingerie', 'Fashion', 'Swimwear'],
#  'EWKjkBKWYvzxom_7dX96yw': ['Windows Installation', 'Home Services'],
#  'Yw-R7D38MuDFNNcL6i-0Ww': ['Restaurants', 'Thai'],
#  'MrqG_TzPLMRrob--EHNdOw': ['Sandwiches',
#   'Poutineries',
#   'Restaurants',
#   'Cafes'],
#  'efxnaXEAWCeB1S-fv_Ri0Q': ['Bars', 'Pubs', 'Nightlife'],
#  'SQ5we-HZLsFpj8ppMtEBcQ': ['Specialty Schools',
#   'Beauty & Spas',
#   'Cosmetology Schools',
#   'Hair Salons',
#   'Education',
#   'Vocational & Technical School'],
#  'uFAjW-4-5GWvD9n5u0h8MQ': ['Local Services',
#   'Laundry Services',
#   'Dry Cleaning & Laundry'],
#  'U8Uecw7AZPMuA4fkKbEd1A': ['Event Planning & Services',
#   'Restaurants',
#   'Fast Food',
#   'Sandwiches',
#   'Caterers'],
#  '7WZz6pi9S_o1u584KMFiVg': ['Local Services',
#   'Community Service/Non-Profit',
#   'Medical Centers',
#   'Blood & Plasma Donation Centers',
#   'Health & Medical'],
#  'N41VYb9fhafQOi1WP_VPCA': ['Body Shops',
#   'Oil Change Stations',
#   'Auto Repair',
#   'Automotive'],
#  'vK4GNzRjuolV5ZMUfbdRCg': ['Doctors',
#   'Internal Medicine',
#   'Health & Medical'],
#  'V2Sb71qv_um1ntfaMW8yFw': ['Lingerie', 'Shopping', 'Fashion'],
#  'U50YoWOEmagNix2sbD-yMg': ['French', 'Restaurants'],
#  'jlpTlPzu3xbdaT8YTBaB9A': ['Auto Repair',
#   'Automotive',
#   'Oil Change Stations'],
#  'fM4bmkEW-4s3QTT1oKVlKw': ['Lounges',
#   'Event Planning & Services',
#   'Venues & Event Spaces',
#   'Bars',
#   'Nightlife'],
#  'DJTp8_qFr1mU_HMvvhk8Bw': ['Restaurants', 'American (Traditional)'],
#  'aSB_HTwUzvN50-Rv9YiWSg': ['Insurance',
#   'Tours',
#   'Travel Services',
#   'Financial Services',
#   'Hotels & Travel'],
#  'QgXTuzc_i8dO_p2XD7PP0Q': ['Automotive', 'Auto Parts & Supplies'],
#  'F5arCcVW_mjFWbgJbWYO-Q': ['Food', 'Juice Bars & Smoothies', 'Coffee & Tea'],
#  'P-na-PyTJTL-uZ15vEg6zA': ['Coffee & Tea', 'Food', 'Cafes', 'Restaurants'],
#  '2W3If040rgz34_ZO3c_SxA': ['Restaurants',
#   'Bars',
#   'Nightlife',
#   'Pizza',
#   'Sports Bars'],
#  'YQnRNfqNarkwZvn_ESQ8dg': ['Keys & Locksmiths', 'Home Services'],
#  'BWxGMT2wbAIEzrEjZNENRw': ['Veterinarians', 'Pets'],
#  'uwpPniaFEVkK5T_PWdQZ0A': ['Breakfast & Brunch',
#   'Restaurants',
#   'Coffee & Tea',
#   'American (Traditional)',
#   'Food'],
#  'G2mxGuaLm4QVF8ep80d3yQ': ['Pets', 'Veterinarians', 'Animal Shelters'],
#  'DrTZoBYke80zH1herrG0_g': ['Transportation',
#   'Party Equipment Rentals',
#   'DJs',
#   'Limos',
#   'Professional Services',
#   'Hotels & Travel',
#   'Event Planning & Services',
#   'Local Services'],
#  'COExayvsDDJOjWTOFZ7a4A': ['African', 'Bars', 'Restaurants', 'Nightlife'],
#  '1miWFf_qJZpBE7DYK63iqA': ['Automotive', 'Car Dealers'],
#  's-lwOqEEWb_peWh8DhhWUg': ['Food', 'Grocery'],
#  'ZYMCKCjMc4mtiT_okzcirw': ['Laser Hair Removal',
#   'Body Contouring',
#   'Beauty & Spas',
#   'Tattoo Removal',
#   'Health & Medical',
#   'Doctors',
#   'Medical Spas',
#   'Hair Removal'],
#  'yd6pLLCKrrQvV_sV37YLrQ': ['Pet Services',
#   'Pet Groomers',
#   'Pet Sitting',
#   'Pets',
#   'Veterinarians',
#   'Pet Boarding'],
#  'WsdmzI2giWHcRN2plprxIg': ['Parks', 'Active Life', 'Playgrounds'],
#  '0WAL6O1YvcJbeDRYeRm34w': ['Pizza', 'Restaurants', 'Italian'],
#  'hwwSII35ZAmhl3pTDhUTRQ': ["Women's Clothing",
#   'Shopping',
#   "Men's Clothing",
#   'Outlet Stores',
#   'Fashion'],
#  '-pKhASvKFolihdipQfQXyA': ['Burgers', 'Fast Food', 'Restaurants'],
#  'yKpdzrqe_qIbu9dB6bj9Gg': ['American (Traditional)',
#   'Restaurants',
#   'Bars',
#   'Nightlife'],
#  'HxUD_4GpOInD-mXIppZiZA': ['Vitamins & Supplements',
#   'Shopping',
#   'Health Markets',
#   'Food',
#   'Weight Loss Centers',
#   'Specialty Food',
#   'Health & Medical'],
#  'XuVXu2OgjR79vcJUyP1KaQ': ['Movers', 'Home Services'],
#  'QRHeEcLrZBocsIV_tntIZA': ['Real Estate Services',
#   'Real Estate',
#   'Real Estate Agents',
#   'Home Services'],
#  'kKTXiGVLEVpPA7r2R6baVw': ['Beer Bar',
#   'Beer',
#   'Wine & Spirits',
#   'Restaurants',
#   'American (New)',
#   'Nightlife',
#   'Bars',
#   'Food'],
#  '8CCOH5A-ZNTgeK9rUOWejQ': ['Shopping', 'Musical Instruments & Teachers'],
#  'bbMYlQK4FxWh8mzZ2-2R-A': ['Shopping',
#   'Drugstores',
#   'Vitamins & Supplements'],
#  'q-DeyxfDo3AFjmghv5Gm1g': ['Restaurants', 'Indian', 'Kosher'],
#  'cs1qJvnWUg_f8g020z_3PQ': ['Tapas/Small Plates',
#   'Italian',
#   'Pizza',
#   'Restaurants'],
#  'Ro5Kduh_Y2D4L9tmIYibfg': ['Health & Medical', 'Midwives'],
#  'YfuL93FEOMxevS_ij8HyDg': ['Restaurants', 'Pizza'],
#  'rz_MbxHYHWwZMT-F5fgfUA': ['Barbeque',
#   'Filipino',
#   'Buffets',
#   'Fish & Chips',
#   'Restaurants'],
#  'lXCmTGagqHuPgaeN2g2P1Q': ['Restaurants', 'Pizza'],
#  'P9gT0PMDa6eNamPIwBdqbA': ['Health & Medical',
#   'Dentists',
#   'Endodontists',
#   'Cosmetic Dentists',
#   'General Dentistry'],
#  '3BvQZXfTlFxHSJXdvTn17w': ['Property Management',
#   'Real Estate',
#   'Apartments',
#   'Home Services'],
#  'jXzxNtgvFCd8RJPHLNBeDw': ['Veterinarians', 'Pet Stores', 'Pets'],
#  'tk7__jHNlFMsfShjv5CJNQ': ['American (Traditional)',
#   'Modern European',
#   'Ukrainian',
#   'Burgers',
#   'Barbeque',
#   'Imported Food',
#   'Mediterranean',
#   'Specialty Food',
#   'Food',
#   'Ethnic Food',
#   'Restaurants'],
#  'inMRWxx835CHwtVnxJPlLg': ['Heating & Air Conditioning/HVAC',
#   'Professional Services',
#   'Carpet Cleaning',
#   'Home Services',
#   'Home Cleaning',
#   'Air Duct Cleaning',
#   'Local Services'],
#  'tuELRpI9dIKY7p59MMernw': ['Sporting Goods',
#   'Sports Wear',
#   'Watches',
#   'Shopping',
#   'Fashion',
#   'Used',
#   'Vintage & Consignment',
#   'Accessories',
#   "Women's Clothing",
#   "Men's Clothing"],
#  '53HY4Wcj4p277C_UXdKqHg': ['Automotive',
#   'Mobile Phone Repair',
#   'Local Services',
#   'Shopping',
#   'Battery Stores',
#   'Lighting Fixtures & Equipment',
#   'IT Services & Computer Repair',
#   'Electronics Repair',
#   'Photography Stores & Services',
#   'Hardware Stores',
#   'Home Services',
#   'Motorcycle Dealers',
#   'Home & Garden',
#   'Electronics'],
#  'Idk-QTyUZq9w0ALh5cyvrw': ['Pizza',
#   'Restaurants',
#   'Italian',
#   'Chicken Wings'],
#  'e50AUC6C8NMh1KHxdpyznQ': ['Churches', 'Religious Organizations'],
#  '0txNpCq2YunZSL7jHIiGlA': ['Restaurants', 'French', 'Italian'],
#  'Go9aSrAlZfKtrbs535HZ6g': ['Chiropractors', 'Health & Medical'],
#  'tosKDTUz7f-gWEDjhDgBNg': ['Blow Dry/Out Services',
#   'Cosmetics & Beauty Supply',
#   'Beauty & Spas',
#   'Shopping',
#   'Hair Extensions',
#   'Hair Salons'],
#  'GmIUJmlwf3fJxFm79EZNgw': ['Shopping', 'Pawn Shops'],
#  'qL2LoSauX4IG2KHtQevFUw': ['Thai', 'Restaurants'],
#  'bxJ4xRv05vy7ClfsN8WOlA': ['Pet Stores',
#   'Pet Groomers',
#   'Pet Services',
#   'Pets'],
#  'Gp8_vPUZBncqy4Fwc8ga7A': ['Restaurants', 'Fast Food'],
#  'SEWFpFa9sVxWiNdk9oCbug': ['Event Planning & Services',
#   'Party & Event Planning',
#   'Venues & Event Spaces',
#   'Wedding Planning'],
#  'sZxvu5gI3KeaHh38QMuUfA': ['Yoga',
#   'Fitness & Instruction',
#   'Health & Medical',
#   'Massage Therapy',
#   'Active Life',
#   'Pilates'],
#  '1KbcmHmjwUN1OKKDi7xLnQ': ['Hobby Shops',
#   'Venues & Event Spaces',
#   'Event Planning & Services',
#   'Shopping'],
#  '2rwzeVlbMhkY3b2dZr4eOQ': ['Appliances & Repair',
#   'Local Services',
#   'Shopping',
#   'Department Stores',
#   'Fashion'],
#  '9E1q2uEMd881wnruicNTUA': ['Sports Bars',
#   'Nightlife',
#   'Chicken Wings',
#   'Restaurants',
#   'Bars',
#   'American (Traditional)'],
#  'fZ5jJ_TOJHeaRi5UBdRvYw': ['Restaurants', 'American (Traditional)'],
#  'Uh1d0u0zznX-_X7xLIaFZg': ['Eyewear & Opticians',
#   'Optometrists',
#   'Health & Medical',
#   'Shopping'],
#  'm62h9Zo78l_LmbYuOIGfzQ': ['Cosmetics & Beauty Supply',
#   'Beauty & Spas',
#   'Skin Care',
#   'Shopping',
#   'Hair Salons'],
#  'UDXof8_KofkMnZpO0Hn1ig': ['Yoga', 'Active Life', 'Fitness & Instruction'],
#  'OTMKPz-000UxEN-jBFMA9w': ['Local Flavor',
#   'Adult Entertainment',
#   'Bingo Halls',
#   'Nightlife',
#   'Arts & Entertainment',
#   'Casinos',
#   'Event Planning & Services',
#   'Venues & Event Spaces'],
#  'nxeeZnumQkrEFORtFpwSvA': ['Nightlife',
#   'Restaurants',
#   'Bars',
#   'Burgers',
#   'Delis'],
#  'mrTQDyURrL_THMp-nsVquQ': ['Pets', 'Pet Stores'],
#  '5G9aIrRiCD4TZCC5j2D39A': ['Bagels',
#   'Donuts',
#   'Coffee & Tea',
#   'Breakfast & Brunch',
#   'Restaurants',
#   'Food'],
#  'y85X24N89dQgbEfGNuj2WQ': ['Shopping', 'Outlet Stores', 'Shopping Centers'],
#  'yXgSKKxG4LDHXzpESmD-tw': ['Health & Medical', 'Medical Centers'],
#  'c5hK7QFeHpFBTam3N5i4hQ': ['Pet Groomers',
#   'Pets',
#   'Pet Sitting',
#   'Pet Services'],
#  'in8uc02eZJbPnDP2PWl8ig': ['Sewing & Alterations', 'Local Services'],
#  'lTU80hSQiTRLCelBkhEhkQ': ['Landscaping', 'Home Services'],
#  'aUh_NqYX0lvK6erjKfJn_A': ['Dentists',
#   'General Dentistry',
#   'Endodontists',
#   'Cosmetic Dentists',
#   'Health & Medical'],
#  '1us5qNogRwpeI1NkztKa1Q': ['Active Life', 'Amateur Sports Teams'],
#  '6LBMax_eriJaDs2qWQM3Kg': ['Parks', 'Active Life'],
#  'ljtJ8In8nEoLkotLwxguPg': ['Beauty & Spas', 'Hair Salons', 'Barbers'],
#  'Es8M4aIZ_KKPb6oUtcdSqw': ['Bars', 'Nightlife', 'Dive Bars'],
#  '6koDlaDeLdZ8ZAMCcQDpkg': ["Men's Clothing",
#   'Department Stores',
#   'Shopping',
#   'Plus Size Fashion',
#   'Fashion',
#   'Shoe Stores',
#   'Accessories'],
#  '0Vf9cMIIdH8uNLOtW-Dtjg': ['Beauty & Spas',
#   'Skin Care',
#   'Hair Removal',
#   'Hair Salons'],
#  'BxRsg5YTYnxXEhoGcabydg': ['Mexican', 'Restaurants', 'Food', 'Food Trucks'],
#  'KykaDerdKSmeiyX4L-82uA': ['Active Life',
#   'Trainers',
#   'Physical Therapy',
#   'Pilates',
#   'Health & Medical',
#   'Fitness & Instruction',
#   'Cardio Classes'],
#  'EJgC5p_-AxdHaxm9Dh0P5g': ['Auto Repair', 'Automotive'],
#  'TreYsBGjXptogQQmQh1-bg': ['Breakfast & Brunch',
#   'Greek',
#   'American (Traditional)',
#   'Restaurants',
#   'Mediterranean'],
#  'Ycp3Agr7dt71TZkeKV7jng': ['Restaurants',
#   'Desserts',
#   'Sandwiches',
#   'Cafes',
#   'French',
#   'Coffee & Tea',
#   'Food',
#   'Breakfast & Brunch'],
#  'us8NtNBTEm4k-GKrYKz4Dw': ['Beauty & Spas', 'Barbers', 'Hair Salons'],
#  'OqERAAmawmB0oIAQP8-Ezg': ['Acupuncture',
#   'Health & Medical',
#   'Naturopathic/Holistic',
#   'Nutritionists',
#   'Weight Loss Centers',
#   'Doctors'],
#  '7IoodTC2xwmBWvoFCP5urg': ['Waxing',
#   'Permanent Makeup',
#   'Day Spas',
#   'Skin Care',
#   'Beauty & Spas',
#   'Hair Removal'],
#  '8N5KG-iuAJrPVL6awBzBaQ': ['Gyms',
#   'Trainers',
#   'Active Life',
#   'Fitness & Instruction'],
#  'n9eudXq_35C0htRLtHZ2XQ': ['Beer',
#   'Wine & Spirits',
#   'Whiskey Bars',
#   'Coffee & Tea',
#   'Beer Bar',
#   'Breakfast & Brunch',
#   'Bars',
#   'Cocktail Bars',
#   'Food',
#   'Cafes',
#   'Wine Bars',
#   'Restaurants',
#   'Local Flavor',
#   'Nightlife'],
#  '5DVG0kea51olW0_kxNcD9g': ['Sports Bars',
#   'Nightlife',
#   'Bars',
#   'Chicken Wings',
#   'Restaurants',
#   'American (Traditional)'],
#  'Pmb9R4aEyMWVYCIStUZBTg': ['Motorcycle Dealers',
#   'Automotive',
#   'Motorcycle Repair'],
#  'jg72eKbD8rlv0i1DRN5uxQ': ['Video Game Stores',
#   'Videos & Video Game Rental',
#   'Shopping',
#   'Books',
#   'Mags',
#   'Music & Video',
#   'Hobby Shops'],
#  '22emEUJINj455l5gnWbDQg': ['Auto Parts & Supplies',
#   'Automotive',
#   'Car Dealers',
#   'Auto Repair'],
#  'J38n-oFC0V_PUo4qcTxang': ['Appliances & Repair', 'Local Services'],
#  '-DXRTcIIFSDFaec9SozG3A': ['African', 'Restaurants'],
#  'Wc0Leurb7WMVrP3KIZYiUw': ['Dentists', 'Health & Medical', 'Oral Surgeons'],
#  '6KgGE8B1RsR7jc9R5nuH0Q': ['American (Traditional)', 'Restaurants'],
#  'emyCP3Ry2SbpNrwRAtm9PQ': ['Restaurants',
#   'Hot Pot',
#   'Korean',
#   'Asian Fusion'],
#  ...}

# %%
len(set(stars_agg.keys())), len(set(ctgr_agg.keys()))
# Out:
# (148572, 192127)

# %%
### wrong!!!
# joined_dict = {} #{ctgr: (sum, len)}
# for bs_id, ctgrs in ctgr_agg.items():
#     for ctgr in ctgrs:
#         if bs_id in stars_agg:
#             if ctgr not in joined_dict:
#                 joined_dict[ctgr] = stars_agg[bs_id]
#             else:
#                 joined_dict[ctgr][0] += stars_agg[bs_id][0]
#                 joined_dict[ctgr][1] += stars_agg[bs_id][1]
# joined_dict

# %%
joined_dict = {}
for bs_id, s in stars_agg.items():
    if bs_id in ctgr_agg and ctgr_agg[bs_id]!=None:
#     if ctgr_agg.get(bs_id) is not None:
        for c in ctgr_agg[bs_id]:
            if c not in joined_dict:
                joined_dict[c] = s
            else:
#                 joined_dict[c][0] += s[0] # would change stars_agg too!!!
#                 joined_dict[c][1] += s[1]
                s1 = joined_dict[c][0] + s[0]
                s2 = joined_dict[c][1] + s[1]
                joined_dict[c] = [s1, s2]
joined_dict
# Out:
# {'Restaurants': [2692071.0, 723938],
#  'Breakfast & Brunch': [429101.0, 111793],
#  'Burgers': [243122.0, 68237],
#  'American (New)': [474471.0, 125765],
#  'Sports Bars': [94678.0, 28398],
#  'Bars': [701505.0, 189620],
#  'Nightlife': [764749.0, 206984],
#  'Hotels & Travel': [188699.0, 58590],
#  'Travel Services': [6508.0, 1962],
#  'Transportation': [16632.0, 5806],
#  'Party & Event Planning': [25931.0, 6485],
#  'Limos': [5366.0, 1511],
#  'Event Planning & Services': [339684.0, 93858],
#  'Fast Food': [127305.0, 39729],
#  'Vegetarian': [100819.0, 25279],
#  'Vegan': [79635.0, 19422],
#  'Indian': [52013.0, 13785],
#  'Sandwiches': [312779.0, 82244],
#  'Southern': [46690.0, 12329],
#  'Chicken Wings': [71525.0, 21603],
#  'Caterers': [101362.0, 26179],
#  'Polish': [4232.0, 1021],
#  'Delis': [62409.0, 16412],
#  'Pizza': [250471.0, 67599],
#  'Italian': [253095.0, 67463],
#  'Roofing': [2653.0, 688],
#  'Home Services': [180071.0, 49536],
#  'Custom Cakes': [7904.0, 2030],
#  'Food': [993364.0, 260209],
#  'Greek': [50906.0, 12909],
#  'Mediterranean': [95304.0, 23975],
#  'Cafes': [147477.0, 37440],
#  'Bakeries': [127377.0, 32278],
#  'Patisserie/Cake Shop': [8361.0, 2014],
#  'Cocktail Bars': [121374.0, 31327],
#  'Dance Clubs': [38674.0, 11624],
#  'Hobby Shops': [8011.0, 2042],
#  'Appliances': [9777.0, 3125],
#  'Home & Garden': [60701.0, 17049],
#  'Home Decor': [21800.0, 6096],
#  'Fabric Stores': [1739.0, 482],
#  'Sewing & Alterations': [10173.0, 2555],
#  'Shopping': [328911.0, 89270],
#  'Arts & Crafts': [15393.0, 3918],
#  'Local Services': [138162.0, 36108],
#  'Embroidery & Crochet': [725.0, 181],
#  'Floral Designers': [1730.0, 434],
#  'Florists': [12290.0, 3183],
#  'Flowers & Gifts': [25767.0, 6655],
#  'American (Traditional)': [456663.0, 126661],
#  'Ice Cream & Frozen Yogurt': [83610.0, 21381],
#  'Diners': [77819.0, 21306],
#  'Venues & Event Spaces': [88702.0, 23436],
#  'Arts & Entertainment': [257003.0, 71738],
#  'Video Game Stores': [1116.0, 292],
#  'Videos & Video Game Rental': [2622.0, 722],
#  'Books': [14026.0, 3525],
#  'Mags': [14026.0, 3525],
#  'Music & Video': [14026.0, 3525],
#  'Salad': [163452.0, 42776],
#  'Health & Medical': [164196.0, 43371],
#  'Dental Hygienists': [514.0, 118],
#  'Cosmetic Dentists': [22678.0, 5453],
#  'Orthodontists': [11805.0, 2886],
#  'Dentists': [34697.0, 8384],
#  'General Dentistry': [27791.0, 6754],
#  'Tapas Bars': [32602.0, 8273],
#  'Foundation Repair': [258.0, 81],
#  'Contractors': [31145.0, 7876],
#  'Waterproofing': [231.0, 73],
#  'Bubble Tea': [28073.0, 6980],
#  'Juice Bars & Smoothies': [77474.0, 19750],
#  'Taiwanese': [14141.0, 3862],
#  'Coffee & Tea': [226632.0, 58969],
#  'Mexican': [255872.0, 69345],
#  'Persian/Iranian': [6302.0, 1602],
#  'Beer': [117430.0, 30784],
#  'Wine & Spirits': [117430.0, 30784],
#  'Dive Bars': [19952.0, 5395],
#  'Steakhouses': [155904.0, 41608],
#  'Seafood': [224023.0, 58921],
#  'Canadian (New)': [55739.0, 15515],
#  'Barbeque': [113547.0, 29739],
#  'Performing Arts': [40786.0, 10180],
#  'Music Venues': [52271.0, 14223],
#  'Stadiums & Arenas': [6493.0, 1688],
#  'Cinema': [17545.0, 4913],
#  'Bagels': [22009.0, 6060],
#  'Desserts': [185760.0, 47053],
#  'Buffets': [78288.0, 22645],
#  'Latin American': [38357.0, 9540],
#  'Wine Bars': [103065.0, 26284],
#  'Shopping Centers': [16709.0, 4632],
#  'Resorts': [41772.0, 12750],
#  'Hotels': [127634.0, 39675],
#  'Automotive': [165002.0, 46367],
#  'Casinos': [81046.0, 25578],
#  'Car Wash': [20198.0, 6368],
#  'Specialty Food': [143909.0, 36240],
#  'Grocery': [61282.0, 16876],
#  'Ethnic Food': [45589.0, 11758],
#  'Whiskey Bars': [4608.0, 1182],
#  'Country Dance Halls': [1187.0, 353],
#  'Gastropubs': [62439.0, 16320],
#  'Asian Fusion': [157362.0, 41428],
#  'Malaysian': [5151.0, 1332],
#  'Thai': [89322.0, 23121],
#  'Singaporean': [2988.0, 801],
#  'Chinese': [159136.0, 45286],
#  'Do-It-Yourself Food': [7145.0, 1801],
#  'Live/Raw Food': [6542.0, 1625],
#  'Martial Arts': [4362.0, 1023],
#  'Fitness & Instruction': [49778.0, 12592],
#  'Active Life': [148604.0, 38220],
#  'Cajun/Creole': [25837.0, 6804],
#  'Vietnamese': [58822.0, 15524],
#  'Dim Sum': [19550.0, 5646],
#  'Japanese': [203598.0, 53347],
#  'Physical Therapy': [8098.0, 2059],
#  'Doctors': [52964.0, 15369],
#  'Sports Medicine': [4019.0, 1052],
#  'Family Practice': [6334.0, 2044],
#  'Tapas/Small Plates': [51422.0, 12863],
#  'Beauty & Spas': [295063.0, 74665],
#  'Nail Salons': [97098.0, 25598],
#  'Hawaiian': [32256.0, 7993],
#  'Pubs': [102710.0, 27990],
#  'Poutineries': [6246.0, 1628],
#  'Tex-Mex': [34528.0, 9883],
#  'Tacos': [27510.0, 6810],
#  'Soup': [55721.0, 14511],
#  'Massage Therapy': [23363.0, 5530],
#  'Gluten-Free': [66697.0, 17206],
#  'Noodles': [45618.0, 11687],
#  'Ramen': [29002.0, 7438],
#  'Middle Eastern': [48311.0, 12179],
#  'Sushi Bars': [165872.0, 43767],
#  'Pan Asian': [4093.0, 1159],
#  'Internet Service Providers': [3762.0, 1873],
#  'Television Service Providers': [2106.0, 1144],
#  'Professional Services': [57618.0, 15477],
#  'Utilities': [841.0, 402],
#  'Lounges': [97415.0, 26296],
#  'Landmarks & Historical Buildings': [5368.0, 1268],
#  'Public Services & Government': [15034.0, 4279],
#  'Local Flavor': [62801.0, 15925],
#  'Jazz & Blues': [7712.0, 1993],
#  'Creperies': [15520.0, 3829],
#  'Shipping Centers': [5869.0, 2083],
#  'Couriers & Delivery Services': [3591.0, 1078],
#  'Chiropractors': [11479.0, 2619],
#  'Osteopathic Physicians': [416.0, 132],
#  'Korean': [62532.0, 16304],
#  'Donuts': [25310.0, 6688],
#  'Poke': [15184.0, 3578],
#  'Tires': [30867.0, 8463],
#  'Wheel & Rim Repair': [7829.0, 1891],
#  'Auto Parts & Supplies': [35127.0, 10124],
#  'Reflexology': [10521.0, 2558],
#  'Day Spas': [73491.0, 18925],
#  'Food Trucks': [19291.0, 4634],
#  'Comedy Clubs': [5242.0, 1344],
#  'Massage': [45592.0, 11241],
#  'Skin Care': [65674.0, 15949],
#  'Health Markets': [16309.0, 4169],
#  'Cupcakes': [13699.0, 3476],
#  'Gas Stations': [11402.0, 3563],
#  'Golf': [10459.0, 2870],
#  'Dog Walkers': [2920.0, 636],
#  'Pet Sitting': [19364.0, 4752],
#  'Pet Services': [39915.0, 9825],
#  'Pets': [54330.0, 13540],
#  'Heating & Air Conditioning/HVAC': [17828.0, 4727],
#  'Zoos': [3992.0, 1038],
#  'Swimming Pools': [9970.0, 2753],
#  'Veterinarians': [20587.0, 5176],
#  'Web Design': [2551.0, 621],
#  'Cards & Stationery': [3409.0, 861],
#  'Printing Services': [8416.0, 2410],
#  'Bridal': [9121.0, 2278],
#  'Graphic Design': [3877.0, 918],
#  'Tours': [16868.0, 4156],
#  'Water Heater Installation/Repair': [8856.0, 2171],
#  'Water Purification Services': [3579.0, 917],
#  'Plumbing': [17854.0, 4585],
#  'Breweries': [44532.0, 11587],
#  'Waffles': [11399.0, 2933],
#  'Security Systems': [6043.0, 1619],
#  'Home Automation': [1850.0, 486],
#  'Pain Management': [1968.0, 530],
#  'Spine Surgeons': [244.0, 76],
#  'Orthopedists': [2388.0, 735],
#  'Surgeons': [1364.0, 376],
#  'Hair Salons': [92585.0, 22762],
#  'Cosmetics & Beauty Supply': [25826.0, 6944],
#  "Men's Hair Salons": [13902.0, 3202],
#  'Hair Stylists': [27441.0, 6332],
#  'Barbers': [28343.0, 6904],
#  'Eyelash Service': [40900.0, 9994],
#  'Fish & Chips': [13633.0, 3616],
#  'Peruvian': [5455.0, 1330],
#  'Halal': [22138.0, 5787],
#  'Comfort Food': [48402.0, 12789],
#  'Colleges & Universities': [2655.0, 791],
#  'Education': [30313.0, 7628],
#  'Pakistani': [18392.0, 4973],
#  'Beer Bar': [40242.0, 10323],
#  'Soccer': [496.0, 139],
#  'Sports Clubs': [6672.0, 1966],
#  'Boot Camps': [5330.0, 1229],
#  'Gyms': [28310.0, 7654],
#  'Weight Loss Centers': [7659.0, 1887],
#  'Interval Training Gyms': [3095.0, 673],
#  'Trainers': [22102.0, 5857],
#  'Movers': [12015.0, 3308],
#  'Bowling': [7177.0, 2163],
#  'Optometrists': [12829.0, 3328],
#  'Drugstores': [14955.0, 5134],
#  'Auto Detailing': [17262.0, 4954],
#  'Party Bus Rentals': [2391.0, 571],
#  'Airport Shuttles': [4921.0, 1579],
#  'Financial Services': [16142.0, 4960],
#  'Banks & Credit Unions': [5554.0, 2021],
#  'Outlet Stores': [4798.0, 1344],
#  'Fashion': [69637.0, 19999],
#  'Jewelry': [18113.0, 4490],
#  'Watches': [4432.0, 1065],
#  'Accessories': [15586.0, 4236],
#  'Arcades': [12383.0, 3472],
#  'Car Rental': [12280.0, 4599],
#  'Hakka': [768.0, 203],
#  'Adult Entertainment': [16307.0, 4751],
#  'Garage Door Services': [5672.0, 1322],
#  'Pet Cremation Services': [783.0, 180],
#  'Wholesale Stores': [5868.0, 1559],
#  'Photography Stores & Services': [4778.0, 1469],
#  'Department Stores': [19404.0, 6313],
#  'Eyewear & Opticians': [11078.0, 2900],
#  'Furniture Stores': [17844.0, 5402],
#  'Kitchen & Bath': [8268.0, 2201],
#  "Women's Clothing": [23356.0, 6679],
#  'Used': [7983.0, 2256],
#  'Vintage & Consignment': [7983.0, 2256],
#  'Parks': [15132.0, 3591],
#  'Playgrounds': [5615.0, 1384],
#  'Food Stands': [9680.0, 2368],
#  'Wedding Planning': [15366.0, 3902],
#  'Gelato': [10142.0, 2369],
#  'Sporting Goods': [21990.0, 5625],
#  'Shoe Stores': [11606.0, 3285],
#  'Outdoor Gear': [4960.0, 1296],
#  'Hunting & Fishing Supplies': [927.0, 259],
#  'Auto Repair': [88281.0, 24486],
#  'Oil Change Stations': [35319.0, 9911],
#  'Jewelry Repair': [4169.0, 928],
#  'Watch Repair': [3567.0, 804],
#  'Customized Merchandise': [1227.0, 300],
#  'Engraving': [501.0, 111],
#  'Internet Cafes': [6506.0, 1558],
#  'African': [6852.0, 1895],
#  'Solar Installation': [1900.0, 509],
#  'Home Energy Auditors': [712.0, 158],
#  'Building Supplies': [7376.0, 2135],
#  'Cheese Shops': [7068.0, 1700],
#  'Seafood Markets': [7816.0, 1990],
#  'Chocolatiers & Shops': [12987.0, 3238],
#  'Portuguese': [5242.0, 1399],
#  'Spanish': [17771.0, 4505],
#  'Cannabis Clinics': [3586.0, 923],
#  'Medical Cannabis Referrals': [309.0, 78],
#  'French': [71045.0, 17888],
#  'Lebanese': [9161.0, 2242],
#  'Wedding Chapels': [2415.0, 574],
#  'Aerial Fitness': [470.0, 107],
#  'Cantonese': [9410.0, 2645],
#  'Food Court': [3450.0, 975],
#  'Wraps': [11306.0, 2768],
#  'Urgent Care': [6275.0, 2116],
#  'Irish': [13164.0, 3698],
#  'Oral Surgeons': [9839.0, 2423],
#  'Bangladeshi': [441.0, 115],
#  'Waxing': [58342.0, 14081],
#  'Hair Removal': [83748.0, 20383],
#  'Smog Check Stations': [7179.0, 1789],
#  'Hair Extensions': [17396.0, 3992],
#  'Mini Golf': [2827.0, 746],
#  'Windshield Installation & Repair': [8801.0, 2197],
#  'Car Dealers': [39665.0, 12406],
#  'Keys & Locksmiths': [5902.0, 1349],
#  'Strip Clubs': [1731.0, 490],
#  'Hot Dogs': [27068.0, 7059],
#  'Tattoo': [14220.0, 3227],
#  'Pharmacy': [2625.0, 893],
#  'Damage Restoration': [5623.0, 1324],
#  'Office Cleaning': [6192.0, 1511],
#  'Carpet Cleaning': [12208.0, 2903],
#  'Air Duct Cleaning': [5249.0, 1224],
#  'Home Cleaning': [16379.0, 4085],
#  'Hospitals': [6148.0, 2164],
#  'Counseling & Mental Health': [2644.0, 720],
#  'Mobile Phone Repair': [10820.0, 2687],
#  'IT Services & Computer Repair': [18442.0, 5036],
#  'Mobile Phones': [13427.0, 4396],
#  'Data Recovery': [3330.0, 770],
#  'Dog Parks': [2433.0, 598],
#  'Pet Training': [7662.0, 1994],
#  'Pet Boarding': [5852.0, 1406],
#  'Pediatricians': [3854.0, 1183],
#  'Ethiopian': [3290.0, 805],
#  'Observatories': [508.0, 126],
#  'Vacation Rentals': [3032.0, 943],
#  'Pest Control': [8343.0, 2037],
#  'Window Washing': [3408.0, 813],
#  'Caribbean': [20453.0, 5204],
#  'Szechuan': [6537.0, 1762],
#  'New Mexican Cuisine': [14388.0, 3551],
#  'German': [9705.0, 2477],
#  'Luggage': [957.0, 251],
#  'Shoe Repair': [3289.0, 818],
#  'Brazilian': [11639.0, 3048],
#  'Interior Design': [5367.0, 1424],
#  'Tiling': [4683.0, 1078],
#  'Countertop Installation': [999.0, 249],
#  'Flooring': [8615.0, 2124],
#  'Auto Glass Services': [16196.0, 3847],
#  'Bikes': [7074.0, 1719],
#  'Bike Rentals': [4419.0, 1041],
#  'Bike Repair/Maintenance': [4130.0, 960],
#  'Mountain Biking': [1646.0, 376],
#  "Children's Clothing": [4355.0, 1293],
#  "Men's Clothing": [15716.0, 4553],
#  'Baby Gear & Furniture': [3207.0, 914],
#  'Employment Agencies': [2103.0, 679],
#  'Thrift Stores': [5310.0, 1580],
#  'Hookah Bars': [6963.0, 1866],
#  'Lingerie': [2691.0, 697],
#  'Adult': [2405.0, 586],
#  'Tobacco Shops': [11685.0, 2800],
#  'Meat Shops': [13114.0, 3141],
#  'Cheesesteaks': [11010.0, 2904],
#  'Auto Insurance': [2805.0, 710],
#  'Life Insurance': [1317.0, 314],
#  'Home & Rental Insurance': [2263.0, 573],
#  'Insurance': [5633.0, 1608],
#  'Medical Centers': [16236.0, 5127],
#  'Urologists': [398.0, 168],
#  'Pet Groomers': [24193.0, 6030],
#  'Airlines': [5274.0, 2193],
#  'Airports': [10123.0, 3247],
#  'Electronics': [17754.0, 5860],
#  'Antiques': [5417.0, 1371],
#  'Museums': [16140.0, 3913],
#  'Medical Spas': [17434.0, 4228],
#  'Laser Hair Removal': [8596.0, 2185],
#  'Festivals': [5526.0, 1540],
#  'Self Storage': [8735.0, 2396],
#  'Truck Rental': [1509.0, 488],
#  'Packing Supplies': [1095.0, 291],
#  'Makeup Artists': [20830.0, 4845],
#  'Body Shops': [17085.0, 4551],
#  'Auto Customization': [7175.0, 1593],
#  'Towing': [7615.0, 2175],
#  'Discount Store': [8194.0, 2747],
#  'Street Art': [1092.0, 233],
#  'Chicken Shop': [15846.0, 4483],
#  'Rugs': [1614.0, 466],
#  'Recreation Centers': [4999.0, 1218],
#  'Art Galleries': [11995.0, 2826],
#  'Art Museums': [2505.0, 589],
#  'Dermatologists': [3630.0, 1047],
#  'Tattoo Removal': [3197.0, 747],
#  'Wallpapering': [64.0, 14],
#  'Hardware Stores': [7010.0, 2190],
#  'Mortgage Brokers': [3953.0, 1231],
#  'Mortgage Lenders': [1253.0, 325],
#  'Real Estate': [39376.0, 12773],
#  'Bed & Breakfast': [2218.0, 623],
#  'Transmission Repair': [8548.0, 2046],
#  'Apartments': [18285.0, 6612],
#  'Electronics Repair': [10922.0, 2673],
#  'Computers': [8211.0, 2495],
#  'Art Classes': [2889.0, 661],
#  'Fruits & Veggies': [8864.0, 2187],
#  'Farms': [909.0, 234],
#  'Personal Chefs': [1634.0, 353],
#  'Food Delivery Services': [30805.0, 8157],
#  'Carpeting': [6955.0, 1727],
#  'Street Vendors': [13360.0, 3123],
#  'Cosmetic Surgeons': [5251.0, 1340],
#  'Plastic Surgeons': [1324.0, 307],
#  'Fences & Gates': [2053.0, 527],
#  'Patio Coverings': [1092.0, 269],
#  'Henna Artists': [1904.0, 420],
#  'Threading Services': [6811.0, 1578],
#  'Spray Tanning': [7234.0, 1626],
#  'Tanning': [13192.0, 3207],
#  'Candy Stores': [7890.0, 2054],
#  'Laser Eye Surgery/Lasik': [2556.0, 648],
#  'Taxis': [3541.0, 1295],
#  'Public Transportation': [2493.0, 840],
#  'Nutritionists': [6194.0, 1438],
#  'RV Parks': [610.0, 192],
#  'RV Repair': [1485.0, 429],
#  'Vacation Rental Agents': [297.0, 94],
#  'Campgrounds': [652.0, 184],
#  'Arabian': [2504.0, 614],
#  'Parking': [1802.0, 535],
#  'Public Markets': [1946.0, 441],
#  'Blow Dry/Out Services': [12009.0, 2716],
#  'Permanent Makeup': [8721.0, 1997],
#  'Internal Medicine': [2650.0, 840],
#  'Convenience Stores': [12670.0, 3866],
#  'Farmers Market': [12184.0, 2927],
#  'Wineries': [3486.0, 883],
#  'Pool & Hot Tub Service': [5444.0, 1406],
#  'Pool Cleaners': [5105.0, 1323],
#  'Safe Stores': [477.0, 114],
#  'Lighting Fixtures & Equipment': [3876.0, 996],
#  'Electricians': [5411.0, 1294],
#  'Amusement Parks': [18809.0, 5192],
#  'Social Clubs': [4829.0, 1456],
#  'Pasta Shops': [4059.0, 1040],
#  'Piano Bars': [2141.0, 597],
#  'Special Education': [736.0, 180],
#  'Argentine': [2651.0, 644],
#  'Auto Loan Providers': [1809.0, 614],
#  'Used Car Dealers': [6073.0, 1891],
#  'Tea Rooms': [19690.0, 4859],
#  'Imported Food': [9750.0, 2603],
#  'Party Equipment Rentals': [2558.0, 590],
#  'Laundry Services': [9662.0, 2797],
#  'Laundromat': [1394.0, 373],
#  'Dry Cleaning & Laundry': [9942.0, 2878],
#  'Immunodermatologists': [69.0, 20],
#  'Pulmonologist': [165.0, 54],
#  'Allergists': [1041.0, 329],
#  'Belgian': [3844.0, 1049],
#  'Leather Goods': [3729.0, 1047],
#  'Irish Pub': [5824.0, 1630],
#  'British': [14973.0, 3957],
#  'Community Service/Non-Profit': [5057.0, 1313],
#  'Yoga': [16110.0, 4087],
#  'Basque': [1240.0, 349],
#  'Marketing': [2818.0, 721],
#  'Ticket Sales': [1549.0, 398],
#  'Session Photography': [4090.0, 916],
#  'Event Photography': [4338.0, 950],
#  'Photographers': [7415.0, 1700],
#  'Photo Booth Rentals': [1241.0, 262],
#  'Refinishing Services': [2248.0, 492],
#  'Stucco Services': [694.0, 153],
#  'Cabinetry': [2355.0, 591],
#  'Painters': [4507.0, 1040],
#  'Kids Activities': [7913.0, 2033],
#  'Rock Climbing': [1765.0, 399],
#  'Trampoline Parks': [1820.0, 496],
#  'Professional Sports Teams': [1337.0, 337],
#  'Sports Wear': [6793.0, 1848],
#  'Art Supplies': [3087.0, 836],
#  'Vinyl Records': [1995.0, 483],
#  'Music & DVDs': [4023.0, 1026],
#  'Kosher': [3807.0, 962],
#  'Macarons': [3916.0, 948],
#  'Packing Services': [3506.0, 903],
#  'Furniture Assembly': [1053.0, 259],
#  'Smokehouse': [6341.0, 1608],
#  'Home Organization': [1830.0, 426],
#  'Child Care & Day Care': [5307.0, 1356],
#  'Preschools': [4173.0, 1060],
#  'Holiday Decorations': [361.0, 106],
#  'Funeral Services & Cemeteries': [1350.0, 362],
#  'Mortuary Services': [128.0, 31],
#  'Battery Stores': [626.0, 187],
#  'Appliances & Repair': [10287.0, 2882],
#  'Falafel': [3818.0, 945],
#  'Junk Removal & Hauling': [2741.0, 688],
#  'Pressure Washers': [3063.0, 671],
#  'Eyebrow Services': [10176.0, 2393],
#  'Teeth Whitening': [1705.0, 385],
#  'Coffee Roasteries': [8382.0, 1965],
#  'Formal Wear': [3230.0, 860],
#  'Plus Size Fashion': [1439.0, 389],
#  'Registration Services': [901.0, 228],
#  'Gay Bars': [3445.0, 965],
#  'Karaoke': [13984.0, 3751],
#  'Neurologist': [762.0, 276],
#  'Bus Tours': [1242.0, 336],
#  'Water Delivery': [627.0, 198],
#  'Water Stores': [484.0, 109],
#  'Specialty Schools': [16243.0, 3934],
#  'Comic Books': [2328.0, 551],
#  'Toy Stores': [6379.0, 1636],
#  'Brewpubs': [5531.0, 1445],
#  'Vape Shops': [6967.0, 1647],
#  'Head Shops': [2889.0, 675],
#  'International Grocery': [3209.0, 795],
#  'Neurotologists': [59.0, 16],
#  'Hearing Aid Providers': [388.0, 104],
#  'Audiologist': [612.0, 179],
#  'Puerto Rican': [1331.0, 319],
#  'Hot Pot': [6935.0, 1817],
#  'Vehicle Shipping': [533.0, 160],
#  'Rehabilitation Center': [1677.0, 489],
#  'Skilled Nursing': [218.0, 76],
#  'Motorcycle Repair': [3824.0, 982],
#  'Herbs & Spices': [2366.0, 551],
#  'Tax Services': [2098.0, 516],
#  'Payroll Services': [800.0, 187],
#  'Business Consulting': [647.0, 149],
#  'Accountants': [1876.0, 458],
#  'Mattresses': [8692.0, 2676],
#  'Eatertainment': [1237.0, 419],
#  'Modern European': [10891.0, 2667],
#  'Donairs': [1009.0, 254],
#  'Pediatric Dentists': [7704.0, 1818],
#  'Estheticians': [409.0, 89],
#  'Boat Dealers': [385.0, 109],
#  'Boat Repair': [567.0, 148],
#  'Gift Shops': [7687.0, 1965],
#  'Nurseries & Gardening': [7190.0, 2024],
#  'Escape Games': [5392.0, 1233],
#  'Endodontists': [6614.0, 1571],
#  'Clothing Rental': [395.0, 96],
#  'Turkish': [5426.0, 1387],
#  'Swimming Lessons/Schools': [1180.0, 280],
#  'Car Window Tinting': [6070.0, 1317],
#  'Home Window Tinting': [5339.0, 1170],
#  'Shades & Blinds': [4777.0, 1136],
#  'Ophthalmologists': [3987.0, 1112],
#  'Elementary Schools': [2663.0, 701],
#  'Montessori Schools': [237.0, 54],
#  'Adult Education': [1552.0, 422],
#  'Striptease Dancers': [527.0, 144],
#  'Pool Halls': [4568.0, 1308],
#  'Laser Tag': [1288.0, 341],
#  'Hot Tub & Pool': [3766.0, 1029],
#  'Landscaping': [10675.0, 2721],
#  'Climbing': [1654.0, 384],
#  'Bespoke Clothing': [2142.0, 515],
#  'Parenting Classes': [287.0, 64],
#  'Psychiatrists': [504.0, 172],
#  'Property Management': [6345.0, 2441],
#  'Handyman': [8095.0, 1898],
#  'Hungarian': [1172.0, 312],
#  'Door Sales/Installation': [3412.0, 879],
#  'Endocrinologists': [457.0, 157],
#  'Real Estate Services': [10553.0, 2996],
#  'Beer Gardens': [9554.0, 2445],
#  'Piercing': [8130.0, 1875],
#  'Party Supplies': [3764.0, 999],
#  'Guns & Ammo': [6633.0, 1623],
#  'Cannabis Dispensaries': [2729.0, 711],
#  'Naturopathic/Holistic': [5064.0, 1190],
#  'Soul Food': [20469.0, 5408],
#  'Motorcycle Dealers': [4017.0, 1068],
#  'Dry Cleaning': [3546.0, 976],
#  'Roadside Assistance': [1748.0, 476],
#  "Children's Museums": [680.0, 163],
#  'Outdoor Furniture Stores': [1091.0, 281],
#  'RV Dealers': [1524.0, 476],
#  'Basketball Courts': [246.0, 73],
#  'Customs Brokers': [23.0, 5],
#  'Brasseries': [7200.0, 1890],
#  'Ski & Snowboard Shops': [298.0, 75],
#  'Kebab': [2952.0, 775],
#  'Financial Advising': [1731.0, 470],
#  'Pet Stores': [14842.0, 3881],
#  'Cideries': [356.0, 82],
#  'Fire Protection Services': [638.0, 144],
#  'Golf Lessons': [691.0, 178],
#  'Acai Bowls': [5003.0, 1253],
#  'Grout Services': [2441.0, 514],
#  'Amateur Sports Teams': [2510.0, 660],
#  'Private Tutors': [711.0, 160],
#  'Knitting Supplies': [1127.0, 312],
#  'Personal Assistants': [593.0, 130],
#  'Bistros': [3969.0, 1038],
#  'Scottish': [130.0, 34],
#  'Distilleries': [2193.0, 514],
#  'Pilates': [5468.0, 1376],
#  'Team Building Activities': [3344.0, 755],
#  'Real Estate Agents': [7446.0, 1832],
#  'Obstetricians & Gynecologists': [4905.0, 1453],
#  'Bookstores': [6142.0, 1529],
#  'Barre Classes': [2568.0, 588],
#  'Moroccan': [2365.0, 584],
#  'Siding': [399.0, 121],
#  'Roof Inspectors': [185.0, 39],
#  'Bartenders': [466.0, 113],
#  'Motorcycle Rental': [427.0, 109],
#  'Screen Printing/T-Shirt Printing': [1429.0, 338],
#  'Uniforms': [976.0, 251],
#  'Piano Services': [485.0, 116],
#  'Musical Instruments & Teachers': [2814.0, 697],
#  'Guitar Stores': [747.0, 205],
#  'Musical Instrument Services': [1657.0, 424],
#  'Piano Stores': [115.0, 29],
#  'Nail Technicians': [4964.0, 1190],
#  'Coffee & Tea Supplies': [546.0, 131],
#  'Tree Services': [5313.0, 1287],
#  'Christmas Trees': [1442.0, 355],
#  'Legal Services': [1620.0, 388],
#  'Business Law': [585.0, 139],
#  'General Litigation': [1196.0, 289],
#  'Lawyers': [6485.0, 1583],
#  'Personal Injury Law': [3197.0, 757],
#  'Acupuncture': [5960.0, 1372],
#  'CPR Classes': [652.0, 142],
#  'Educational Services': [2564.0, 618],
#  'Laotian': [3121.0, 776],
#  'Religious Organizations': [4036.0, 945],
#  'Churches': [2790.0, 640],
#  'Historical Tours': [736.0, 162],
#  'Libraries': [2372.0, 584],
#  'Airport Lounges': [1064.0, 302],
#  'Holiday Decorating Services': [160.0, 37],
#  'Home Health Care': [1761.0, 503],
#  'Periodontists': [4400.0, 1075],
#  'Dance Studios': [3082.0, 694],
#  'Print Media': [1062.0, 288],
#  'Mass Media': [2242.0, 689],
#  'Bookbinding': [41.0, 9],
#  'Tennis': [1417.0, 425],
#  'Newspapers & Magazines': [479.0, 128],
#  'Delicatessen': [3053.0, 774],
#  'Butcher': [7588.0, 1798],
#  'Hydro-jetting': [1295.0, 311],
#  'Leisure Centers': [1463.0, 351],
#  'Hiking': [4878.0, 1087],
#  'Hydrotherapy': [512.0, 111],
#  'Sicilian': [86.0, 20],
#  'Business Financing': [98.0, 47],
#  'Tanning Beds': [2044.0, 487],
#  'Valet Services': [146.0, 45],
#  'Diagnostic Services': [4478.0, 1451],
#  'Diagnostic Imaging': [2510.0, 763],
#  'Radiologists': [1166.0, 391],
#  'Gun/Rifle Ranges': [5115.0, 1238],
#  'Pet Adoption': [2027.0, 545],
#  'Reiki': [2779.0, 610],
#  'Dance Schools': [1578.0, 364],
#  'Masonry/Concrete': [3027.0, 742],
#  'Chimney Sweeps': [281.0, 67],
#  'Fireplace Services': [726.0, 181],
#  'Irrigation': [3715.0, 901],
#  'Gardeners': [2854.0, 708],
#  'Gymnastics': [1048.0, 250],
#  'Skate Parks': [371.0, 91],
#  'Face Painting': [449.0, 93],
#  'Ethical Grocery': [541.0, 137],
#  'Cheese Tasting Classes': [212.0, 50],
#  'Tasting Classes': [942.0, 235],
#  'Emergency Rooms': [1390.0, 466],
#  'Train Stations': [321.0, 97],
#  'Ethnic Grocery': [1474.0, 350],
#  'Teppanyaki': [4890.0, 1241],
#  'Cycling Classes': [1966.0, 434],
#  'Knife Sharpening': [307.0, 66],
#  'Personal Shopping': [1976.0, 556],
#  'Paint & Sip': [1663.0, 364],
#  'Commercial Real Estate': [1468.0, 373],
#  'Midwives': [783.0, 202],
#  'Karate': [360.0, 81],
#  'Shaved Ice': [10307.0, 2424],
#  'Vehicle Wraps': [2665.0, 573],
#  'Sleep Specialists': [431.0, 118],
#  'Ear Nose & Throat': [892.0, 309],
#  'Cooking Classes': [1032.0, 252],
#  'Television Stations': [441.0, 182],
#  'Condominiums': [197.0, 69],
#  'Afghan': [3759.0, 966],
#  'Emergency Pet Hospital': [1798.0, 489],
#  'Home Inspectors': [3377.0, 807],
#  'Animal Shelters': [1978.0, 546],
#  'Vitamins & Supplements': [2794.0, 689],
#  'Gold Buyers': [1894.0, 427],
#  'Pawn Shops': [2313.0, 637],
#  'Septic Services': [1715.0, 413],
#  'Filipino': [9442.0, 2557],
#  'Summer Camps': [2278.0, 557],
#  'Tabletop Games': [1465.0, 350],
#  'Race Tracks': [919.0, 228],
#  'Advertising': [1296.0, 342],
#  'Shared Office Spaces': [793.0, 185],
#  'Drywall Installation & Repair': [2420.0, 538],
#  'Artificial Turf': [1266.0, 292],
#  'Botanical Gardens': [4216.0, 1034],
#  'Meditation Centers': [1137.0, 249],
#  'Sailing': [72.0, 23],
#  'RV Rental': [1121.0, 353],
#  'Scuba Diving': [429.0, 96],
#  'Diving': [452.0, 102],
#  'Dive Shops': [124.0, 28],
#  'Challenge Courses': [2675.0, 620],
#  'Career Counseling': [695.0, 192],
#  'Commercial Truck Repair': [967.0, 245],
#  'Cuban': [4285.0, 1104],
#  'Bartending Schools': [89.0, 22],
#  'Grilling Equipment': [253.0, 60],
#  'Car Brokers': [109.0, 27],
#  'Car Buyers': [868.0, 258],
#  'Radio Stations': [344.0, 110],
#  'Cambodian': [1360.0, 333],
#  'Livestock Feed & Supply': [297.0, 73],
#  'Fondue': [4759.0, 1182],
#  'Kickboxing': [910.0, 196],
#  'Boxing': [2535.0, 575],
#  'Mongolian': [3880.0, 1023],
#  'Windows Installation': [4240.0, 1059],
#  'Donation Center': [416.0, 128],
#  'Guest Houses': [532.0, 133],
#  'Tuscan': [1119.0, 278],
#  'Organic Stores': [6641.0, 1672],
#  'Coffeeshops': [754.0, 215],
#  'Traditional Chinese Medicine': [1761.0, 399],
#  'Propane': [521.0, 162],
#  'Haitian': [218.0, 52],
#  'Trailer Repair': [575.0, 137],
#  'Mobile Dent Repair': [1183.0, 281],
#  'Lakes': [1091.0, 251],
#  'Popcorn Shops': [1732.0, 387],
#  'Paintball': [435.0, 115],
#  'Tiki Bars': [2393.0, 562],
#  'Restaurant Supplies': [151.0, 41],
#  'Wholesalers': [949.0, 268],
#  'Skate Shops': [440.0, 110],
#  'Test Preparation': [515.0, 123],
#  'Boating': [1859.0, 459],
#  'Car Stereo Installation': [3383.0, 899],
#  'Auto Security': [1120.0, 274],
#  'Post Offices': [2150.0, 830],
#  'Orthotics': [526.0, 132],
#  'Shoe Shine': [394.0, 90],
#  'Nurse Practitioner': [225.0, 54],
#  'Psychologists': [170.0, 56],
#  'Car Share Services': [452.0, 130],
#  'Souvenir Shops': [1755.0, 430],
#  'Firearm Training': [958.0, 215],
#  'Medical Supplies': [1566.0, 446],
#  'Office Equipment': [2706.0, 863],
#  'Cooking Schools': [1354.0, 334],
#  'Middle Schools & High Schools': [1103.0, 303],
#  'Archery': [1079.0, 246],
#  'University Housing': [824.0, 312],
#  'Framing': [1153.0, 274],
#  'Notaries': [3811.0, 1080],
#  'Mailbox Centers': [2147.0, 648],
#  'Art Schools': [2120.0, 479],
#  'Departments of Motor Vehicles': [1714.0, 523],
#  'Golf Equipment': [926.0, 256],
#  'Fitness/Exercise Equipment': [910.0, 253],
#  'Kitchen Supplies': [52.0, 15],
#  'Wine Tasting Classes': [253.0, 63],
#  'Auto Upholstery': [656.0, 151],
#  'Mobile Phone Accessories': [4403.0, 1278],
#  'Videographers': [1368.0, 321],
#  'Landscape Architects': [2914.0, 725],
#  'Aquarium Services': [558.0, 137],
#  'Aquariums': [3484.0, 959],
#  'Kids Hair Salons': [975.0, 236],
#  'Cultural Center': [750.0, 184],
#  'Opera & Ballet': [682.0, 166],
#  'Himalayan/Nepalese': [2977.0, 734],
#  'Signmaking': [2387.0, 642],
#  'Occupational Therapy': [668.0, 206],
#  'Driving Schools': [1422.0, 355],
#  'Costumes': [1476.0, 408],
#  'Podiatrists': [1545.0, 391],
#  'Concierge Medicine': [170.0, 39],
#  'Laboratory Testing': [1446.0, 520],
#  'Shutters': [1457.0, 344],
#  'Pet Photography': [212.0, 46],
#  'Carpet Installation': [2282.0, 570],
#  'Cosmetology Schools': [2179.0, 606],
#  'Recording & Rehearsal Studios': [344.0, 81],
#  'Digitizing Services': [17.0, 5],
#  'Armenian': [393.0, 88],
#  'Burmese': [420.0, 99],
#  'Estate Planning Law': [943.0, 214],
#  'Wills': [447.0, 99],
#  'Trusts': [447.0, 99],
#  '& Probates': [447.0, 99],
#  'DJs': [1794.0, 424],
#  'Hostels': [1608.0, 438],
#  'Hats': [395.0, 105],
#  'Machine & Tool Rental': [113.0, 28],
#  'Animal Physical Therapy': [98.0, 24],
#  'Cardiologists': [840.0, 262],
#  'Doulas': [543.0, 118],
#  'Telecommunications': [2344.0, 791],
#  'Motorsport Vehicle Dealers': [238.0, 73],
#  'Walk-in Clinics': [735.0, 245],
#  'Beaches': [1646.0, 456],
#  'Glass & Mirrors': [2250.0, 548],
#  'TV Mounting': [1221.0, 263],
#  'Home Theatre Installation': [2019.0, 457],
#  'Metal Fabricators': [978.0, 245],
#  'Russian': [2234.0, 545],
#  'Gastroenterologist': [366.0, 122],
#  'Shanghainese': [467.0, 122],
#  'Candle Stores': [320.0, 86],
#  'Go Karts': [1444.0, 415],
#  'Wigs': [1318.0, 374],
#  'Bounce House Rentals': [286.0, 72],
#  'Party Characters': [307.0, 63],
#  'Editorial Services': [283.0, 62],
#  'Prosthetics': [187.0, 45],
#  'Hair Loss Centers': [944.0, 215],
#  'Speech Therapists': [250.0, 87],
#  'Airport Terminals': [511.0, 161],
#  'Champagne Bars': [1409.0, 364],
#  'Estate Liquidation': [239.0, 72],
#  'Maternity Wear': [578.0, 162],
#  'Carousels': [30.0, 7],
#  'Food Banks': [120.0, 25],
#  'Swimwear': [913.0, 248],
#  'Commercial Truck Dealers': [462.0, 151],
#  'Airsoft': [143.0, 38],
#  'Service Stations': [218.0, 73],
#  'Wine Tasting Room': [894.0, 216],
#  'Furniture Reupholstery': [2460.0, 581],
#  'Boat Charters': [571.0, 151],
#  'Marinas': [59.0, 15],
#  'Rafting/Kayaking': [1641.0, 368],
#  'Wildlife Control': [758.0, 167],
#  'Oxygen Bars': [577.0, 130],
#  'Ukrainian': [1099.0, 259],
#  'Auction Houses': [575.0, 172],
#  'Vocational & Technical School': [900.0, 243],
#  'Yelp Events': [1143.0, 260],
#  'Beach Bars': [44.0, 13],
#  'Beach Volleyball': [3.0, 1],
#  'Aestheticians': [425.0, 106],
#  'Hong Kong Style Cafe': [237.0, 81],
#  'Speakeasies': [1352.0, 342],
#  'Wine Tours': [510.0, 113],
#  'High Fidelity Audio Equipment': [342.0, 76],
#  'DUI Law': [1849.0, 434],
#  'Criminal Defense Law': [2278.0, 543],
#  'Motorcycle Gear': [1272.0, 367],
#  'Hospice': [307.0, 81],
#  'Title Loans': [506.0, 133],
#  'Check Cashing/Pay-day Loans': [924.0, 250],
#  'Installment Loans': [278.0, 88],
#  'Massage Schools': [378.0, 96],
#  'Disability Law': [52.0, 12],
#  'Social Security Law': [160.0, 42],
#  'Habilitative Services': [10.0, 2],
#  'Community Centers': [407.0, 107],
#  'Divorce & Family Law': [1679.0, 407],
#  'Tutoring Centers': [1014.0, 251],
#  'Officiants': [875.0, 188],
#  'Gutter Services': [984.0, 238],
#  'Brewing Supplies': [356.0, 81],
#  'Retina Specialists': [107.0, 31],
#  'Austrian': [395.0, 102],
#  'Disc Golf': [369.0, 85],
#  'Local Fish Stores': [540.0, 139],
#  'Horseback Riding': [1187.0, 293],
#  'Insulation Installation': [736.0, 202],
#  'Bookkeepers': [529.0, 123],
#  'Religious Schools': [129.0, 29],
#  'Cardio Classes': [1193.0, 305],
#  'Home Staging': [974.0, 224],
#  'Prenatal/Perinatal Care': [290.0, 67],
#  'Salvadoran': [1877.0, 476],
#  'Lactation Services': [595.0, 129],
#  'Immigration Law': [538.0, 132],
#  'Retirement Homes': [713.0, 205],
#  'Assisted Living Facilities': [278.0, 79],
#  'Indonesian': [1078.0, 275],
#  'Boudoir Photography': [442.0, 91],
#  'Pet Hospice': [275.0, 60],
#  'Hydroponics': [50.0, 13],
#  'Drive-In Theater': [340.0, 84],
#  'Screen Printing': [1242.0, 324],
#  'Ultrasound Imaging Centers': [112.0, 25],
#  'Blood & Plasma Donation Centers': [271.0, 91],
#  'Cabaret': [955.0, 242],
#  'Visitor Centers': [104.0, 22],
#  'Skating Rinks': [1106.0, 334],
#  'Pop-up Shops': [305.0, 71],
#  'Appraisal Services': [697.0, 162],
#  'Home Network Installation': [869.0, 184],
#  'Sugaring': [1366.0, 288],
#  'Body Contouring': [947.0, 233],
#  'Indoor Playcentre': [864.0, 198],
#  'Perfume': [85.0, 27],
#  'Skydiving': [671.0, 150],
#  'Used Bookstore': [417.0, 105],
#  'Hypnosis/Hypnotherapy': [601.0, 128],
#  'Paint Stores': [639.0, 181],
#  'Izakaya': [3335.0, 780],
#  'Golf Cart Rentals': [105.0, 24],
#  'Golf Cart Dealers': [52.0, 13],
#  'Furniture Repair': [629.0, 146],
#  'Courthouses': [252.0, 74],
#  'Pumpkin Patches': [169.0, 49],
#  'Oncologist': [324.0, 89],
#  'Carpenters': [492.0, 115],
#  'Public Relations': [317.0, 80],
#  'DIY Auto Shop': [85.0, 17],
#  'Recycling Center': [807.0, 232],
#  'First Aid Classes': [447.0, 96],
#  'Prosthodontists': [495.0, 111],
#  'Magicians': [2680.0, 652],
#  'Pet Transportation': [389.0, 87],
#  'Pole Dancing Classes': [284.0, 63],
#  'Security Services': [1289.0, 312],
#  'Gerontologists': [99.0, 22],
#  'Country Clubs': [659.0, 174],
#  'Muay Thai': [183.0, 41],
#  'Brazilian Jiu-jitsu': [520.0, 108],
#  'Colombian': [2770.0, 643],
#  'Empanadas': [982.0, 229],
#  'Misting System Services': [121.0, 30],
#  'Investing': [996.0, 290],
#  'Video/Film Production': [1386.0, 321],
#  'Cafeteria': [1161.0, 298],
#  'Vascular Medicine': [135.0, 34],
#  'Well Drilling': [14.0, 5],
#  'Lawn Services': [590.0, 148],
#  'Paddleboarding': [489.0, 107],
#  'Traffic Schools': [133.0, 32],
#  'Traffic Ticketing Law': [699.0, 156],
#  'Hazardous Waste Disposal': [62.0, 14],
#  'Environmental Abatement': [245.0, 57],
#  'Fertility': [858.0, 226],
#  'Colonics': [433.0, 105],
#  'Spiritual Shop': [824.0, 196],
#  'Musicians': [1803.0, 467],
#  'Music Production Services': [115.0, 25],
#  'Homeowner Association': [43.0, 17],
#  'Acne Treatment': [702.0, 177],
#  'Addiction Medicine': [158.0, 51],
#  'LAN Centers': [176.0, 38],
#  'Life Coach': [2074.0, 444],
#  'Decks & Railing': [477.0, 151],
#  'Balloon Services': [239.0, 56],
#  'Pretzels': [1995.0, 536],
#  'Nanny Services': [319.0, 69],
#  'Farming Equipment': [218.0, 61],
#  'Farm Equipment Repair': [170.0, 42],
#  'Bar Crawl': [430.0, 103],
#  'Supernatural Readings': [2883.0, 680],
#  'Psychics': [777.0, 174],
#  'Trailer Dealers': [226.0, 68],
#  'Venezuelan': [2608.0, 603],
#  'Saunas': [427.0, 95],
#  'Currency Exchange': [240.0, 60],
#  'Bankruptcy Law': [1294.0, 306],
#  'Real Estate Law': [810.0, 204],
#  'Float Spa': [856.0, 184],
#  'Personal Care Services': [159.0, 37],
#  'Elder Care Planning': [54.0, 14],
#  'Process Servers': [197.0, 46],
#  'Art Tours': [148.0, 36],
#  'Tui Na': [220.0, 47],
#  'Gunsmith': [343.0, 77],
#  'Ziplining': [458.0, 128],
#  'Product Design': [131.0, 29],
#  '3D Printing': [26.0, 8],
#  'Awnings': [542.0, 131],
#  'Axe Throwing': [443.0, 93],
#  'Trinidadian': [122.0, 28],
#  'Egyptian': [793.0, 202],
#  'Language Schools': [130.0, 30],
#  'Psychic Mediums': [311.0, 67],
#  'Boat Tours': [268.0, 72],
#  'Health Retreats': [1618.0, 400],
#  'Municipality': [29.0, 10],
#  'International': [1243.0, 335],
#  'Tai Chi': [332.0, 77],
#  'Tenant and Eviction Law': [46.0, 14],
#  'Medical Transportation': [340.0, 119],
#  'Holistic Animal Care': [179.0, 40],
#  'Racing Experience': [719.0, 164],
#  'Australian': [479.0, 124],
#  'Rotisserie Chicken': [90.0, 19],
#  'Sandblasting': [71.0, 18],
#  'Races & Competitions': [429.0, 118],
#  'CSA': [353.0, 84],
#  'Home Developers': [50.0, 20],
#  'Taekwondo': [275.0, 64],
#  'Paint-Your-Own Pottery': [444.0, 113],
#  'Beer Tours': [513.0, 116],
#  'Health Insurance Offices': [254.0, 68],
#  'Workers Compensation Law': [391.0, 93],
#  'Petting Zoos': [152.0, 36],
#  'Horse Boarding': [247.0, 57],
#  'Toxicologists': [6.0, 2],
#  'Embassy': [59.0, 19],
#  'Bingo Halls': [153.0, 40],
#  'Fire Departments': [32.0, 7],
#  'Dinner Theater': [850.0, 218],
#  'Fishing': [466.0, 113],
#  'Junkyards': [30.0, 11],
#  'Halotherapy': [164.0, 35],
#  'Sunglasses': [342.0, 82],
#  'Beverage Store': [1275.0, 308],
#  ...}

# %%
results_dict = {k: v[0]/v[1] for k,v in joined_dict.items()}
results_dict
# Out:
# {'Restaurants': 3.755635342376966,
#  'Breakfast & Brunch': 3.755635342376966,
#  'Burgers': 3.755635342376966,
#  'American (New)': 3.755635342376966,
#  'Sports Bars': 3.755635342376966,
#  'Bars': 3.755635342376966,
#  'Nightlife': 3.755635342376966,
#  'Hotels & Travel': 3.642283345882606,
#  'Travel Services': 3.642283345882606,
#  'Transportation': 3.642283345882606,
#  'Party & Event Planning': 3.642283345882606,
#  'Limos': 3.642283345882606,
#  'Event Planning & Services': 3.642283345882606,
#  'Fast Food': 3.7693775114226606,
#  'Vegetarian': 3.7693775114226606,
#  'Vegan': 3.7693775114226606,
#  'Indian': 3.7693775114226606,
#  'Sandwiches': 3.754745992658088,
#  'Southern': 3.754745992658088,
#  'Chicken Wings': 3.754745992658088,
#  'Caterers': 3.7871098693686345,
#  'Polish': 3.7871098693686345,
#  'Delis': 3.7643233325192407,
#  'Pizza': 3.7643233325192407,
#  'Italian': 3.7488106564117287,
#  'Roofing': 3.7243600748764787,
#  'Home Services': 3.7243600748764787,
#  'Custom Cakes': 3.7675351799691663,
#  'Food': 3.7675351799691663,
#  'Greek': 3.7675351799691663,
#  'Mediterranean': 3.7675351799691663,
#  'Cafes': 3.7675351799691663,
#  'Bakeries': 3.7675351799691663,
#  'Patisserie/Cake Shop': 3.7675351799691663,
#  'Cocktail Bars': 3.675553375983594,
#  'Dance Clubs': 3.675553375983594,
#  'Hobby Shops': 3.732270487275959,
#  'Appliances': 3.732270487275959,
#  'Home & Garden': 3.732270487275959,
#  'Home Decor': 3.732270487275959,
#  'Fabric Stores': 3.732270487275959,
#  'Sewing & Alterations': 3.732270487275959,
#  'Shopping': 3.732270487275959,
#  'Arts & Crafts': 3.732270487275959,
#  'Local Services': 3.732270487275959,
#  'Embroidery & Crochet': 3.732270487275959,
#  'Floral Designers': 3.760953535757591,
#  'Florists': 3.760953535757591,
#  'Flowers & Gifts': 3.760953535757591,
#  'American (Traditional)': 3.7491105336473236,
#  'Ice Cream & Frozen Yogurt': 3.927182380570512,
#  'Diners': 3.697818985564311,
#  'Venues & Event Spaces': 3.697818985564311,
#  'Arts & Entertainment': 3.697818985564311,
#  'Video Game Stores': 3.6678074080834024,
#  'Videos & Video Game Rental': 3.6678074080834024,
#  'Books': 3.6678074080834024,
#  'Mags': 3.6678074080834024,
#  'Music & Video': 3.6678074080834024,
#  'Salad': 3.7482713561137175,
#  'Health & Medical': 3.8690336865342743,
#  'Dental Hygienists': 3.8690336865342743,
#  'Cosmetic Dentists': 3.8690336865342743,
#  'Orthodontists': 3.8690336865342743,
#  'Dentists': 3.8690336865342743,
#  'General Dentistry': 3.8690336865342743,
#  'Tapas Bars': 3.786066342112425,
#  'Foundation Repair': 3.8549756141397142,
#  'Contractors': 3.8549756141397142,
#  'Waterproofing': 3.8549756141397142,
#  'Bubble Tea': 3.793130995256833,
#  'Juice Bars & Smoothies': 3.793130995256833,
#  'Taiwanese': 3.793130995256833,
#  'Coffee & Tea': 3.793130995256833,
#  'Mexican': 3.7677575708195845,
#  'Persian/Iranian': 3.9655902145850086,
#  'Beer': 3.756265960939056,
#  'Wine & Spirits': 3.756265960939056,
#  'Dive Bars': 3.756265960939056,
#  'Steakhouses': 3.756265960939056,
#  'Seafood': 3.756265960939056,
#  'Canadian (New)': 3.795799060966569,
#  'Barbeque': 3.8342883037107898,
#  'Performing Arts': 3.6724793864204712,
#  'Music Venues': 3.6724793864204712,
#  'Stadiums & Arenas': 3.6724793864204712,
#  'Cinema': 3.6724793864204712,
#  'Bagels': 3.643337183660611,
#  'Desserts': 3.7850744695678595,
#  'Buffets': 3.7463482634188026,
#  'Latin American': 3.806021204932602,
#  'Wine Bars': 3.806021204932602,
#  'Shopping Centers': 3.611825171013034,
#  'Resorts': 3.611825171013034,
#  'Hotels': 3.611825171013034,
#  'Automotive': 3.611825171013034,
#  'Casinos': 3.611825171013034,
#  'Car Wash': 3.611825171013034,
#  'Specialty Food': 3.760591947924302,
#  'Grocery': 3.760591947924302,
#  'Ethnic Food': 3.760591947924302,
#  'Whiskey Bars': 3.850502301043888,
#  'Country Dance Halls': 3.850502301043888,
#  'Gastropubs': 3.850502301043888,
#  'Asian Fusion': 3.7607336864203,
#  'Malaysian': 3.7607336864203,
#  'Thai': 3.7607336864203,
#  'Singaporean': 3.7607336864203,
#  'Chinese': 3.7607336864203,
#  'Do-It-Yourself Food': 3.926095751854349,
#  'Live/Raw Food': 4.093381686310064,
#  'Martial Arts': 3.8234157711176366,
#  'Fitness & Instruction': 3.8234157711176366,
#  'Active Life': 3.8234157711176366,
#  'Cajun/Creole': 3.814505121715278,
#  'Vietnamese': 3.814505121715278,
#  'Dim Sum': 3.761285188459394,
#  'Japanese': 3.761285188459394,
#  'Physical Therapy': 3.7514377556219642,
#  'Doctors': 3.7514377556219642,
#  'Sports Medicine': 3.7514377556219642,
#  'Family Practice': 3.7514377556219642,
#  'Tapas/Small Plates': 4.013303205761898,
#  'Beauty & Spas': 3.7613329361897527,
#  'Nail Salons': 3.7613329361897527,
#  'Hawaiian': 3.930296801993219,
#  'Pubs': 3.738345295460935,
#  'Poutineries': 3.8434221146085554,
#  'Tex-Mex': 3.7624049149899617,
#  'Tacos': 3.7624049149899617,
#  'Soup': 3.7882115299155656,
#  'Massage Therapy': 4.26465320989528,
#  'Gluten-Free': 3.863775268830953,
#  'Noodles': 3.7862037037037037,
#  'Ramen': 3.927928377266266,
#  'Middle Eastern': 3.7747078203645663,
#  'Sushi Bars': 3.778292186369884,
#  'Pan Asian': 3.5365160556976414,
#  'Internet Service Providers': 3.6648294288878533,
#  'Television Service Providers': 3.6648294288878533,
#  'Professional Services': 3.6648294288878533,
#  'Utilities': 3.6648294288878533,
#  'Lounges': 3.7436640209168655,
#  'Landmarks & Historical Buildings': 3.7634611217730454,
#  'Public Services & Government': 3.7634611217730454,
#  'Local Flavor': 3.7634611217730454,
#  'Jazz & Blues': 3.97974327480542,
#  'Creperies': 3.97974327480542,
#  'Shipping Centers': 3.332757569599675,
#  'Couriers & Delivery Services': 3.332757569599675,
#  'Chiropractors': 3.749382093403642,
#  'Osteopathic Physicians': 3.749382093403642,
#  'Korean': 3.766374131218407,
#  'Donuts': 3.7848706686188383,
#  'Poke': 3.984934447596412,
#  'Tires': 3.7061870929544107,
#  'Wheel & Rim Repair': 3.7061870929544107,
#  'Auto Parts & Supplies': 3.7061870929544107,
#  'Reflexology': 3.8518657055652965,
#  'Day Spas': 3.8518657055652965,
#  'Food Trucks': 4.20750264464155,
#  'Comedy Clubs': 3.4611339848206755,
#  'Massage': 4.150054924268322,
#  'Skin Care': 4.150054924268322,
#  'Health Markets': 4.058926351771286,
#  'Cupcakes': 3.9397195724629355,
#  'Gas Stations': 3.7483243261574684,
#  'Golf': 3.695662479260488,
#  'Dog Walkers': 4.047543734498402,
#  'Pet Sitting': 4.047543734498402,
#  'Pet Services': 4.047543734498402,
#  'Pets': 4.047543734498402,
#  'Heating & Air Conditioning/HVAC': 3.8108569231508627,
#  'Zoos': 3.9213686309054663,
#  'Swimming Pools': 3.9213686309054663,
#  'Veterinarians': 4.013012683248229,
#  'Web Design': 3.7175987247331435,
#  'Cards & Stationery': 3.7175987247331435,
#  'Printing Services': 3.7175987247331435,
#  'Bridal': 3.7175987247331435,
#  'Graphic Design': 3.7175987247331435,
#  'Tours': 3.684165700631669,
#  'Water Heater Installation/Repair': 3.714626124196549,
#  'Water Purification Services': 3.714626124196549,
#  'Plumbing': 3.714626124196549,
#  'Breweries': 3.9089182012478143,
#  'Waffles': 3.8837574262975,
#  'Security Systems': 3.703956981705535,
#  'Home Automation': 3.703956981705535,
#  'Pain Management': 3.750217039207747,
#  'Spine Surgeons': 3.750217039207747,
#  'Orthopedists': 3.750217039207747,
#  'Surgeons': 3.750217039207747,
#  'Hair Salons': 3.747896978782103,
#  'Cosmetics & Beauty Supply': 3.747896978782103,
#  "Men's Hair Salons": 3.747896978782103,
#  'Hair Stylists': 3.747896978782103,
#  'Barbers': 3.747896978782103,
#  'Eyelash Service': 4.145691200978841,
#  'Fish & Chips': 3.75240727532097,
#  'Peruvian': 3.9689580682389844,
#  'Halal': 3.8629387543551497,
#  'Comfort Food': 3.7461855636311165,
#  'Colleges & Universities': 3.911946623313926,
#  'Education': 3.911946623313926,
#  'Pakistani': 3.7562282813624988,
#  'Beer Bar': 3.8593634648511195,
#  'Soccer': 3.8742322192570002,
#  'Sports Clubs': 3.8742322192570002,
#  'Boot Camps': 3.792792359097702,
#  'Gyms': 3.792792359097702,
#  'Weight Loss Centers': 3.792792359097702,
#  'Interval Training Gyms': 3.792792359097702,
#  'Trainers': 3.792792359097702,
#  'Movers': 3.6251644795334115,
#  'Bowling': 3.3126409138734405,
#  'Optometrists': 3.799652189422991,
#  'Drugstores': 2.957611645694547,
#  'Auto Detailing': 3.406209632395918,
#  'Party Bus Rentals': 3.395177530344452,
#  'Airport Shuttles': 3.395177530344452,
#  'Financial Services': 3.479666972538663,
#  'Banks & Credit Unions': 3.479666972538663,
#  'Outlet Stores': 3.7200386769096725,
#  'Fashion': 3.7200386769096725,
#  'Jewelry': 3.695783562179382,
#  'Watches': 3.695783562179382,
#  'Accessories': 3.695783562179382,
#  'Arcades': 3.6137223471733826,
#  'Car Rental': 3.3728605110058885,
#  'Hakka': 3.7803660565723796,
#  'Adult Entertainment': 3.464483156013562,
#  'Garage Door Services': 4.28492739108663,
#  'Pet Cremation Services': 4.392441860465116,
#  'Wholesale Stores': 3.7097029016483796,
#  'Photography Stores & Services': 3.7097029016483796,
#  'Department Stores': 3.7097029016483796,
#  'Eyewear & Opticians': 3.7097029016483796,
#  'Furniture Stores': 3.7097029016483796,
#  'Kitchen & Bath': 3.7097029016483796,
#  "Women's Clothing": 3.6883284746390648,
#  'Used': 3.6883284746390648,
#  'Vintage & Consignment': 3.6883284746390648,
#  'Parks': 4.082778937510974,
#  'Playgrounds': 4.082778937510974,
#  'Food Stands': 4.076391371707782,
#  'Wedding Planning': 3.7881700949608654,
#  'Gelato': 3.7881700949608654,
#  'Sporting Goods': 3.773280616399917,
#  'Shoe Stores': 3.773280616399917,
#  'Outdoor Gear': 3.773280616399917,
#  'Hunting & Fishing Supplies': 3.773280616399917,
#  'Auto Repair': 3.5786956571129966,
#  'Oil Change Stations': 3.5786956571129966,
#  'Jewelry Repair': 4.23613595706619,
#  'Watch Repair': 4.23613595706619,
#  'Customized Merchandise': 4.23613595706619,
#  'Engraving': 4.23613595706619,
#  'Internet Cafes': 3.837490007993605,
#  'African': 3.837490007993605,
#  'Solar Installation': 3.767804797226683,
#  'Home Energy Auditors': 3.767804797226683,
#  'Building Supplies': 3.767804797226683,
#  'Cheese Shops': 4.018485211830535,
#  'Seafood Markets': 4.018485211830535,
#  'Chocolatiers & Shops': 4.018485211830535,
#  'Portuguese': 3.766124653890005,
#  'Spanish': 3.9729770349885776,
#  'Cannabis Clinics': 3.9872922776148583,
#  'Medical Cannabis Referrals': 3.9872922776148583,
#  'French': 3.9735376592064573,
#  'Lebanese': 4.02638773326994,
#  'Wedding Chapels': 4.191422594142259,
#  'Aerial Fitness': 4.372093023255814,
#  'Cantonese': 3.6113693998309384,
#  'Food Court': 3.9275398200874805,
#  'Wraps': 3.9275398200874805,
#  'Urgent Care': 2.9607796245366496,
#  'Irish': 3.7022489451992535,
#  'Oral Surgeons': 4.129271804579415,
#  'Bangladeshi': 3.798798798798799,
#  'Waxing': 4.15226969695307,
#  'Hair Removal': 4.15226969695307,
#  'Smog Check Stations': 4.040819901892081,
#  'Hair Extensions': 4.373870032406618,
#  'Mini Golf': 3.701897733263047,
#  'Windshield Installation & Repair': 3.393040055857423,
#  'Car Dealers': 3.461861780737021,
#  'Keys & Locksmiths': 4.370262390670554,
#  'Strip Clubs': 3.465810356247646,
#  'Hot Dogs': 3.859624925110018,
#  'Tattoo': 4.381701668675846,
#  'Pharmacy': 2.943361529974255,
#  'Damage Restoration': 4.069247750042452,
#  'Office Cleaning': 4.069247750042452,
#  'Carpet Cleaning': 4.069247750042452,
#  'Air Duct Cleaning': 4.069247750042452,
#  'Home Cleaning': 4.069247750042452,
#  'Hospitals': 3.1841051597794063,
#  'Counseling & Mental Health': 3.1841051597794063,
#  'Mobile Phone Repair': 3.7371236058190584,
#  'IT Services & Computer Repair': 3.7371236058190584,
#  'Mobile Phones': 3.7371236058190584,
#  'Data Recovery': 3.7371236058190584,
#  'Dog Parks': 4.02937968147771,
#  'Pet Training': 4.02937968147771,
#  'Pet Boarding': 4.02937968147771,
#  'Pediatricians': 3.2446376811594204,
#  'Ethiopian': 4.080215211543164,
#  'Observatories': 4.002481389578164,
#  'Vacation Rentals': 3.0805742155148614,
#  'Pest Control': 4.26925866821413,
#  'Window Washing': 4.26925866821413,
#  'Caribbean': 3.938443113772455,
#  'Szechuan': 3.938443113772455,
#  'New Mexican Cuisine': 3.938443113772455,
#  'German': 3.888755980861244,
#  'Luggage': 3.6227152721364746,
#  'Shoe Repair': 3.6227152721364746,
#  'Brazilian': 3.7919678055190538,
#  'Interior Design': 3.95915682830181,
#  'Tiling': 3.95915682830181,
#  'Countertop Installation': 3.95915682830181,
#  'Flooring': 3.95915682830181,
#  'Auto Glass Services': 3.6181091317155283,
#  'Bikes': 3.969843724564545,
#  'Bike Rentals': 3.969843724564545,
#  'Bike Repair/Maintenance': 3.969843724564545,
#  'Mountain Biking': 3.969843724564545,
#  "Children's Clothing": 3.6689957140725573,
#  "Men's Clothing": 3.6689957140725573,
#  'Baby Gear & Furniture': 3.6689957140725573,
#  'Employment Agencies': 3.636434833135437,
#  'Thrift Stores': 3.7241652274035695,
#  'Hookah Bars': 3.743781887755102,
#  'Lingerie': 4.01513998477991,
#  'Adult': 4.01513998477991,
#  'Tobacco Shops': 4.01513998477991,
#  'Meat Shops': 4.181350782893199,
#  'Cheesesteaks': 3.7823561946902653,
#  'Auto Insurance': 3.832647402850583,
#  'Life Insurance': 3.832647402850583,
#  'Home & Rental Insurance': 3.832647402850583,
#  'Insurance': 3.832647402850583,
#  'Medical Centers': 3.6401778051188427,
#  'Urologists': 3.6401778051188427,
#  'Pet Groomers': 4.05530970662027,
#  'Airlines': 3.490945487572056,
#  'Airports': 3.490945487572056,
#  'Electronics': 3.5921417736505235,
#  'Antiques': 3.8244059679498985,
#  'Museums': 4.158374073489986,
#  'Medical Spas': 4.010893442327776,
#  'Laser Hair Removal': 4.010893442327776,
#  'Festivals': 3.5897879705755082,
#  'Self Storage': 3.5944464988066023,
#  'Truck Rental': 3.5944464988066023,
#  'Packing Supplies': 3.5944464988066023,
#  'Makeup Artists': 4.044360460849783,
#  'Body Shops': 3.398120337003611,
#  'Auto Customization': 3.398120337003611,
#  'Towing': 3.398120337003611,
#  'Discount Store': 3.6434884063996136,
#  'Street Art': 4.686695278969957,
#  'Chicken Shop': 3.547879568046914,
#  'Rugs': 3.7502555366269164,
#  'Recreation Centers': 4.105327245053273,
#  'Art Galleries': 4.187210540654333,
#  'Art Museums': 4.187210540654333,
#  'Dermatologists': 3.8643941807369653,
#  'Tattoo Removal': 3.8643941807369653,
#  'Wallpapering': 3.7567434261228767,
#  'Hardware Stores': 3.7567434261228767,
#  'Mortgage Brokers': 3.232037397184506,
#  'Mortgage Lenders': 3.232037397184506,
#  'Real Estate': 3.232037397184506,
#  'Bed & Breakfast': 3.556498673740053,
#  'Transmission Repair': 4.141988600379987,
#  'Apartments': 3.0386019391817114,
#  'Electronics Repair': 3.7851438179307033,
#  'Computers': 3.7851438179307033,
#  'Art Classes': 3.9560413899794216,
#  'Fruits & Veggies': 3.9560413899794216,
#  'Farms': 3.9560413899794216,
#  'Personal Chefs': 3.865527936615267,
#  'Food Delivery Services': 3.865527936615267,
#  'Carpeting': 4.045199295309403,
#  'Street Vendors': 4.278193113614826,
#  'Cosmetic Surgeons': 3.838333651824957,
#  'Plastic Surgeons': 3.838333651824957,
#  'Fences & Gates': 3.9312178387650087,
#  'Patio Coverings': 3.9312178387650087,
#  'Henna Artists': 4.419657879977566,
#  'Threading Services': 4.419657879977566,
#  'Spray Tanning': 4.174984083954572,
#  'Tanning': 4.174984083954572,
#  'Candy Stores': 4.0420908780321145,
#  'Laser Eye Surgery/Lasik': 3.7522018567007853,
#  'Taxis': 3.396090753223806,
#  'Public Transportation': 3.396090753223806,
#  'Nutritionists': 3.9279172716648367,
#  'RV Parks': 3.39649816436035,
#  'RV Repair': 3.39649816436035,
#  'Vacation Rental Agents': 3.39649816436035,
#  'Campgrounds': 3.39649816436035,
#  'Arabian': 4.0654885654885655,
#  'Parking': 3.3963254593175853,
#  'Public Markets': 4.413059984813971,
#  'Blow Dry/Out Services': 4.388283126963593,
#  'Permanent Makeup': 4.238929817758821,
#  'Internal Medicine': 3.2485442844008583,
#  'Convenience Stores': 3.748580302115584,
#  'Farmers Market': 4.114953801682755,
#  'Wineries': 3.944037503662467,
#  'Pool & Hot Tub Service': 3.712343124344952,
#  'Pool Cleaners': 3.712343124344952,
#  'Safe Stores': 4.1503067484662575,
#  'Lighting Fixtures & Equipment': 3.8456140350877193,
#  'Electricians': 3.8456140350877193,
#  'Amusement Parks': 3.7417146834757724,
#  'Social Clubs': 3.19212808539026,
#  'Pasta Shops': 3.9234820322180917,
#  'Piano Bars': 3.6005763688760806,
#  'Special Education': 4.081632653061225,
#  'Argentine': 4.103484139365575,
#  'Auto Loan Providers': 3.196949994089136,
#  'Used Car Dealers': 3.196949994089136,
#  'Tea Rooms': 3.759485333641081,
#  'Imported Food': 3.759485333641081,
#  'Party Equipment Rentals': 3.523953649256313,
#  'Laundry Services': 3.5967597654308716,
#  'Laundromat': 3.5967597654308716,
#  'Dry Cleaning & Laundry': 3.5967597654308716,
#  'Immunodermatologists': 3.5889804946712247,
#  'Pulmonologist': 3.5889804946712247,
#  'Allergists': 3.5889804946712247,
#  'Belgian': 3.675104133290612,
#  'Leather Goods': 3.6742691270993157,
#  'Irish Pub': 3.737908342964503,
#  'British': 3.737908342964503,
#  'Community Service/Non-Profit': 3.782632855122247,
#  'Yoga': 3.9052907755127215,
#  'Basque': 3.554066985645933,
#  'Marketing': 4.075175715595396,
#  'Ticket Sales': 4.075175715595396,
#  'Session Photography': 3.669672046676943,
#  'Event Photography': 3.669672046676943,
#  'Photographers': 3.669672046676943,
#  'Photo Booth Rentals': 3.669672046676943,
#  'Refinishing Services': 3.9557385396000493,
#  'Stucco Services': 3.9557385396000493,
#  'Cabinetry': 3.9557385396000493,
#  'Painters': 3.9557385396000493,
#  'Kids Activities': 4.100868840752202,
#  'Rock Climbing': 4.100868840752202,
#  'Trampoline Parks': 4.100868840752202,
#  'Professional Sports Teams': 3.8810148062117933,
#  'Sports Wear': 3.8810148062117933,
#  'Art Supplies': 3.823036430706266,
#  'Vinyl Records': 3.997447894512973,
#  'Music & DVDs': 3.997447894512973,
#  'Kosher': 3.9907997169143665,
#  'Macarons': 4.135883424408014,
#  'Packing Services': 3.7991237387148167,
#  'Furniture Assembly': 3.7991237387148167,
#  'Smokehouse': 3.941725425134799,
#  'Home Organization': 4.208883553421368,
#  'Child Care & Day Care': 4.0283856226381936,
#  'Preschools': 4.0283856226381936,
#  'Holiday Decorations': 3.8277556440903053,
#  'Funeral Services & Cemeteries': 3.748587570621469,
#  'Mortuary Services': 3.748587570621469,
#  'Battery Stores': 3.620521019467695,
#  'Appliances & Repair': 3.6857217097570483,
#  'Falafel': 4.040974920522784,
#  'Junk Removal & Hauling': 4.395560989372708,
#  'Pressure Washers': 4.395560989372708,
#  'Eyebrow Services': 4.148072323242715,
#  'Teeth Whitening': 4.148072323242715,
#  'Coffee Roasteries': 4.2578336249403534,
#  'Formal Wear': 3.8203464457447427,
#  'Plus Size Fashion': 3.8203464457447427,
#  'Registration Services': 3.9695364238410598,
#  'Gay Bars': 3.697761974482326,
#  'Karaoke': 3.697761974482326,
#  'Neurologist': 2.773121387283237,
#  'Bus Tours': 3.7395121951219514,
#  'Water Delivery': 3.5988103106411105,
#  'Water Stores': 3.5988103106411105,
#  'Specialty Schools': 4.0530705412405075,
#  'Comic Books': 3.8721101017244193,
#  'Toy Stores': 3.8721101017244193,
#  'Brewpubs': 3.872291184515043,
#  'Vape Shops': 4.128923048769329,
#  'Head Shops': 4.128923048769329,
#  'International Grocery': 4.088526046873264,
#  'Neurotologists': 3.525096525096525,
#  'Hearing Aid Providers': 3.525096525096525,
#  'Audiologist': 3.525096525096525,
#  'Puerto Rican': 4.084409136047666,
#  'Hot Pot': 3.8238982113221462,
#  'Vehicle Shipping': 2.9311827956989247,
#  'Rehabilitation Center': 3.0653911676058185,
#  'Skilled Nursing': 3.0653911676058185,
#  'Motorcycle Repair': 3.7286828655967006,
#  'Herbs & Spices': 4.038218893727868,
#  'Tax Services': 4.129793932455638,
#  'Payroll Services': 4.129793932455638,
#  'Business Consulting': 4.129793932455638,
#  'Accountants': 4.129793932455638,
#  'Mattresses': 3.4267943305186974,
#  'Eatertainment': 2.9521149241819633,
#  'Modern European': 3.955864085801694,
#  'Donairs': 3.9646381578947367,
#  'Pediatric Dentists': 4.139982860285747,
#  'Estheticians': 4.5951417004048585,
#  'Boat Dealers': 3.778898696931484,
#  'Boat Repair': 3.778898696931484,
#  'Gift Shops': 3.717378226883276,
#  'Nurseries & Gardening': 3.717378226883276,
#  'Escape Games': 4.2681777378815084,
#  'Endodontists': 4.13411998862667,
#  'Clothing Rental': 3.820942830186679,
#  'Turkish': 3.7879667737576677,
#  'Swimming Lessons/Schools': 4.3512413512413515,
#  'Car Window Tinting': 4.589410187667561,
#  'Home Window Tinting': 4.589410187667561,
#  'Shades & Blinds': 4.110855752332027,
#  'Ophthalmologists': 3.684165781083953,
#  'Elementary Schools': 3.95372460496614,
#  'Montessori Schools': 3.95372460496614,
#  'Adult Education': 3.9362888239978764,
#  'Striptease Dancers': 3.9362888239978764,
#  'Pool Halls': 3.4900560938296787,
#  'Laser Tag': 3.6941418899028555,
#  'Hot Tub & Pool': 3.8550605414020924,
#  'Landscaping': 3.8550605414020924,
#  'Climbing': 4.312554112554112,
#  'Bespoke Clothing': 4.155827430779137,
#  'Parenting Classes': 3.7152826238660155,
#  'Psychiatrists': 3.7152826238660155,
#  'Property Management': 3.7806343988420874,
#  'Handyman': 3.7806343988420874,
#  'Hungarian': 3.776584317937701,
#  'Door Sales/Installation': 3.8838709677419354,
#  'Endocrinologists': 2.910064239828694,
#  'Real Estate Services': 3.672522873272338,
#  'Beer Gardens': 3.8838383838383836,
#  'Piercing': 4.3393258426966295,
#  'Party Supplies': 3.9345597897503284,
#  'Guns & Ammo': 4.121670081967213,
#  'Cannabis Dispensaries': 3.9507143838439345,
#  'Naturopathic/Holistic': 3.9507143838439345,
#  'Soul Food': 3.7909680434655604,
#  'Motorcycle Dealers': 3.683784853797862,
#  'Dry Cleaning': 3.737144585601936,
#  'Roadside Assistance': 3.68147120055517,
#  "Children's Museums": 4.1787941787941785,
#  'Outdoor Furniture Stores': 3.794475138121547,
#  'RV Dealers': 3.229636048526863,
#  'Basketball Courts': 3.3767441860465115,
#  'Customs Brokers': 4.6,
#  'Brasseries': 3.8282218091697646,
#  'Ski & Snowboard Shops': 4.037469671577578,
#  'Kebab': 3.9853538283062644,
#  'Financial Advising': 3.950670822604689,
#  'Pet Stores': 3.8292373857614623,
#  'Cideries': 4.330543933054393,
#  'Fire Protection Services': 4.349206349206349,
#  'Golf Lessons': 3.9069423929098965,
#  'Acai Bowls': 3.996617226125423,
#  'Grout Services': 4.160559737374407,
#  'Amateur Sports Teams': 3.8048780487804876,
#  'Private Tutors': 4.263293943870015,
#  'Knitting Supplies': 3.5893970893970892,
#  'Personal Assistants': 4.552356020942408,
#  'Bistros': 3.8696918223732104,
#  'Scottish': 3.869565217391304,
#  'Distilleries': 4.269685039370079,
#  'Pilates': 3.837984241628365,
#  'Team Building Activities': 4.241562064156207,
#  'Real Estate Agents': 4.068864706837745,
#  'Obstetricians & Gynecologists': 3.5145639594453497,
#  'Bookstores': 3.7775148952225246,
#  'Barre Classes': 4.328853422931541,
#  'Moroccan': 4.026470588235294,
#  'Siding': 3.691848906560636,
#  'Roof Inspectors': 3.691848906560636,
#  'Bartenders': 4.132132132132132,
#  'Motorcycle Rental': 3.7136844636844635,
#  'Screen Printing/T-Shirt Printing': 3.992581602373887,
#  'Uniforms': 3.992581602373887,
#  'Piano Services': 3.9019347998939837,
#  'Musical Instruments & Teachers': 3.9019347998939837,
#  'Guitar Stores': 3.9019347998939837,
#  'Musical Instrument Services': 3.9019347998939837,
#  'Piano Stores': 3.9019347998939837,
#  'Nail Technicians': 4.191686686407062,
#  'Coffee & Tea Supplies': 4.163682864450128,
#  'Tree Services': 4.02313232742758,
#  'Christmas Trees': 4.02313232742758,
#  'Legal Services': 4.133232640407011,
#  'Business Law': 4.133232640407011,
#  'General Litigation': 4.133232640407011,
#  'Lawyers': 4.133232640407011,
#  'Personal Injury Law': 4.133232640407011,
#  'Acupuncture': 3.8507068952946555,
#  'CPR Classes': 3.8507068952946555,
#  'Educational Services': 3.8507068952946555,
#  'Laotian': 4.057416267942584,
#  'Religious Organizations': 3.8129508850323095,
#  'Churches': 3.8129508850323095,
#  'Historical Tours': 3.8129508850323095,
#  'Libraries': 3.8129508850323095,
#  'Airport Lounges': 3.5212527964205815,
#  'Holiday Decorating Services': 4.192771084337349,
#  'Home Health Care': 3.382278481012658,
#  'Periodontists': 4.128578865174388,
#  'Dance Studios': 4.373118279569892,
#  'Print Media': 3.379857009636307,
#  'Mass Media': 3.379857009636307,
#  'Bookbinding': 3.379857009636307,
#  'Tennis': 3.711829612522453,
#  'Newspapers & Magazines': 3.714673913043478,
#  'Delicatessen': 4.1894660502221015,
#  'Butcher': 4.1894660502221015,
#  'Hydro-jetting': 3.939197166469894,
#  'Leisure Centers': 4.292553191489362,
#  'Hiking': 4.500143636885952,
#  'Hydrotherapy': 3.437753036437247,
#  'Sicilian': 4.636363636363637,
#  'Business Financing': 3.5054617676266138,
#  'Tanning Beds': 4.163061775082436,
#  'Valet Services': 3.216,
#  'Diagnostic Services': 3.120159214700425,
#  'Diagnostic Imaging': 3.120159214700425,
#  'Radiologists': 3.120159214700425,
#  'Gun/Rifle Ranges': 4.120885787956924,
#  'Pet Adoption': 3.816172564020827,
#  'Reiki': 4.1147368421052635,
#  'Dance Schools': 4.086782757636311,
#  'Masonry/Concrete': 4.060798717777481,
#  'Chimney Sweeps': 4.060798717777481,
#  'Fireplace Services': 4.060798717777481,
#  'Irrigation': 4.144359626802375,
#  'Gardeners': 4.144359626802375,
#  'Gymnastics': 4.171213546566322,
#  'Skate Parks': 4.171213546566322,
#  'Face Painting': 4.808764940239044,
#  'Ethical Grocery': 3.911032028469751,
#  'Cheese Tasting Classes': 4.122191863995143,
#  'Tasting Classes': 4.122191863995143,
#  'Emergency Rooms': 2.9741379310344827,
#  'Train Stations': 3.464818763326226,
#  'Ethnic Grocery': 4.101874490627547,
#  'Teppanyaki': 3.9444893559687415,
#  'Cycling Classes': 4.5326842837273995,
#  'Knife Sharpening': 4.632075471698113,
#  'Personal Shopping': 3.7874564459930316,
#  'Paint & Sip': 4.566298342541437,
#  'Commercial Real Estate': 3.9371069182389937,
#  'Midwives': 4.140081799591002,
#  'Karate': 4.435146443514644,
#  'Shaved Ice': 4.256096066658498,
#  'Vehicle Wraps': 3.757615167340635,
#  'Sleep Specialists': 3.6204525923804067,
#  'Ear Nose & Throat': 3.6204525923804067,
#  'Cooking Classes': 4.0906666666666665,
#  'Television Stations': 2.407749077490775,
#  'Condominiums': 2.8805970149253732,
#  'Afghan': 3.891078838174274,
#  'Emergency Pet Hospital': 3.681537405628003,
#  'Home Inspectors': 4.173406193078324,
#  'Animal Shelters': 3.7470468431771895,
#  'Vitamins & Supplements': 4.217106984043944,
#  'Gold Buyers': 4.031657805703238,
#  'Pawn Shops': 4.031657805703238,
#  'Septic Services': 4.132906325060048,
#  'Filipino': 3.69320690998831,
#  'Summer Camps': 4.079514080618443,
#  'Tabletop Games': 4.141040315401247,
#  'Race Tracks': 4.141040315401247,
#  'Advertising': 4.141040315401247,
#  'Shared Office Spaces': 4.290676416819013,
#  'Drywall Installation & Repair': 4.471351173863076,
#  'Artificial Turf': 4.471351173863076,
#  'Botanical Gardens': 4.096292878018766,
#  'Meditation Centers': 4.571155682903534,
#  'Sailing': 3.813953488372093,
#  'RV Rental': 3.212931453573165,
#  'Scuba Diving': 4.522189349112426,
#  'Diving': 4.522189349112426,
#  'Dive Shops': 4.522189349112426,
#  'Challenge Courses': 4.065337001375516,
#  'Career Counseling': 3.817191283292978,
#  'Commercial Truck Repair': 3.940151515151515,
#  'Cuban': 3.879915305505142,
#  'Bartending Schools': 3.9423076923076925,
#  'Grilling Equipment': 4.244318181818182,
#  'Car Brokers': 3.38159509202454,
#  'Car Buyers': 3.38159509202454,
#  'Radio Stations': 3.1165644171779143,
#  'Cambodian': 4.084762865792129,
#  'Livestock Feed & Supply': 4.0691244239631335,
#  'Fondue': 3.9406764495347173,
#  'Kickboxing': 4.474803149606299,
#  'Boxing': 4.474803149606299,
#  'Mongolian': 3.8935527706477426,
#  'Windows Installation': 4.031347962382445,
#  'Donation Center': 3.2751322751322753,
#  'Guest Houses': 3.989873417721519,
#  'Tuscan': 4.0229468599033815,
#  'Organic Stores': 4.027593732948788,
#  'Coffeeshops': 3.4880763116057234,
#  'Traditional Chinese Medicine': 4.298327137546468,
#  'Propane': 3.3778672032193158,
#  'Haitian': 4.149253731343284,
#  'Trailer Repair': 4.209716599190283,
#  'Mobile Dent Repair': 4.209716599190283,
#  'Lakes': 4.351633986928104,
#  'Popcorn Shops': 4.476190476190476,
#  'Paintball': 3.8069164265129682,
#  'Tiki Bars': 4.2749077490774905,
#  'Restaurant Supplies': 3.9455488331892825,
#  'Wholesalers': 3.9455488331892825,
#  'Skate Shops': 4.376237623762377,
#  'Test Preparation': 4.110970996216897,
#  'Boating': 3.925583443416997,
#  'Car Stereo Installation': 3.832104487044449,
#  'Auto Security': 3.832104487044449,
#  'Post Offices': 3.2814935787989015,
#  'Orthotics': 3.9742489270386265,
#  'Shoe Shine': 4.396946564885496,
#  'Nurse Practitioner': 3.6564245810055866,
#  'Psychologists': 3.6564245810055866,
#  'Car Share Services': 3.5819209039548023,
#  'Souvenir Shops': 4.218779790276454,
#  'Firearm Training': 4.218779790276454,
#  'Medical Supplies': 3.996702468437912,
#  'Office Equipment': 3.1407093292212798,
#  'Cooking Schools': 4.069738070397013,
#  'Middle Schools & High Schools': 3.7872768418405833,
#  'Archery': 4.3940677966101696,
#  'University Housing': 2.648068669527897,
#  'Framing': 4.178654292343388,
#  'Notaries': 3.5156763478106403,
#  'Mailbox Centers': 3.5156763478106403,
#  'Art Schools': 4.405460750853242,
#  'Departments of Motor Vehicles': 3.3216019417475726,
#  'Golf Equipment': 3.6370798319327733,
#  'Fitness/Exercise Equipment': 3.6370798319327733,
#  'Kitchen Supplies': 3.935483870967742,
#  'Wine Tasting Classes': 4.0162162162162165,
#  'Auto Upholstery': 4.260011954572624,
#  'Mobile Phone Accessories': 3.4465031315240084,
#  'Videographers': 4.317162698412698,
#  'Landscape Architects': 4.01105436227524,
#  'Aquarium Services': 3.6975817923186343,
#  'Aquariums': 3.6975817923186343,
#  'Kids Hair Salons': 4.128895184135978,
#  'Cultural Center': 4.238198354265916,
#  'Opera & Ballet': 4.238198354265916,
#  'Himalayan/Nepalese': 4.051787351054079,
#  'Signmaking': 3.797847138522921,
#  'Occupational Therapy': 3.37821482602118,
#  'Driving Schools': 3.7757656458055924,
#  'Costumes': 3.824013123741097,
#  'Podiatrists': 3.9564474807856533,
#  'Concierge Medicine': 4.4672897196261685,
#  'Laboratory Testing': 2.9280117531831538,
#  'Shutters': 4.156853830416003,
#  'Pet Photography': 4.691275167785235,
#  'Carpet Installation': 4.154302670623146,
#  'Cosmetology Schools': 3.617837338262477,
#  'Recording & Rehearsal Studios': 4.24892703862661,
#  'Digitizing Services': 3.5454545454545454,
#  'Armenian': 4.4125,
#  'Burmese': 4.233676975945017,
#  'Estate Planning Law': 4.2493628769644625,
#  'Wills': 4.2493628769644625,
#  'Trusts': 4.2493628769644625,
#  '& Probates': 4.2493628769644625,
#  'DJs': 4.027335872731347,
#  'Hostels': 3.6594427244582044,
#  'Hats': 3.753993610223642,
#  'Machine & Tool Rental': 4.291666666666667,
#  'Animal Physical Therapy': 4.0,
#  'Cardiologists': 3.1923076923076925,
#  'Doulas': 4.55902004454343,
#  'Telecommunications': 2.880190095047524,
#  'Motorsport Vehicle Dealers': 3.2203389830508473,
#  'Walk-in Clinics': 3.0388349514563107,
#  'Beaches': 3.8486238532110093,
#  'Glass & Mirrors': 4.094827586206897,
#  'TV Mounting': 4.2135871001850385,
#  'Home Theatre Installation': 4.2135871001850385,
#  'Metal Fabricators': 3.9863201094391245,
#  'Russian': 4.1198129748684975,
#  'Gastroenterologist': 2.977900552486188,
#  'Shanghainese': 3.8254437869822486,
#  'Candle Stores': 3.6984126984126986,
#  'Go Karts': 3.6637605347282767,
#  'Wigs': 3.5610200364298725,
#  'Bounce House Rentals': 4.383720930232558,
#  'Party Characters': 4.383720930232558,
#  'Editorial Services': 4.583333333333333,
#  'Prosthetics': 3.9920844327176783,
#  'Hair Loss Centers': 4.386895475819033,
#  'Speech Therapists': 2.9392857142857145,
#  'Airport Terminals': 3.207188160676533,
#  'Champagne Bars': 3.8688073394495412,
#  'Estate Liquidation': 3.3411214953271027,
#  'Maternity Wear': 3.5869120654396727,
#  'Carousels': 3.8181818181818183,
#  'Food Banks': 3.7626587497938315,
#  'Swimwear': 3.7087628865979383,
#  'Commercial Truck Dealers': 3.641086186540732,
#  'Airsoft': 3.8636363636363638,
#  'Service Stations': 3.0046082949308754,
#  'Wine Tasting Room': 3.9794628751974725,
#  'Furniture Reupholstery': 4.247408742676882,
#  'Boat Charters': 3.821722043586995,
#  'Marinas': 3.821722043586995,
#  'Rafting/Kayaking': 4.491155660377358,
#  'Wildlife Control': 4.531440162271806,
#  'Oxygen Bars': 4.519607843137255,
#  'Ukrainian': 4.227332457293035,
#  'Auction Houses': 3.7409988385598143,
#  'Vocational & Technical School': 3.636868406440866,
#  'Yelp Events': 4.388311688311688,
#  'Beach Bars': 3.4054054054054053,
#  'Beach Volleyball': 3.4054054054054053,
#  'Aestheticians': 3.9768211920529803,
#  'Hong Kong Style Cafe': 2.957805907172996,
#  'Speakeasies': 3.9486166007905137,
#  'Wine Tours': 4.369221767115272,
#  'High Fidelity Audio Equipment': 4.495575221238938,
#  'DUI Law': 4.149320148331273,
#  'Criminal Defense Law': 4.149320148331273,
#  'Motorcycle Gear': 3.459360730593607,
#  'Hospice': 3.803347280334728,
#  'Title Loans': 3.9132630328234073,
#  'Check Cashing/Pay-day Loans': 3.9132630328234073,
#  'Installment Loans': 3.9132630328234073,
#  'Massage Schools': 3.9571428571428573,
#  'Disability Law': 3.908594815825375,
#  'Social Security Law': 3.908594815825375,
#  'Habilitative Services': 3.908594815825375,
#  'Community Centers': 3.908594815825375,
#  'Divorce & Family Law': 4.232094288304624,
#  'Tutoring Centers': 4.046610169491525,
#  'Officiants': 4.680357142857143,
#  'Gutter Services': 3.972732843137255,
#  'Brewing Supplies': 4.384937238493724,
#  'Retina Specialists': 3.5185185185185186,
#  'Austrian': 3.9125874125874125,
#  'Disc Golf': 4.297071129707113,
#  'Local Fish Stores': 3.957767722473605,
#  'Horseback Riding': 4.081335061568374,
#  'Insulation Installation': 3.6345514950166113,
#  'Bookkeepers': 4.3188010899182565,
#  'Religious Schools': 4.518072289156627,
#  'Cardio Classes': 4.14415820973198,
#  'Home Staging': 4.347305389221557,
#  'Prenatal/Perinatal Care': 4.453608247422681,
#  'Salvadoran': 3.9471279373368144,
#  'Lactation Services': 4.489905787348587,
#  'Immigration Law': 4.179032258064516,
#  'Retirement Homes': 3.6440217391304346,
#  'Assisted Living Facilities': 3.6440217391304346,
#  'Indonesian': 3.9173754556500606,
#  'Boudoir Photography': 4.853932584269663,
#  'Pet Hospice': 4.563953488372093,
#  'Hydroponics': 3.8378378378378377,
#  'Drive-In Theater': 4.133333333333334,
#  'Screen Printing': 3.8285123966942147,
#  'Ultrasound Imaging Centers': 4.450704225352113,
#  'Blood & Plasma Donation Centers': 3.0,
#  'Cabaret': 3.9433701657458564,
#  'Visitor Centers': 3.4107806691449816,
#  'Skating Rinks': 3.4107806691449816,
#  'Pop-up Shops': 4.301435406698564,
#  'Appraisal Services': 4.299586776859504,
#  'Home Network Installation': 3.9032285763352226,
#  'Sugaring': 4.749419953596288,
#  'Body Contouring': 4.238498789346247,
#  'Indoor Playcentre': 4.365853658536586,
#  'Perfume': 3.1012658227848102,
#  'Skydiving': 4.651355421686747,
#  'Used Bookstore': 4.010169491525423,
#  'Hypnosis/Hypnotherapy': 4.693717277486911,
#  'Paint Stores': 3.813284143864261,
#  'Izakaya': 4.274568965517242,
#  'Golf Cart Rentals': 4.2075471698113205,
#  'Golf Cart Dealers': 4.2075471698113205,
#  'Furniture Repair': 4.238194444444445,
#  'Courthouses': 3.7905027932960893,
#  'Pumpkin Patches': 3.69775264815345,
#  'Oncologist': 3.630188679245283,
#  'Carpenters': 4.28486646884273,
#  'Public Relations': 4.168846815834768,
#  'DIY Auto Shop': 5.0,
#  'Recycling Center': 3.46056338028169,
#  'First Aid Classes': 4.697080291970803,
#  'Prosthodontists': 4.480362537764351,
#  'Magicians': 4.110655737704918,
#  'Pet Transportation': 4.4903474903474905,
#  'Pole Dancing Classes': 4.4972972972972975,
#  'Security Services': 4.307794508414526,
#  'Gerontologists': 4.484375,
#  'Country Clubs': 3.7972972972972974,
#  'Muay Thai': 4.69727626459144,
#  'Brazilian Jiu-jitsu': 4.69727626459144,
#  'Colombian': 4.306757239899893,
#  'Empanadas': 4.306757239899893,
#  'Misting System Services': 3.9642857142857144,
#  'Investing': 3.5982525814138206,
#  'Video/Film Production': 3.924368979392757,
#  'Cafeteria': 3.890765765765766,
#  'Vascular Medicine': 4.03,
#  'Well Drilling': 2.4615384615384617,
#  'Lawn Services': 4.0030923280812845,
#  'Paddleboarding': 4.555977229601518,
#  'Traffic Schools': 4.426315789473684,
#  'Traffic Ticketing Law': 4.426315789473684,
#  'Hazardous Waste Disposal': 4.40377358490566,
#  'Environmental Abatement': 4.40377358490566,
#  'Fertility': 3.7928994082840237,
#  'Colonics': 4.147540983606557,
#  'Spiritual Shop': 3.711308151941955,
#  'Musicians': 3.925864909390445,
#  'Music Production Services': 3.925864909390445,
#  'Homeowner Association': 2.3488372093023258,
#  'Acne Treatment': 3.946257197696737,
#  'Addiction Medicine': 3.1347517730496453,
#  'LAN Centers': 4.618181818181818,
#  'Life Coach': 4.357462019660411,
#  'Decks & Railing': 3.1507760532150777,
#  'Balloon Services': 4.211538461538462,
#  'Pretzels': 3.7229140722291407,
#  'Nanny Services': 4.619512195121951,
#  'Farming Equipment': 3.7329317269076303,
#  'Farm Equipment Repair': 3.7329317269076303,
#  'Bar Crawl': 4.299870745368375,
#  'Supernatural Readings': 4.370759837177747,
#  'Psychics': 4.370759837177747,
#  'Trailer Dealers': 3.3854166666666665,
#  'Venezuelan': 4.324653739612188,
#  'Saunas': 4.529255319148936,
#  'Currency Exchange': 4.068181818181818,
#  'Bankruptcy Law': 4.192844677137871,
#  'Real Estate Law': 4.192844677137871,
#  'Float Spa': 4.565104166666667,
#  'Personal Care Services': 4.118881118881119,
#  'Elder Care Planning': 4.118881118881119,
#  'Process Servers': 4.264044943820225,
#  'Art Tours': 4.169811320754717,
#  'Tui Na': 4.676258992805756,
#  'Gunsmith': 4.4801762114537445,
#  'Ziplining': 3.5297297297297296,
#  'Product Design': 4.132743362831858,
#  '3D Printing': 4.132743362831858,
#  'Awnings': 4.132992327365729,
#  'Axe Throwing': 4.763837638376383,
#  'Trinidadian': 4.375,
#  'Egyptian': 3.9414715719063547,
#  'Language Schools': 4.318181818181818,
#  'Psychic Mediums': 4.356998381877022,
#  'Boat Tours': 4.317979197622585,
#  'Health Retreats': 4.043405676126878,
#  'Municipality': 2.9615384615384617,
#  'International': 3.7101303911735206,
#  'Tai Chi': 4.599666388657214,
#  'Tenant and Eviction Law': 3.2,
#  'Medical Transportation': 3.0608772286624637,
#  'Holistic Animal Care': 4.456896551724138,
#  'Racing Experience': 4.382231404958677,
#  'Australian': 3.8722826086956523,
#  'Rotisserie Chicken': 4.7368421052631575,
#  'Sandblasting': 3.9038461538461537,
#  'Races & Competitions': 3.6350574712643677,
#  'CSA': 4.191056910569106,
#  'Home Developers': 2.357142857142857,
#  'Taekwondo': 4.169222191246167,
#  'Paint-Your-Own Pottery': 3.9223880597014924,
#  'Beer Tours': 4.3114824335904025,
#  'Health Insurance Offices': 4.02428810720268,
#  'Workers Compensation Law': 4.150442477876106,
#  'Petting Zoos': 4.081638339370298,
#  'Horse Boarding': 4.103994490358127,
#  'Toxicologists': 3.0,
#  'Embassy': 3.0,
#  'Bingo Halls': 3.805084745762712,
#  'Fire Departments': 4.526315789473684,
#  'Dinner Theater': 3.8953846153846152,
#  'Fishing': 4.118694362017804,
#  'Junkyards': 3.4355828220858897,
#  'Halotherapy': 4.65979381443299,
#  'Sunglasses': 4.1570247933884295,
#  'Beverage Store': 4.137744034707159,
#  ...}

# %%
results_dict = dict(sorted(results_dict.items(), key=lambda item: (-item[1], item[0]))[:n])
results_dict
# Out:
# {'Astrologers': 5.0,
#  'Audio/Visual Equipment Rental': 5.0,
#  'Bocce Ball': 5.0,
#  'Calabrian': 5.0,
#  'Chinese Martial Arts': 5.0,
#  'Christmas Markets': 5.0,
#  'Crane Services': 5.0,
#  'DIY Auto Shop': 5.0,
#  'Duplication Services': 5.0,
#  'Fireworks': 5.0}

# %%
results['result'] = [[c, s] for c,s in results_dict.items()]
results
# Out:
# {'result': [['Astrologers', 5.0],
#   ['Audio/Visual Equipment Rental', 5.0],
#   ['Bocce Ball', 5.0],
#   ['Calabrian', 5.0],
#   ['Chinese Martial Arts', 5.0],
#   ['Christmas Markets', 5.0],
#   ['Crane Services', 5.0],
#   ['DIY Auto Shop', 5.0],
#   ['Duplication Services', 5.0],
#   ['Fireworks', 5.0]]}

# %%
with open(output_file, 'w+') as o:
    json.dump(results, o)

# %% [markdown]
# ### Task3: Partition (4pts)

# %% [markdown]
# Task description: In this task, you will learn how partitions work in the RDD. You need to compute the businesses that have more than n reviews in the review file. Other than the default way of partitioning the RDD, you should also design a customized partition function to improve computational efficiency. The “partition_type” is a hyperparameter in your program to decide which partition method to use. For either the default or the customized partition function, you need to show the number of partitions for the RDD, the number of items per partition, and the businesses that have more than n reviews (1pts for each partition type). Your customized partition function should improve the computational efficiency, i.e., reducing the time duration of execution (2pts).

# %%
# params = sys.argv
# input_file, output_file = params[1], params[2]
# partition_type, n_partitions，n = params[3], int(params[4]), int(params[5])

# %%
input_file = './review.json'
# output_file = ''
# partition_type = 'default'
partition_type = 'customized'
n_partitions = 3
n = 1024

# %%
results = {}

# %%
conf = SparkConf()
sc = SparkContext(conf=conf)

review = sc.textFile(input_file).map(lambda r: json.loads(r))

# %%
bs_id_rdd = review.map(lambda r: (r['business_id'], 1))

# %%
if partition_type!='default':
    bs_id_rdd = bs_id_rdd.partitionBy(n_partitions, lambda bs_id: ord(bs_id[0])+ord(bs_id[-1]))

# %%
results['n_partitions'] = bs_id_rdd.getNumPartitions()
results['n_items'] = bs_id_rdd.glom().map(len).collect()
tmp = bs_id_rdd.reduceByKey(add).filter(lambda c: c[1]>n).collect()
results['result'] = [[bs_id, c] for bs_id, c in tmp]

# %%
results
# Out:
# {'n_partitions': 3,
#  'n_items': [398690, 359496, 393439],
#  'result': [['f4x1YBxkLrZg652xt2KR5g', 1039],
#   ['K7lWdNUhCbcnEvI0NhGewg', 1156],
#   ['RESDUcs7fIiihp38-d6_6g', 1502],
#   ['4JNXUYY8wbaaDmk3BPzlWw', 1446]]}

# %%
with open(output_file, 'w+') as o:
    json.dump(results, o)
